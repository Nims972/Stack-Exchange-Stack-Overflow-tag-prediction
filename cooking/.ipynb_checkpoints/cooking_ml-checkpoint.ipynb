# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv('cooking.csv')
test = train.tail(3904)
train = train.head(11500)

# %%
train.head()
# Out:
#    id                                              title  \
# 0   1        How can I get chewy chocolate chip cookies?
# 1   2                How should I cook bacon in an oven?
# 2   3  What is the difference between white and brown...
# 3   4  What is the difference between baking soda and...
# 4   5  In a tomato sauce recipe, how can I cut the ac...
#
#                                              content  \
# 0  <p>My chocolate chips cookies are always too c...
# 1  <p>I've heard of people cooking bacon in an ov...
# 2  <p>I always use brown extra large eggs, but I ...
# 3  <p>And can I use one in place of the other in ...
# 4  <p>It seems that every time I make a tomato sa...
#
#                                                 tags
# 0                             baking cookies texture
# 1                            oven cooking-time bacon
# 2                                               eggs
# 3  substitutions please-remove-this-tag baking-so...
# 4               sauce pasta tomatoes italian-cuisine

# %%
test.head()
# Out:
#           id                                              title  \
# 11500  54965    substitute for shiso leaf in umeboshi makizushi
# 11501  54967  Why did my pork center cut loin turn out tende...
# 11502  54968       Is this chicken safe? silkie chicken edition
# 11503  54972                                 Cookie dough crust
# 11504  54974                     Getting seasoning into a roast
#
#                                                  content  \
# 11500  <p>I would like to make umeboshi makizushi, bu...
# 11501  <p>Why did my pork center cut loin turn out te...
# 11502  <p>First off, I am a pastry chef, and my first...
# 11503  <p>I want to make a dessert using a sugar cook...
# 11504  <p>I'm getting into braising a lot of pork and...
#
#                                        tags
# 11500  substitutions japanese-cuisine sushi
# 11501                                  pork
# 11502     food-safety chicken asian-cuisine
# 11503                                baking
# 11504                        roast braising

# %%
print(len(train), len(test))
# Out:
# 11500 3904

# %%
train.isnull().sum()
# Out:
# id         0
# title      0
# content    0
# tags       0
# dtype: int64

# %%
train[train.isnull().any(axis = 1)]
# Out:
# Empty DataFrame
# Columns: [id, title, content, tags]
# Index: []

# %%
train.dropna(axis = 0, inplace = True)

# %%
y_train = train.iloc[:, 3].values
print(y_train)
print(len(y_train))
# Out:
# ['baking cookies texture' 'oven cooking-time bacon' 'eggs' ... 'freezing'
#  'food-safety' 'frying boiling meatballs']
# 11500

# %%
# %%time
list_of_all_tags = []
for i in range(len(y_train)):
    row_tags = []
    start = 0
    for j in range(len(y_train[i])):
        if(y_train[i][j] == ' '):
            row_tags.append(y_train[i][start : j])
            list_of_all_tags.append(y_train[i][start : j])
            start = j+1
    row_tags.append(y_train[i][start : len(y_train[i])])
    list_of_all_tags.append(y_train[i][start : len(y_train[i])])
    y_train[i] = row_tags
# Out:
# Wall time: 256 ms

# %%
len(list_of_all_tags)
# Out:
# 27030

# %%
list_of_all_unique_tags = set(list_of_all_tags)

# %%
len(list_of_all_unique_tags)
# Out:
# 713

# %%
from collections import defaultdict
tags_count = defaultdict(int)
for i in list_of_all_tags:
    tags_count[i] += 1

# %%
cc = 0
for tags, cnt in tags_count.items():
    if(cnt < 5):
        cc += 1
print(cc)
# Out:
# 135

# %%
tags_to_remove = [tags for tags, cnt in tags_count.items() if(cnt < 100)]

# %%
tags_to_remove = set(tags_to_remove)

# %%
tags_count['mingw']
# Out:
# 0

# %%
# %%time
y = []
for i in range(len(y_train)):
    j = 1
    new_tags = []
    new_tags.append(y_train[i][0])
    while(j < len(y_train[i])):
        if(not(y_train[i][j] in tags_to_remove)):
            new_tags.append(y_train[i][j])
        j += 1
    y.append(new_tags)
# Out:
# Wall time: 18.9 ms

# %%
y
# Out:
# [['baking', 'cookies'],
#  ['oven', 'cooking-time'],
#  ['eggs'],
#  ['substitutions'],
#  ['sauce', 'pasta', 'tomatoes', 'italian-cuisine'],
#  ['substitutions'],
#  ['food-safety', 'beef', 'cooking-time'],
#  ['eggs'],
#  ['ice-cream'],
#  ['baking', 'chicken', 'cooking-time'],
#  ['grilling'],
#  ['baking', 'flour'],
#  ['storage-method', 'storage-lifetime'],
#  ['canning', 'food-preservation'],
#  ['spices'],
#  ['food-safety', 'storage-method', 'storage-lifetime', 'butter'],
#  ['baking', 'bread', 'dough'],
#  ['rice', 'italian-cuisine'],
#  ['eggs', 'food-science'],
#  ['storage-method', 'bread'],
#  ['knife-skills'],
#  ['nutrient-composition'],
#  ['storage-method', 'spices'],
#  ['storage-method', 'storage-lifetime', 'spices'],
#  ['conversion'],
#  ['chicken', 'meat'],
#  ['baking'],
#  ['equipment'],
#  ['grilling'],
#  ['storage-method'],
#  ['grilling', 'sauce'],
#  ['organization'],
#  ['baking', 'bread'],
#  ['substitutions', 'baking', 'pie'],
#  ['food-safety', 'eggs', 'storage-lifetime'],
#  ['storage-method', 'food-science'],
#  ['substitutions', 'milk'],
#  ['equipment'],
#  ['frying'],
#  ['please-remove-this-tag', 'salt'],
#  ['meat', 'salt', 'steak'],
#  ['storage-method'],
#  ['substitutions'],
#  ['meat'],
#  ['storage-method', 'freezing'],
#  ['storage-method', 'spices'],
#  ['chicken'],
#  ['fruit'],
#  ['herbs'],
#  ['substitutions', 'milk'],
#  ['equipment'],
#  ['equipment'],
#  ['baking', 'equipment'],
#  ['rice'],
#  ['spaghetti', 'pasta'],
#  ['spices'],
#  ['mushrooms'],
#  ['frying', 'equipment'],
#  ['spices'],
#  ['sauce'],
#  ['substitutions'],
#  ['baking', 'pizza'],
#  ['mango'],
#  ['substitutions'],
#  ['baking', 'eggs', 'pie'],
#  ['food-safety', 'fish'],
#  ['salt', 'flavor'],
#  ['equipment', 'cleaning'],
#  ['baking', 'dough', 'pie'],
#  ['substitutions', 'sugar'],
#  ['meat', 'steak'],
#  ['chicken', 'frying'],
#  ['knife-skills'],
#  ['equipment'],
#  ['meat'],
#  ['substitutions'],
#  ['knife-skills'],
#  ['substitutions', 'cheese'],
#  ['grilling', 'meat'],
#  ['equipment'],
#  ['baking', 'equipment', 'oven'],
#  ['fire'],
#  ['equipment', 'baking'],
#  ['beef', 'steak'],
#  ['cheese', 'onions', 'soup'],
#  ['substitutions', 'beef'],
#  ['substitutions', 'salt'],
#  ['chicken', 'food-safety'],
#  ['equipment'],
#  ['baking', 'flour'],
#  ['please-remove-this-tag'],
#  ['food-science', 'flavor'],
#  ['substitutions', 'flavor'],
#  ['salt', 'soup'],
#  ['baking', 'eggs'],
#  ['storage-method', 'freezing'],
#  ['substitutions'],
#  ['resources'],
#  ['baking', 'potatoes'],
#  ['flour', 'dough', 'pizza'],
#  ['pasta'],
#  ['substitutions', 'cheese'],
#  ['baking'],
#  ['cheese'],
#  ['storage-method', 'potatoes'],
#  ['fish'],
#  ['food-science', 'beans'],
#  ['vegetarian'],
#  ['drying'],
#  ['storage-method'],
#  ['storage-method', 'food-safety', 'potatoes'],
#  ['pie'],
#  ['equipment', 'slow-cooking'],
#  ['eggs', 'food-science'],
#  ['fish'],
#  ['chinese-cuisine'],
#  ['cookware'],
#  ['baking', 'substitutions'],
#  ['equipment', 'cookware'],
#  ['substitutions', 'pasta'],
#  ['flavor', 'salt', 'spices'],
#  ['baking', 'sugar'],
#  ['onions'],
#  ['chocolate'],
#  ['knives'],
#  ['potatoes'],
#  ['cookies', 'chocolate'],
#  ['substitutions', 'salt'],
#  ['baking', 'oven', 'temperature'],
#  ['garlic'],
#  ['bell-peppers'],
#  ['vegetables'],
#  ['sugar'],
#  ['dessert'],
#  ['cooking-time'],
#  ['food-safety', 'meat'],
#  ['storage-method', 'eggs'],
#  ['meat'],
#  ['food-safety', 'food-preservation'],
#  ['storage-method', 'rice', 'pie'],
#  ['substitutions', 'equipment'],
#  ['eggs'],
#  ['cast-iron'],
#  ['baking', 'pie'],
#  ['substitutions', 'eggs', 'cookies'],
#  ['oil'],
#  ['flavor', 'freezing'],
#  ['alcohol', 'food-science'],
#  ['substitutions'],
#  ['eggplant', 'vegetables'],
#  ['substitutions', 'oil'],
#  ['additives'],
#  ['knives'],
#  ['wok', 'equipment'],
#  ['knife-skills'],
#  ['frying', 'oil'],
#  ['nuts'],
#  ['cast-iron'],
#  ['eggs', 'frying'],
#  ['storage-method', 'food-safety', 'storage-lifetime', 'beef'],
#  ['eggs'],
#  ['cake'],
#  ['rice'],
#  ['fish'],
#  ['substitutions'],
#  ['sauce'],
#  ['substitutions'],
#  ['frying'],
#  ['eggs'],
#  ['italian-cuisine', 'tomatoes'],
#  ['temperature'],
#  ['rice'],
#  ['baking', 'roasting'],
#  ['rice', 'italian-cuisine'],
#  ['language'],
#  ['baking'],
#  ['salt'],
#  ['garlic', 'slow-cooking'],
#  ['substitutions'],
#  ['peeling', 'tomatoes', 'boiling'],
#  ['food-safety', 'food-science'],
#  ['fruit', 'food-preservation'],
#  ['flavor'],
#  ['eggs', 'freezing', 'food-preservation'],
#  ['frying', 'beef'],
#  ['substitutions', 'asian-cuisine'],
#  ['knives', 'equipment'],
#  ['substitutions'],
#  ['equipment'],
#  ['smell', 'refrigerator', 'freezing'],
#  ['bacon'],
#  ['freezing'],
#  ['equipment', 'cheese'],
#  ['food-safety', 'chicken', 'grilling'],
#  ['shopping'],
#  ['eggs'],
#  ['baking', 'flour', 'cookies'],
#  ['cheese'],
#  ['meat', 'steak'],
#  ['baking', 'cookies'],
#  ['frying'],
#  ['garlic'],
#  ['eggs', 'boiling'],
#  ['ripe', 'fruit'],
#  ['equipment', 'oven'],
#  ['storage-method', 'vegetables', 'fruit'],
#  ['storage-method', 'storage-lifetime'],
#  ['pork'],
#  ['baking', 'bread', 'dough'],
#  ['baking', 'bread'],
#  ['frying'],
#  ['bread'],
#  ['lamb'],
#  ['fish'],
#  ['drinks'],
#  ['baking', 'bread'],
#  ['drinks', 'coffee', 'roasting'],
#  ['cocktails'],
#  ['drinks'],
#  ['drinks'],
#  ['chicken', 'meat'],
#  ['baking', 'equipment', 'pie'],
#  ['seeds'],
#  ['salt'],
#  ['eggs'],
#  ['flavor', 'soup'],
#  ['cheese'],
#  ['equipment', 'cookware'],
#  ['grilling', 'fish'],
#  ['cheese', 'milk', 'boiling'],
#  ['smell'],
#  ['condiments'],
#  ['substitutions'],
#  ['cheese-making'],
#  ['knives'],
#  ['vegetables'],
#  ['chocolate'],
#  ['asian-cuisine'],
#  ['frying'],
#  ['culinary-uses'],
#  ['temperature', 'equipment'],
#  ['cleaning'],
#  ['baking', 'cookies'],
#  ['fish', 'grilling'],
#  ['fish'],
#  ['slow-cooking'],
#  ['pork'],
#  ['frying', 'oil', 'steak'],
#  ['flavor', 'spices'],
#  ['storage-method'],
#  ['bread'],
#  ['food-safety', 'storage-lifetime', 'milk'],
#  ['barbecue'],
#  ['baking', 'dessert'],
#  ['knife-skills'],
#  ['potatoes', 'oven', 'microwave'],
#  ['barbecue'],
#  ['food-preservation'],
#  ['jalapeno'],
#  ['american-cuisine'],
#  ['eggs', 'boiling'],
#  ['food-safety'],
#  ['baking'],
#  ['meat', 'steak'],
#  ['storage-method', 'coffee'],
#  ['freezing', 'fruit'],
#  ['equipment'],
#  ['meat', 'frying'],
#  ['ice-cream'],
#  ['food-safety', 'cheese'],
#  ['drinks'],
#  ['drinks', 'sugar'],
#  ['chicken', 'frying'],
#  ['ripe'],
#  ['food-safety', 'potatoes'],
#  ['cleaning'],
#  ['pork-chops'],
#  ['vegetables', 'cleaning'],
#  ['substitutions'],
#  ['food-safety', 'chicken'],
#  ['substitutions', 'cheese'],
#  ['food-safety', 'potatoes', 'vegetables'],
#  ['substitutions'],
#  ['barbecue'],
#  ['substitutions', 'baking', 'sugar'],
#  ['food-safety', 'chicken'],
#  ['food-safety', 'equipment', 'cookware'],
#  ['food-safety', 'meat', 'food-preservation', 'freezing'],
#  ['mushrooms'],
#  ['substitutions', 'fish', 'asian-cuisine'],
#  ['organization'],
#  ['skin'],
#  ['food-safety', 'food-preservation'],
#  ['food-safety'],
#  ['fish'],
#  ['storage-method', 'rice'],
#  ['storage-method'],
#  ['grilling'],
#  ['beef', 'steak'],
#  ['storage-lifetime'],
#  ['food-safety', 'chicken'],
#  ['chicken'],
#  ['chilling'],
#  ['chicken', 'grilling'],
#  ['pasta', 'potatoes', 'italian-cuisine'],
#  ['equipment'],
#  ['vegetables'],
#  ['beverages'],
#  ['grilling'],
#  ['vegetables', 'culinary-uses'],
#  ['equipment', 'pizza'],
#  ['spices'],
#  ['spices'],
#  ['food-safety', 'chicken', 'meat', 'steak'],
#  ['bread'],
#  ['baking', 'bread'],
#  ['baking', 'pizza'],
#  ['pie'],
#  ['fish'],
#  ['food-preservation'],
#  ['please-remove-this-tag', 'pie', 'dough', 'baking'],
#  ['eggs'],
#  ['chicken'],
#  ['restaurant-mimicry'],
#  ['frying', 'oil'],
#  ['substitutions', 'baking', 'chocolate'],
#  ['meat', 'salt'],
#  ['baking', 'bread'],
#  ['soup'],
#  ['chicken'],
#  ['substitutions', 'eggs'],
#  ['seasoning'],
#  ['oil'],
#  ['food-safety'],
#  ['eggs'],
#  ['food-safety'],
#  ['pizza'],
#  ['meat'],
#  ['storage-method', 'storage-lifetime', 'tomatoes'],
#  ['bread', 'baking'],
#  ['pasta', 'italian-cuisine'],
#  ['storage-method', 'eggs', 'refrigerator'],
#  ['substitutions', 'baking', 'milk'],
#  ['eggs', 'italian-cuisine', 'dessert'],
#  ['substitutions', 'milk'],
#  ['vegetables', 'tomatoes'],
#  ['eggs'],
#  ['cookware'],
#  ['sauce'],
#  ['learning'],
#  ['food-safety', 'boiling'],
#  ['baking'],
#  ['baking', 'bread'],
#  ['equipment', 'pizza'],
#  ['eggs'],
#  ['sauce'],
#  ['kohlrabi'],
#  ['storage-method'],
#  ['fish'],
#  ['storage-method'],
#  ['storage-method', 'meat', 'freezing'],
#  ['ripe', 'fruit'],
#  ['equipment', 'cleaning'],
#  ['baking'],
#  ['beef'],
#  ['herbs'],
#  ['butter'],
#  ['sugar', 'fruit'],
#  ['baking', 'cake'],
#  ['meat'],
#  ['knives', 'equipment'],
#  ['dough'],
#  ['substitutions', 'salt'],
#  ['chocolate'],
#  ['coffee'],
#  ['fermentation'],
#  ['food-safety', 'milk'],
#  ['cherries'],
#  ['cake'],
#  ['bread'],
#  ['substitutions'],
#  ['please-remove-this-tag', 'culinary-uses'],
#  ['storage-method', 'cleaning'],
#  ['knife-skills'],
#  ['garlic'],
#  ['caffeine'],
#  ['coffee'],
#  ['duck'],
#  ['freezing'],
#  ['fish', 'grilling'],
#  ['substitutions', 'cheese'],
#  ['storage-method'],
#  ['yogurt'],
#  ['meat', 'slow-cooking', 'sous-vide'],
#  ['fish'],
#  ['garlic'],
#  ['peeling'],
#  ['untagged'],
#  ['kimchi'],
#  ['cheese', 'pasta'],
#  ['substitutions', 'cheese'],
#  ['pasta', 'storage-lifetime', 'refrigerator'],
#  ['barbecue', 'pork'],
#  ['dessert'],
#  ['grilling', 'beef'],
#  ['freezing', 'onions'],
#  ['drinks', 'coffee'],
#  ['tahini'],
#  ['barbecue'],
#  ['cutting'],
#  ['baking', 'bread', 'cookies'],
#  ['fruit'],
#  ['cookbook'],
#  ['smoking'],
#  ['quinoa'],
#  ['canning'],
#  ['bread', 'indian-cuisine'],
#  ['chicken'],
#  ['roast'],
#  ['food-safety'],
#  ['pie'],
#  ['equipment', 'food-safety', 'cleaning'],
#  ['substitutions', 'beef'],
#  ['meat'],
#  ['baking', 'bread', 'dough'],
#  ['grilling', 'pizza', 'oven'],
#  ['baking', 'cookies'],
#  ['milk'],
#  ['salt'],
#  ['yogurt'],
#  ['please-remove-this-tag'],
#  ['pie', 'dough', 'freezing', 'refrigerator'],
#  ['shopping'],
#  ['vegetables'],
#  ['cajun-cuisine'],
#  ['cajun-cuisine'],
#  ['baking', 'bread', 'dough'],
#  ['food-safety'],
#  ['lamb'],
#  ['leeks'],
#  ['food-safety', 'meat', 'vegetables'],
#  ['sushi', 'asian-cuisine'],
#  ['food-safety'],
#  ['substitutions', 'onions'],
#  ['food-safety', 'bread'],
#  ['baking', 'flour'],
#  ['baking', 'substitutions', 'oil', 'butter'],
#  ['grilling'],
#  ['asian-cuisine'],
#  ['resources'],
#  ['learning'],
#  ['food-science', 'flavor'],
#  ['roast'],
#  ['herbs'],
#  ['onions'],
#  ['storage-method', 'freezing', 'onions'],
#  ['pasta', 'dough'],
#  ['stock'],
#  ['storage-method'],
#  ['meat'],
#  ['storage-method', 'vegetables', 'culinary-uses'],
#  ['italian-cuisine'],
#  ['chicken', 'frying', 'spices'],
#  ['stock'],
#  ['stock', 'culinary-uses'],
#  ['bread'],
#  ['substitutions', 'rice'],
#  ['pancakes'],
#  ['grilling'],
#  ['resources'],
#  ['equipment'],
#  ['substitutions', 'baking', 'sugar'],
#  ['rice'],
#  ['vegetables', 'roasting'],
#  ['baking', 'dough'],
#  ['baking'],
#  ['tortilla-chips'],
#  ['freezing'],
#  ['cleaning', 'cookware'],
#  ['substitutions'],
#  ['pasta', 'food-science', 'salt', 'boiling'],
#  ['baking'],
#  ['rice', 'asian-cuisine'],
#  ['substitutions'],
#  ['herbs'],
#  ['stove'],
#  ['rice'],
#  ['beef'],
#  ['equipment', 'meat'],
#  ['frying'],
#  ['food-safety', 'temperature'],
#  ['sauce', 'slow-cooking', 'italian-cuisine'],
#  ['storage-method', 'potatoes'],
#  ['baking'],
#  ['grilling'],
#  ['meat'],
#  ['baking'],
#  ['equipment'],
#  ['equipment', 'cleaning'],
#  ['chocolate', 'dessert'],
#  ['frying', 'oil'],
#  ['meat', 'temperature'],
#  ['food-preservation'],
#  ['rice'],
#  ['jam'],
#  ['grilling'],
#  ['sauce'],
#  ['gumbo'],
#  ['baking', 'grilling'],
#  ['organization'],
#  ['food-science', 'flavor'],
#  ['food-science'],
#  ['food-safety', 'storage-method', 'temperature'],
#  ['beef', 'temperature'],
#  ['food-safety', 'pork'],
#  ['equipment', 'vegetables'],
#  ['substitutions'],
#  ['fruit'],
#  ['onions'],
#  ['equipment', 'sous-vide'],
#  ['storage-method'],
#  ['flavor', 'sous-vide'],
#  ['raw'],
#  ['garlic', 'oil', 'butter'],
#  ['shellfish'],
#  ['baking', 'salt'],
#  ['baking'],
#  ['roast-beef'],
#  ['pie'],
#  ['beef', 'roasting'],
#  ['fruit'],
#  ['cleaning'],
#  ['flavor'],
#  ['history'],
#  ['grilling', 'cleaning'],
#  ['substitutions'],
#  ['basics'],
#  ['crab'],
#  ['food-safety', 'refrigerator'],
#  ['grilling'],
#  ['baking', 'flour'],
#  ['food-safety', 'fish'],
#  ['mutton'],
#  ['fruit'],
#  ['spices', 'flavor'],
#  ['freezing'],
#  ['frying'],
#  ['freezing', 'steak'],
#  ['food-safety', 'eggs'],
#  ['cheese', 'indian-cuisine'],
#  ['stock'],
#  ['storage-method', 'storage-lifetime'],
#  ['duck'],
#  ['breakfast'],
#  ['stock'],
#  ['gelling-agents'],
#  ['substitutions'],
#  ['butter', 'chocolate'],
#  ['substitutions'],
#  ['food-safety', 'oil'],
#  ['sugar', 'dessert'],
#  ['sugar'],
#  ['eggs', 'dessert', 'chocolate'],
#  ['equipment', 'coffee'],
#  ['chicken'],
#  ['food-preservation'],
#  ['cheese'],
#  ['freezing'],
#  ['substitutions', 'pasta', 'boiling'],
#  ['substitutions', 'milk'],
#  ['pancakes'],
#  ['chinese-cuisine'],
#  ['butter'],
#  ['herbs'],
#  ['food-preservation'],
#  ['sausages'],
#  ['storage-method', 'flour'],
#  ['food-safety', 'beef'],
#  ['watermelon'],
#  ['food-safety'],
#  ['substitutions'],
#  ['cookware'],
#  ['wine'],
#  ['sauce', 'cheese'],
#  ['baking', 'sugar', 'butter', 'cookies'],
#  ['culinary-uses'],
#  ['crab'],
#  ['herbs', 'food-preservation'],
#  ['microwave'],
#  ['sauce', 'dessert'],
#  ['batter'],
#  ['baking', 'cookies'],
#  ['pasta', 'food-preservation'],
#  ['wine'],
#  ['cheese'],
#  ['pork'],
#  ['knife-skills', 'tomatoes'],
#  ['chicken', 'frying'],
#  ['drinks'],
#  ['cheese'],
#  ['sauce'],
#  ['fish'],
#  ['cookies'],
#  ['history'],
#  ['frying', 'steak'],
#  ['sauce', 'culinary-uses'],
#  ['food-safety'],
#  ['chicken'],
#  ['pork'],
#  ['cookies'],
#  ['baking', 'flour'],
#  ['meat', 'steak'],
#  ['cheesecake'],
#  ['wine'],
#  ['broth', 'culinary-uses'],
#  ['sauce'],
#  ['culinary-uses'],
#  ['seasoning'],
#  ['bacon'],
#  ['vegetables', 'onions'],
#  ['stainless-steel'],
#  ['greek-cuisine'],
#  ['tzatziki'],
#  ['pork'],
#  ['equipment'],
#  ['grilling', 'steak'],
#  ['pasta', 'microwave'],
#  ['fish'],
#  ['frying', 'steak'],
#  ['culinary-uses'],
#  ['substitutions', 'fish'],
#  ['pizza'],
#  ['fresh'],
#  ['meat'],
#  ['tuna'],
#  ['culinary-uses'],
#  ['gelatin'],
#  ['chocolate'],
#  ['cookies'],
#  ['cheese-making'],
#  ['substitutions'],
#  ['cream'],
#  ['asian-cuisine'],
#  ['baking'],
#  ['curry'],
#  ['resources'],
#  ['storage-method', 'storage-lifetime'],
#  ['steak'],
#  ['meat'],
#  ['substitutions', 'spices'],
#  ['food-safety', 'meat'],
#  ['food-safety', 'spices', 'storage-lifetime', 'food-preservation'],
#  ['substitutions'],
#  ['storage-method'],
#  ['shrimp'],
#  ['food-safety', 'chicken', 'grilling'],
#  ['shopping'],
#  ['spices', 'steak'],
#  ['storage-method', 'storage-lifetime'],
#  ['please-remove-this-tag', 'vegetables', 'oil'],
#  ['food-safety'],
#  ['spices', 'flavor'],
#  ['kitchen'],
#  ['equipment'],
#  ['substitutions', 'chocolate'],
#  ['italian-cuisine', 'culinary-uses'],
#  ['meat'],
#  ['jam'],
#  ['eggs', 'butter'],
#  ['resources'],
#  ['storage-method', 'vegetables', 'freezing'],
#  ['onions'],
#  ['milk', 'coffee'],
#  ['substitutions', 'fish'],
#  ['pork', 'sous-vide'],
#  ['substitutions', 'baking', 'butter'],
#  ['fruit'],
#  ['baking', 'flour', 'food-science'],
#  ['please-remove-this-tag', 'dessert'],
#  ['dessert'],
#  ['cheese'],
#  ['grilling', 'beef'],
#  ['eggs'],
#  ['substitutions', 'italian-cuisine'],
#  ['batter'],
#  ['substitutions', 'italian-cuisine'],
#  ['equipment', 'salt'],
#  ['pork'],
#  ['oil'],
#  ['please-remove-this-tag', 'vegetables'],
#  ['olive'],
#  ['food-safety'],
#  ['baking', 'substitutions', 'chocolate'],
#  ['please-remove-this-tag'],
#  ['substitutions', 'baking'],
#  ['chicken'],
#  ['baking', 'bread', 'freezing'],
#  ['food-safety', 'storage-method'],
#  ['pasta', 'slow-cooking'],
#  ['equipment', 'coffee'],
#  ['knives'],
#  ['equipment'],
#  ['chicken'],
#  ['storage-method', 'fruit'],
#  ['food-safety', 'meat', 'storage-lifetime'],
#  ['sauce', 'butter'],
#  ['baking'],
#  ['basics'],
#  ['substitutions', 'baking', 'milk'],
#  ['milk'],
#  ['beef'],
#  ['flavor'],
#  ['please-remove-this-tag', 'flour'],
#  ['eggs', 'boiling'],
#  ['sauce'],
#  ['storage-method'],
#  ['okra'],
#  ['baking'],
#  ['chicken', 'frying'],
#  ['storage-lifetime'],
#  ['fish'],
#  ['additives'],
#  ['food-safety', 'cleaning'],
#  ['wheat'],
#  ['substitutions'],
#  ['mushrooms'],
#  ['oven'],
#  ['uht'],
#  ['mushrooms'],
#  ['food-safety', 'beef', 'slow-cooking'],
#  ['spices'],
#  ['knives'],
#  ['storage-method'],
#  ['equipment'],
#  ['pasta', 'boiling'],
#  ['grilling'],
#  ['flavor'],
#  ['lettuce'],
#  ['food-science'],
#  ['cabbage'],
#  ['food-safety', 'storage-method', 'slow-cooking'],
#  ['chicken'],
#  ['oil', 'boiling'],
#  ['presentation'],
#  ['language'],
#  ['barbecue'],
#  ['meat'],
#  ['storage-method', 'oven'],
#  ['food-safety', 'steak'],
#  ['food-science', 'dough', 'bread'],
#  ['vegetables'],
#  ['milk'],
#  ['knife-skills', 'onions'],
#  ['potatoes'],
#  ['sugar', 'food-science'],
#  ['artichokes'],
#  ['eggplant'],
#  ['substitutions', 'eggs'],
#  ['substitutions'],
#  ['flan'],
#  ['sauce', 'cheese'],
#  ['equipment', 'pizza'],
#  ['grilling', 'steak'],
#  ['substitutions', 'sugar'],
#  ['soup', 'milk'],
#  ['sour-cream'],
#  ['grilling', 'fruit'],
#  ['alcohol'],
#  ['substitutions', 'baking'],
#  ['baking', 'dessert', 'cake'],
#  ['slow-cooking'],
#  ['dessert', 'chocolate'],
#  ['soup'],
#  ['storage-method', 'food-science', 'flavor'],
#  ['baking', 'substitutions', 'spices', 'cake'],
#  ['soup'],
#  ['middle-eastern-cuisine'],
#  ['bread', 'soup'],
#  ['oven'],
#  ['baking'],
#  ['substitutions', 'eggs'],
#  ['liver'],
#  ['grilling'],
#  ['italian-cuisine'],
#  ['beans'],
#  ['eggs'],
#  ['pasta', 'boiling'],
#  ['meat', 'pasta'],
#  ['vegetables', 'boiling', 'cooking-time'],
#  ['sauce'],
#  ['sauce'],
#  ['slow-cooking'],
#  ['slow-cooking'],
#  ['substitutions'],
#  ['bread', 'indian-cuisine'],
#  ['food-safety'],
#  ['cheese', 'baking'],
#  ['eggs'],
#  ['onions'],
#  ['indian-cuisine'],
#  ['chicken', 'microwave'],
#  ['fruit'],
#  ['shopping', 'equipment'],
#  ['frying', 'oil'],
#  ['food-safety', 'steak'],
#  ['potatoes'],
#  ['please-remove-this-tag', 'cheese'],
#  ['restaurant-mimicry', 'indian-cuisine'],
#  ['brining'],
#  ['comparisons'],
#  ['mascarpone'],
#  ['seafood'],
#  ['barbecue', 'equipment'],
#  ['grilling'],
#  ['fish', 'freezing'],
#  ['corn'],
#  ['vegetables'],
#  ['herbs', 'soup'],
#  ['eggs', 'sauce', 'italian-cuisine'],
#  ['substitutions', 'cheese'],
#  ['pizza'],
#  ['sauce'],
#  ['vinegar'],
#  ['potatoes', 'tomatoes'],
#  ['meat', 'culinary-uses'],
#  ['food-safety', 'beef', 'steak'],
#  ['culinary-uses', 'tea'],
#  ['ice-cream'],
#  ['grilling'],
#  ['sauce'],
#  ['spicy-hot'],
#  ['fats'],
#  ['food-safety', 'chicken'],
#  ['chicken'],
#  ['substitutions'],
#  ['grilling'],
#  ['chicken'],
#  ['baking', 'fish'],
#  ['eggs'],
#  ['substitutions', 'milk'],
#  ['potatoes'],
#  ['frying'],
#  ['hamburgers'],
#  ['beef', 'oven'],
#  ['rice'],
#  ['peaches'],
#  ['fish'],
#  ['temperature', 'refrigerator'],
#  ['asian-cuisine'],
#  ['dessert'],
#  ['sous-vide'],
#  ['pork'],
#  ['salt'],
#  ['pie'],
#  ['steak'],
#  ['dough'],
#  ['measurements'],
#  ['eggs', 'boiling', 'cooking-time'],
#  ['vegetables'],
#  ['potatoes'],
#  ['candy'],
#  ['baking'],
#  ['curry'],
#  ['substitutions'],
#  ['substitutions', 'italian-cuisine'],
#  ['substitutions', 'salt', 'food-science'],
#  ['eggs', 'sauce'],
#  ['please-remove-this-tag'],
#  ['allergy'],
#  ['fruit'],
#  ['cake'],
#  ['bread'],
#  ['storage-lifetime'],
#  ['okra'],
#  ['storage-lifetime', 'coffee'],
#  ['baking', 'flour'],
#  ['pasta'],
#  ['food-safety', 'fruit'],
#  ['fruit'],
#  ['nuts'],
#  ['food-science'],
#  ['barbecue'],
#  ['seasoning'],
#  ['bread', 'cheese'],
#  ['salami'],
#  ['custard'],
#  ['storage-method', 'storage-lifetime', 'onions'],
#  ['chicken'],
#  ['equipment', 'fish', 'sous-vide'],
#  ['fish'],
#  ['fruit'],
#  ['equipment', 'food-safety', 'meat'],
#  ['equipment'],
#  ['fruit'],
#  ['texture'],
#  ['fruit'],
#  ['chocolate'],
#  ['chicken'],
#  ['substitutions'],
#  ['chicken', 'frying'],
#  ['grilling', 'boiling'],
#  ['substitutions', 'asian-cuisine'],
#  ['equipment'],
#  ['food-science'],
#  ['cooking-time'],
#  ['baking', 'grilling'],
#  ['eggs', 'pasta'],
#  ['knives'],
#  ['pasta'],
#  ['frosting'],
#  ['equipment'],
#  ['frying'],
#  ['equipment'],
#  ['milk'],
#  ['freezing', 'pie'],
#  ['substitutions', 'baking', 'cake'],
#  ['vegetables', 'food-science', 'freezing'],
#  ['meat', 'milk'],
#  ['italian-cuisine'],
#  ['baking', 'bread'],
#  ['cooking-time', 'slow-cooking'],
#  ['canning'],
#  ['boiling', 'cooking-time'],
#  ['equipment', 'grilling'],
#  ['risotto'],
#  ['baking', 'equipment', 'oven'],
#  ['food-safety', 'pork'],
#  ['onions'],
#  ['pie'],
#  ['bacon'],
#  ['equipment'],
#  ['jicama'],
#  ['food-safety'],
#  ['pie'],
#  ['sauce'],
#  ['onions'],
#  ['non-stick'],
#  ['pork', 'cooking-time'],
#  ['dough', 'pizza', 'italian-cuisine'],
#  ['baking', 'food-science', 'butter'],
#  ['freezing', 'cheese'],
#  ['fruit'],
#  ['baking', 'bread'],
#  ['storage-method', 'fruit'],
#  ['fruit'],
#  ['coffee'],
#  ['cream'],
#  ['pasta'],
#  ['baking', 'substitutions', 'flour'],
#  ['storage-method', 'eggs', 'freezing'],
#  ['frying', 'potatoes'],
#  ['garlic'],
#  ['substitutions', 'potatoes'],
#  ['food-safety', 'cooking-time'],
#  ['equipment', 'cleaning'],
#  ['equipment'],
#  ['storage-method', 'equipment', 'bread'],
#  ['milk'],
#  ['peeling'],
#  ['eggs'],
#  ['equipment'],
#  ['onions'],
#  ['equipment'],
#  ['substitutions'],
#  ['salt'],
#  ['baking', 'cake'],
#  ['substitutions'],
#  ['equipment'],
#  ['measurements'],
#  ['storage-method', 'eggs'],
#  ['equipment'],
#  ['substitutions', 'eggs'],
#  ['vegetables'],
#  ['wok'],
#  ['baking', 'cake'],
#  ['food-science', 'sugar'],
#  ['equipment'],
#  ['food-preservation'],
#  ['fish'],
#  ['substitutions'],
#  ['substitutions'],
#  ['please-remove-this-tag'],
#  ['eggs', 'microwave'],
#  ['baking', 'fruit', 'cake'],
#  ['cleaning', 'boiling', 'milk'],
#  ['soymilk'],
#  ['reheating'],
#  ['food-safety', 'storage-method', 'storage-lifetime'],
#  ['culinary-uses'],
#  ['freezing'],
#  ['storage-lifetime'],
#  ['food-safety', 'storage-method', 'cleaning'],
#  ['please-remove-this-tag', 'coffee'],
#  ['substitutions', 'chocolate'],
#  ['flavor'],
#  ['food-safety', 'storage-method', 'cleaning', 'flour'],
#  ['bread'],
#  ['storage-lifetime', 'sugar'],
#  ['allergy'],
#  ['flour'],
#  ...]

# %%
final_tags = []
for i in range(len(y)):
    for j in range(len(y[i])):
        final_tags.append(y[i][j])

# %%
len(final_tags)
final_tags = set(final_tags)
print(len(final_tags))
# Out:
# 488

# %%
# %%time
from sklearn.preprocessing import MultiLabelBinarizer
mlb = MultiLabelBinarizer(classes=list(final_tags))
y = mlb.fit_transform(y)
# Out:
# Wall time: 11.4 s

# %%
import nltk
# nltk.download('stopwords')
from nltk.corpus import stopwords
import re

# %%
x_train = train.iloc[:, 1].values
tmp = train.values
for i in range(0,len(tmp)):
    x_train[i]=tmp[i,1] + " " + tmp[i,2];
x_train[0]
# Out:
# 'How can I get chewy chocolate chip cookies? <p>My chocolate chips cookies are always too crisp. How can I get chewy cookies, like those of Starbucks?</p>\n\n<hr>\n\n<p>Thank you to everyone who has answered. So far the tip that had the biggest impact was to chill and rest the dough, however I also increased the brown sugar ratio and increased a bit the butter. Also adding maple syrup helped. </p>\n'

# %%
x_train = [str(i) for i in x_train]

# %%
x_test = test.iloc[:, 1].values
tmp = test.values
for i in range(0,len(tmp)):
    x_test[i]=tmp[i,1] + " " + tmp[i,2];
x_test[0]
# Out:
# "substitute for shiso leaf in umeboshi makizushi <p>I would like to make umeboshi makizushi, but I don't have access to shiso leaf which is traditionally paired with the umeboshi. Is there any acceptable substitute for the shiso that is more readily accessible in the US?</p>\n"

# %%
x_test = [str(i) for i in x_test]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
def tfidf_features(X_train, X_test):    
    tfidf_vectorizer = TfidfVectorizer(min_df=10, max_df=0.9, ngram_range=(1, 2),
                                       token_pattern='(\S+)')
    X_train = tfidf_vectorizer.fit_transform(X_train)
    X_test = tfidf_vectorizer.transform(X_test)
    
    return X_train, X_test, tfidf_vectorizer.vocabulary_

# %%
X_train_tfidf, X_test_tfidf, tfidf_vocab = tfidf_features(x_train, x_test)
tfidf_reversed_vocab = {i:word for word,i in tfidf_vocab.items()}

# %%
X_train_tfidf
# Out:
# <11500x17850 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1128560 stored elements in Compressed Sparse Row format>

# %%
tfidf_vocab['oven']
# Out:
# 11207

# %%
del train

# %%
id = test.iloc[:, 0].values
# Out:
# array([54965, 54967, 54968, ..., 73680, 73681, 73683], dtype=int64)

# %%
# y

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression, RidgeClassifier
def train_classifier(X_train, y_train):
    """
      X_train, y_train — training data
      
      return: trained classifier
    """
    
    # Create and fit LogisticRegression wraped into OneVsRestClassifier.

    ######################################
    ######### YOUR CODE HERE #############
    ######################################  
#     clf = OneVsRestClassifier(MLPClassifier(hidden_layer_sizes=(16,8,8), learning_rate='adaptive', max_iter=2000,verbose=True))
#     clf = OneVsRestClassifier(SVC(max_iter=1000, verbose=True))
    clf = OneVsRestClassifier(LogisticRegression())
#     clf = OneVsRestClassifier(AdaBoostClassifier())
#     clf = OneVsRestClassifier(RidgeClassifier(normalize=True))
    clf.fit(X_train, y_train)
    return clf

# %%
# %%time
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression
clf = OneVsRestClassifier(LogisticRegression())
clf.fit(X_train_tfidf, y)
# Out:
# E:\intelpython3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# Wall time: 56.6 s

# %%
y_pred = clf.predict(X_test_tfidf)

# %%
y_inv = mlb.inverse_transform(y_pred)

# %%
y_inv
# Out:
# [('substitutions',),
#  (),
#  (),
#  ('baking',),
#  (),
#  (),
#  (),
#  (),
#  ('eggs',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('chocolate',),
#  ('cheese',),
#  ('chocolate',),
#  (),
#  (),
#  (),
#  (),
#  ('substitutions',),
#  (),
#  (),
#  (),
#  ('food-safety',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('sauce',),
#  (),
#  ('bread',),
#  (),
#  (),
#  (),
#  ('chicken',),
#  (),
#  (),
#  (),
#  (),
#  ('baking',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('substitutions',),
#  ('substitutions',),
#  (),
#  ('bread',),
#  (),
#  (),
#  ('substitutions',),
#  (),
#  ('substitutions',),
#  (),
#  (),
#  ('rice',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('baking', 'bread'),
#  (),
#  (),
#  ('rice',),
#  (),
#  (),
#  ('food-safety',),
#  ('chicken',),
#  (),
#  ('cookies',),
#  ('pizza',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('cookies', 'baking'),
#  (),
#  (),
#  (),
#  ('baking',),
#  (),
#  (),
#  ('salt',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('cake',),
#  (),
#  (),
#  ('bread',),
#  (),
#  (),
#  (),
#  (),
#  ('bread',),
#  ('bread',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('substitutions',),
#  (),
#  (),
#  (),
#  ('food-safety',),
#  (),
#  ('tomatoes',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('freezing',),
#  ('oil',),
#  ('bread',),
#  (),
#  (),
#  (),
#  ('baking',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('bread',),
#  (),
#  (),
#  (),
#  (),
#  ('chicken',),
#  (),
#  (),
#  ('bread',),
#  (),
#  (),
#  (),
#  ('baking',),
#  ('baking', 'bread'),
#  (),
#  (),
#  (),
#  ('food-safety',),
#  (),
#  (),
#  (),
#  ('chicken',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('bread',),
#  ('chicken',),
#  (),
#  (),
#  (),
#  ('food-safety',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('microwave',),
#  (),
#  (),
#  ('cake', 'baking'),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('food-safety',),
#  ('substitutions',),
#  ('baking',),
#  (),
#  (),
#  ('food-safety',),
#  (),
#  (),
#  (),
#  (),
#  ('bread',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('baking',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('cake', 'baking'),
#  ('meat',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('bread',),
#  (),
#  ('cake',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('eggs',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('baking',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('coffee',),
#  ('tea',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('cake',),
#  ('baking',),
#  ('salt',),
#  (),
#  (),
#  ('substitutions',),
#  (),
#  ('cake',),
#  (),
#  (),
#  (),
#  (),
#  ('salt',),
#  ('food-safety',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('flour',),
#  (),
#  ('bread',),
#  (),
#  (),
#  (),
#  ('freezing',),
#  (),
#  (),
#  (),
#  (),
#  ('substitutions',),
#  ('chicken',),
#  (),
#  ('freezing',),
#  (),
#  (),
#  ('baking', 'bread'),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('bread',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('chocolate',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('slow-cooking',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('chicken',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('substitutions', 'cookies', 'baking'),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('chicken',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('butter',),
#  ('steak',),
#  (),
#  (),
#  ('eggs',),
#  (),
#  (),
#  ('bread',),
#  ('substitutions',),
#  (),
#  (),
#  (),
#  ('food-safety',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('chicken',),
#  (),
#  ('bread',),
#  ('cake',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('baking',),
#  (),
#  ('pork',),
#  (),
#  ('food-safety',),
#  ('chicken',),
#  (),
#  (),
#  ('coffee',),
#  (),
#  ('chocolate',),
#  ('fish', 'food-safety'),
#  ('chicken',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('chicken',),
#  (),
#  ('chicken', 'food-safety'),
#  (),
#  (),
#  (),
#  (),
#  ('coffee',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('freezing',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('flour', 'bread'),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('oil',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('bread',),
#  (),
#  (),
#  (),
#  (),
#  ('rice',),
#  (),
#  ('chicken',),
#  ('baking',),
#  (),
#  (),
#  ('slow-cooking',),
#  ('bread',),
#  (),
#  (),
#  (),
#  ('eggs',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('food-safety',),
#  ('bread',),
#  (),
#  (),
#  ('pasta',),
#  (),
#  ('dough',),
#  (),
#  (),
#  (),
#  (),
#  ('sugar',),
#  (),
#  (),
#  (),
#  (),
#  ('chicken',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('beans',),
#  ('substitutions',),
#  (),
#  (),
#  (),
#  (),
#  ('substitutions', 'flour'),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('flour',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('cake', 'baking'),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('substitutions',),
#  (),
#  ('cheese',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('chicken',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('cheese',),
#  (),
#  (),
#  (),
#  ('fish',),
#  (),
#  (),
#  ('baking',),
#  (),
#  ('baking',),
#  ('chicken',),
#  ('tea',),
#  (),
#  ('rice',),
#  (),
#  ('pizza',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('cheese',),
#  (),
#  ('pasta',),
#  ('substitutions',),
#  (),
#  (),
#  ('food-safety',),
#  (),
#  (),
#  ('substitutions',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('baking',),
#  (),
#  (),
#  ('food-safety',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('rice',),
#  (),
#  ('coffee',),
#  (),
#  ('tea',),
#  (),
#  ('rice',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('eggs',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('pork',),
#  (),
#  (),
#  (),
#  ('sugar',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('chicken',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('baking',),
#  (),
#  (),
#  ('fish',),
#  ('bread',),
#  ('baking', 'eggs'),
#  (),
#  (),
#  (),
#  (),
#  ('beef',),
#  (),
#  (),
#  (),
#  (),
#  ('substitutions',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('food-safety',),
#  (),
#  (),
#  (),
#  ('bread',),
#  ('sauce',),
#  ('cheese',),
#  (),
#  ('food-safety',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('beef',),
#  (),
#  (),
#  ('baking', 'bread'),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('vegetables',),
#  ('bread',),
#  ('chicken', 'food-safety'),
#  ('substitutions',),
#  ('pasta',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('baking',),
#  ('soup',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('sugar',),
#  (),
#  (),
#  (),
#  ('cake',),
#  (),
#  ('substitutions',),
#  (),
#  (),
#  (),
#  ('eggs',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('substitutions',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('cheese',),
#  (),
#  (),
#  (),
#  (),
#  ('chicken',),
#  (),
#  ('bread',),
#  (),
#  ('pork',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('dough',),
#  (),
#  ('pizza',),
#  (),
#  ('bread',),
#  (),
#  (),
#  ('food-safety',),
#  (),
#  (),
#  (),
#  (),
#  ('grilling',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('baking',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('bread',),
#  ('chicken',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('tea',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('substitutions',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('salt',),
#  ('oil',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('rice',),
#  (),
#  (),
#  (),
#  (),
#  ('bread',),
#  ('rice',),
#  (),
#  (),
#  (),
#  ('cake', 'baking'),
#  (),
#  (),
#  (),
#  ('flour',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('food-safety',),
#  ('substitutions',),
#  ('baking',),
#  (),
#  (),
#  (),
#  ('chicken',),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  (),
#  ('eggs',),
#  (),
#  ('chicken',),
#  (),
#  ('baking',),
#  (),
#  (),
#  (),
#  (),
#  ...]

# %%
# test.head(20)

# %%
pred = []
for i in range(len(y_inv)):
    s = ""
    for j in range(len(y_inv[i])-1):
        s += y_inv[i][j]
        s += "|"
    
    if(len(y_inv[i]) == 0):
        s += "javascript"
    else:
        s += y_inv[i][len(y_inv[i])-1]
    pred.append(s)

# %%
pred
# Out:
# ['javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'php',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'php',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'java',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'android',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  'javascript',
#  ...]

# %%
my_submission = pd.DataFrame({'id': id, 'tags': pred})
my_submission.to_csv('lr_270k.csv', index=False)
