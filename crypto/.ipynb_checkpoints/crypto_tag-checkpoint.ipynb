# %%
import nltk
#nltk.download('stopwords')
from ast import literal_eval
import pandas as pd
import numpy as np
from nltk.corpus import stopwords

# %%
def read_data(filename):
    data = pd.read_csv(filename, sep='\t')
    data['tags'] = data['tags'].apply(literal_eval)
    return data

# %%
tmp = pd.read_csv('crypto.csv')
#train = read_data('cooking.csv')
#validation = read_data('validation.tsv')
#test = pd.read_csv('test.tsv', sep='\t')
tmp
# Out:
#           id                                              title  \
# 0          3  What are the benefits of the two permutation t...
# 1          7  Why use a 1-2 Oblivious Transfer instead of a ...
# 2          8  Why do we append the length of the message in ...
# 3          9  What is the general justification for the hard...
# 4         14  How can I use asymmetric encryption, such as R...
# 5         16          How were the DES S-box values determined?
# 6         17  How to provide secure "vanity" bitcoin address...
# 7         18  How can a random salt for a hash function work...
# 8         20  What are the practical differences between 256...
# 9         24  What makes a hash function good for password h...
# 10        27  How do I apply differential cryptanalysis to a...
# 11        31  Current mathematics theory used in cryptograph...
# 12        32  How can SSL secure a two-way communication wit...
# 13        34                  Necessity of Randomness of Salts?
# 14        36  What are the main weaknesses of a Playfair cip...
# 15        43                           Salting when encrypting?
# 16        47  With sufficient randomness, is XOR an acceptab...
# 17        48  Is it feasible to build a stream cipher from a...
# 18        55  Known methods for constant time (table-free) A...
# 19        59        Taking advantage of one-time pad key reuse?
# 20        66  What are the details of the DES weakness of re...
# 21        70  Protocol to generate Client Certificates at th...
# 22        71    How can I generate large prime numbers for RSA?
# 23        72  Should DES be avoided when developing new syst...
# 24        89  advances in usability for cryptography/authent...
# 25        98                      Replacing the Rijndael S-Box?
# 26       109                          RSA with small exponents?
# 27       116  Is using slow password hashing on the client s...
# 28       123  Are there any tools for expressing the cipher ...
# 29       128           Sites to find crypto intermediate values
# ...      ...                                                ...
# 10402  39704                 Key extraction from Plaintext+CMAC
# 10403  39707  Problems when using PBKDF2 to create an ECDSA ...
# 10404  39710           Does AugPake not require key stretching?
# 10405  39711      How exactly does plaintext become ciphertext?
# 10406  39715  Is it safe to use a SSH server keys for a SSH ...
# 10407  39721  What is the next number of this lottery sequence?
# 10408  39722  Hi.. all! CP-ABE implementation in cloud compu...
# 10409  39725  Same-length plaintext results in predictable c...
# 10410  39726  Is there a Fernet implementation for Java or C...
# 10411  39728      Authenticating a message with HMAC vs AES-CBC
# 10412  39730  Help with terms: hash function and a pseudoran...
# 10413  39731    Does passphrase length impact read-write speed?
# 10414  39735          What's a cryptographic primitive, really?
# 10415  39736  Is there a signature scheme in which private k...
# 10416  39737  How to compare security between S-Box and Addi...
# 10417  39739              Selecting an appropriate key for HMAC
# 10418  39741  In A5/1 stream cipher, why are the specific bi...
# 10419  39742          How effective is Serpent-256 in CTR mode?
# 10420  39743                       PBKDF2WithHmacSHA512 in Java
# 10421  39746        Why standard deviation of BLISS is so high?
# 10422  39750    Surely the best Hash would be one nobody knows?
# 10423  39752  Is it possible to use RSA with AEAD operation ...
# 10424  39753  is it possible to extract a "hint hash" of som...
# 10425  39754  Could someone help me to decipher this? I beli...
# 10426  39757                     RSA - twin primes, two modulus
# 10427  39758     Prevent hash collisions with HMAC secret as IV
# 10428  39759  Can a modified executable file be padded to gi...
# 10429  39761                             Definitions of secrecy
# 10430  39762                                 What is a ratchet?
# 10431  39768          Encrypting 256 bit AES keys with AES ECB?
#
#                                                  content  \
# 0      <p>Why do we use a permutation table in the fi...
# 1      <p>When initiating an <a href="http://en.wikip...
# 2      <p>As we know, <a href="http://en.wikipedia.or...
# 3      <p>Since most cryptographic hash functions are...
# 4      <p>RSA is not designed to be used on long bloc...
# 5      <p>It seems like the S-boxes in <a href="http:...
# 6      <p><a href="http://www.bitcoin.org/" rel="nofo...
# 7      <p>I understand the theory behind the use salt...
# 8      <p>AES has several different variants:</p>\n\n...
# 9      <p>Using a cryptographic hash to store e.g. pa...
# 10     <p>I have read a lot of summaries of block cip...
# 11     <p>What are the mainstream techniques borrowed...
# 12     <p>As I understand it, SSL involved the use of...
# 13     <p>Given the desire to have unique salts for e...
# 14     <p>What are the main weaknesses of a <a href="...
# 15     <p>I was attending a database encryption sessi...
# 16     <p>I have heard criticism of various cryptosys...
# 17     <p>A few years ago I devised a symmetric-key s...
# 18     <p>There are several known methods for impleme...
# 19     <p>Suppose Alice wants to send encryptions (un...
# 20     <p>I think I once faced the recommendation, th...
# 21     <p>A more secure form of 'cookie' could be cre...
# 22     <p>What is the currently industry-standard alg...
# 23     <p>According to wikipedia…</p>\n\n<blockquote>...
# 24     <p>I'm wondering if there have been any recent...
# 25     <p>The Rijndael S-Box design generates a <a hr...
# 26     <p>Just to establish notation with respect to ...
# 27     <p><a href="http://crypto.stackexchange.com/qu...
# 28     <p>The first step In <a href="http://en.citize...
# 29     <p>Does anyone know of any sites where interme...
# ...                                                  ...
# 10402  <p>Can leakage of a plaintext and correspondin...
# 10403  <p>System based on, e.g.:<br>\nPBKDF2, ECDSA a...
# 10404  <p>I was reading the <a href="https://datatrac...
# 10405  <p>I'm having a hard time finding out how Plai...
# 10406  <p>Let me explain my question. I am working on...
# 10407  <p>1469356\n352428\n1413795\n1656764\n347481\n...
# 10408  <p>I want to know how to implement (deploy)  C...
# 10409  <p>I started with a basic mixed-monoalphabetic...
# 10410  <p>I want to encrypt user data and exchange it...
# 10411  <p>Given some string <code>s</code> I want to ...
# 10412  <p>I am a little bit confused about the terms ...
# 10413  <p>I'm using <a href="https://diskcryptor.net/...
# 10414  <p>The more I encounter the term "cryptographi...
# 10415  <p>Normally in a signature system, the private...
# 10416  <p>I'm studying a block cipher based on ARX(Ad...
# 10417  <p>I'm writing a symmetric encryption scheme f...
# 10418  <p>My two part question is:</p>\n\n<p>1) How a...
# 10419  <p>I downloaded a compression program known as...
# 10420  <p>I want to encrypt password with PBKDF2WithH...
# 10421  <p>In lattice based digital signature scheme B...
# 10422  <p>I'm very confused as to why companys use co...
# 10423  <p>Some research shows that RSA is commonly us...
# 10424  <p>I'm a web developer starting to dip into cr...
# 10425  <p>I have a cipher I have been attempting to s...
# 10426  <p>I'm working on this problem. I'm given </p>...
# 10427  <p>Our organistation would like to hash large ...
# 10428  <p>MD5 or SHA1 checksums seem to be the gold s...
# 10429  <p>I found terms like "forward secrecy", "futu...
# 10430  <p>while reading Whatsapp's Security Whitepape...
# 10431  <p>What are the pros/cons of using AES ECB mod...
#
#                                                     tags
# 0                           block-cipher des permutation
# 1      oblivious-transfer multiparty-computation func...
# 2                                             sha-1 hash
# 3                 hash cryptanalysis preimage-resistance
# 4                              encryption rsa public-key
# 5                                 des encryption s-boxes
# 6                        dsa bitcoin digital-cash ripemd
# 7                               hash implementation salt
# 8                   encryption aes block-cipher key-size
# 9                                         hash passwords
# 10      cryptanalysis block-cipher differential-analysis
# 11        coding-theory elliptic-curves hermitian-curves
# 12                        encryption tls public-key keys
# 13                                  hash salt randomness
# 14     cryptanalysis classical-cipher substitution-ci...
# 15                              encryption salt database
# 16                                     xor stream-cipher
# 17            encryption hash block-cipher stream-cipher
# 18     implementation aes side-channel-attack timing-...
# 19                  cryptanalysis one-time-pad key-reuse
# 20                 encryption des modes-of-operation cbc
# 21                        public-key protocol-design tls
# 22                       rsa number-theory prime-numbers
# 23                                                   des
# 24                                        authentication
# 25       encryption aes s-boxes permutation block-cipher
# 26                          cryptanalysis public-key rsa
# 27                        hash passwords protocol-design
# 28                        cryptanalysis algebraic-attack
# 29                     encryption resources test-vectors
# ...                                                  ...
# 10402                             aes cryptanalysis cmac
# 10403  public-key cryptanalysis elliptic-curves authe...
# 10404                           password-hashing augpake
# 10405                      encryption rsa public-key pgp
# 10406                             rsa public-key tls ssh
# 10407                                         randomness
# 10408                                     implementation
# 10409                      symmetric substitution-cipher
# 10410                               encryption symmetric
# 10411                                 signature hmac mac
# 10412       hash hmac pseudo-random-function terminology
# 10413                           key-size disk-encryption
# 10414                       algorithm-design terminology
# 10415                               public-key signature
# 10416                                       block-cipher
# 10417                                       aes keys mac
# 10418                                         encryption
# 10419    encryption symmetric modes-of-operation serpent
# 10420                                               java
# 10421  signature post-quantum-cryptography lattice-cr...
# 10422                                               hash
# 10423                             rsa modes-of-operation
# 10424                                               hash
# 10425                                      cryptanalysis
# 10426                    rsa cryptanalysis prime-numbers
# 10427                     hash hmac collision-resistance
# 10428                                       hash padding
# 10429                    perfect-secrecy forward-secrecy
# 10430                                hash diffie-hellman
# 10431                  encryption aes symmetric key-wrap
#
# [10432 rows x 4 columns]

# %%
test = tmp.tail(431)
train = tmp.head(10431)
validation = tmp.head(11500).tail(1500)

# %%
validation.head()
# Out:
#          id                                              title  \
# 8932  33806  Breaking linear blockcipher - expanding recurs...
# 8933  33808  Finding Private key in RSA with public key, ci...
# 8934  33810  Is WPA2(PKS) AES vulnerable to 4 way hand shak...
# 8935  33812  Is it acceptable to write the nonce to the enc...
# 8936  33813                              homomorpic encryption
#
#                                                 content  \
# 8932  <p>I am trying to break a block cipher that ca...
# 8933  <p>Is there a known 'non-brute force' method o...
# 8934  <p>I can easily crack a WPA TKIP using a dicti...
# 8935  <p>I've used AES-128 in CTR mode in the past a...
# 8936  <p>I am doing project k-nearest neighbor class...
#
#                                                    tags
# 8932                  block-cipher linear-cryptanalysis
# 8933                      encryption rsa public-key pki
# 8934                                           wpa2-psk
# 8935  aes authenticated-encryption initialization-ve...
# 8936                  encryption homomorphic-encryption

# %%
train.head()
# Out:
#    id                                              title  \
# 0   3  What are the benefits of the two permutation t...
# 1   7  Why use a 1-2 Oblivious Transfer instead of a ...
# 2   8  Why do we append the length of the message in ...
# 3   9  What is the general justification for the hard...
# 4  14  How can I use asymmetric encryption, such as R...
#
#                                              content  \
# 0  <p>Why do we use a permutation table in the fi...
# 1  <p>When initiating an <a href="http://en.wikip...
# 2  <p>As we know, <a href="http://en.wikipedia.or...
# 3  <p>Since most cryptographic hash functions are...
# 4  <p>RSA is not designed to be used on long bloc...
#
#                                                 tags
# 0                       block-cipher des permutation
# 1  oblivious-transfer multiparty-computation func...
# 2                                         sha-1 hash
# 3             hash cryptanalysis preimage-resistance
# 4                          encryption rsa public-key

# %%
test.head()
# Out:
#           id                                              title  \
# 10001  37608  Clarification on the origin of `01` in this or...
# 10002  37615  Does Kasisky test for Vigenère cyphers assumpt...
# 10003  37617  SPDZ protocol: how expensive is it to generate...
# 10004  37618                  Questions about SSL3 POODLE Bites
# 10005  37621          AES Key Generation based on database guid
#
#                                                  content  \
# 10001  <p>I have found what I believe to be a straigh...
# 10002  <p>In the notes from which I'm studying I read...
# 10003  <p>I am currently reading the <a href="https:/...
# 10004  <p>I have read some articles or books (e.g., “...
# 10005  <p>I am developing a .NET application spanning...
#
#                                           tags
# 10001               cbc padding padding-oracle
# 10002  cryptanalysis classical-cipher vigenere
# 10003                   multiparty-computation
# 10004                                  tls cbc
# 10005             encryption aes keys database

# %%
X_train, y_train = train['title'].values, train['tags'].values
X_val, y_val = validation['title'].values, validation['tags'].values
X_test = test['title'].values

# %%
y_train[1]
# Out:
# 'oblivious-transfer multiparty-computation function-evaluation'

# %%
import re

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))

def text_prepare(text):
    text = text.lower()
    text = REPLACE_BY_SPACE_RE.sub(' ', text)
    text = BAD_SYMBOLS_RE.sub('', text)
    text = ' '.join(word for word in text.split() if word not in STOPWORDS)
    #print(text)
    return text

# %%
# prepared_questions = []
# for line in open('text_prepare_tests.tsv', encoding='utf-8'):
#     line = text_prepare(line.strip())
#     prepared_questions.append(line)
# text_prepare_results = '\n'.join(prepared_questions)

# %%
X_train = [text_prepare(x) for x in X_train]
X_val = [text_prepare(x) for x in X_val]
X_test = [text_prepare(x) for x in X_test]

# %%
y_train[:3]
# Out:
# array(['block-cipher des permutation',
#        'oblivious-transfer multiparty-computation function-evaluation',
#        'sha-1 hash'], dtype=object)

# %%
from collections import defaultdict
tags_counts = defaultdict(int)
words_counts = defaultdict(int)
tmp=[]

for tags in y_train:
    tt = tags.split()
    tmp.append(tt)
    for tag in tt:
        #print(tag)
        tags_counts[tag] += 1
y_train=tmp
tmp=[]

for text in X_train:
    for word in text.split():
        #print(word)
        words_counts[word] += 1
        
for tags in y_val:
    tt = tags.split()
    tmp.append(tt)
    for tag in tt:
        #print(tag)
        tags_counts[tag] += 1
y_val=tmp
tmp=[]
for text in X_val:
    for word in text.split():
        #print(word)
        words_counts[word] += 1

# %%
most_common_tags = sorted(tags_counts.items(), key=lambda x: x[1], reverse=True)[:10]
most_common_words = sorted(words_counts.items(), key=lambda x: x[1], reverse=True)[:3]

# %%
most_common_words
# Out:
# [('key', 1684), ('encryption', 1200), ('rsa', 848)]

# %%
most_common_tags
# Out:
# [('encryption', 1966),
#  ('hash', 1253),
#  ('rsa', 1208),
#  ('aes', 1026),
#  ('public-key', 919),
#  ('cryptanalysis', 806),
#  ('elliptic-curves', 626),
#  ('signature', 497),
#  ('block-cipher', 469),
#  ('algorithm-design', 416)]

# %%
from scipy import sparse as sp_sparse
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
??TfidVectorizer
# Out:
# Object `TfidVectorizer` not found.

# %%
#X_val

# %%
tfidf_vectorizer = TfidfVectorizer(min_df=5, max_df=0.9, ngram_range=(1, 2),token_pattern='(\S+)')
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_val_tfidf = tfidf_vectorizer.transform(X_val)
X_test_tfidf = tfidf_vectorizer.transform(X_test)
tfidf_vocab = tfidf_vectorizer.vocabulary_
#X_train_tfidf, X_val_tfidf, X_test_tfidf, tfidf_vocab = tfidf_features(X_train, X_val, X_test)

# %%
tfidf_reversed_vocab = {i:word for word,i in tfidf_vocab.items()}

# %%
tfidf_vocab['hash']
# Out:
# 915

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# %%
tags_counts.keys()
# Out:
# dict_keys(['block-cipher', 'des', 'permutation', 'oblivious-transfer', 'multiparty-computation', 'function-evaluation', 'sha-1', 'hash', 'cryptanalysis', 'preimage-resistance', 'encryption', 'rsa', 'public-key', 's-boxes', 'dsa', 'bitcoin', 'digital-cash', 'ripemd', 'implementation', 'salt', 'aes', 'key-size', 'passwords', 'differential-analysis', 'coding-theory', 'elliptic-curves', 'hermitian-curves', 'tls', 'keys', 'randomness', 'classical-cipher', 'substitution-cipher', 'playfair', 'database', 'xor', 'stream-cipher', 'side-channel-attack', 'timing-attack', 'one-time-pad', 'key-reuse', 'modes-of-operation', 'cbc', 'protocol-design', 'number-theory', 'prime-numbers', 'authentication', 'algebraic-attack', 'resources', 'test-vectors', 'random-number-generator', 'statistical-test', 'post-quantum-cryptography', 'mceliece', 'key-derivation', 'bcrypt', 'blowfish', 'signature', 'sha-256', 'entropy', 'discrete-logarithm', 'factorization', 'mac', 'authenticated-encryption', 'elgamal-encryption', 'distinguisher', 'ecb', 'finite-field', 'collision-resistance', 'md5', 'white-box', 'feistel-network', 'provable-security', 'group-theory', 'serpent', 'algorithm-design', 'certificates', 'transposition-cipher', 'hmac', 'birthday-attack', 'enigma', 'crc', 'initialization-vector', 'sha-2', 'key-exchange', 'pairings', 'reference-request', 'pgp', 'index-of-coincidence', 'alternating-step', '3des', 'pohlig-hellman', 'homomorphic-encryption', 'sha-3', 'keccak', 'sponge', 'kerberos', 'history', 'file-encryption', 'camellia', 'brute-force-attack', 'dictionary-attack', 'convergent-encryption', 'known-plaintext-attack', 'format-preserving', 'rc4', 'commitments', 'chosen-plaintext-attack', 'symmetric', 'zero-knowledge-proofs', 'fiat-shamir', 'timed-release', 'ntru', 'elgamal-signature', 'diffie-hellman', 'ciphertext-only-attack', 'backdoors', 'key-escrow', 'schnorr-signature', 'schnorr-identification', 'cryptographic-hardware', 'performance', 'non-repudiation', 'pen-and-paper', 'chosen-ciphertext-attack', 'replay-attack', 'hotp', 'one-time-password', 'host-proof', 'random-oracle-model', 'timestamping', 'scrypt', 'deniable-encryption', 'secret-sharing', '2nd-preimage-resistance', 'xml-encryption', 'rainbow-table', 'one-way-function', 'wpa2-psk', 'key-wrap', 'literature', 'security-definition', 'copy-protection', 'license-key', 'broadcast-encryption', 'semantic-security', 'anonymity', 'blind-signature', 'commutative-encryption', 'challenge-response', 'password-based-encryption', 'integrity', 'ctr', 'padding', 'merkle-damgaard', 'malleability', 'hashed-elgamal', 'meet-in-the-middle-attack', 'shamir-secret-sharing', 'pbkdf-2', 'disk-encryption', 'compression', 'asn.1', 'lightweight', 'pseudo-random-function', 'twofish', 'key-check-value', 'srp', 'hill-cipher', 'terminology', 'protocol-analysis', 'sha-3-competition', 'complexity', 'paillier', 'hash-tree', 'order-preserving', 'pseudo-random-generator', 'salsa20', 'secure-index', 'proof-of-work', 'forgery', 'gcm', 'md4', 'eax', 'openssl', 'biclique-attack', 'length-extension', 'rijndael', 'ofb', 'vigenere', 'notation', 'hash-signature', 'lfsr', 'quantum-cryptography', 'linear-cryptanalysis', 'tea', 'blum-blum-shub', 'tweakable-cipher', 'miyaguchi-preneel', 'three-pass-protocol', 'searchable-encryption', 'standards', 'fips-140', 'voting', 'pki', 'cfb', 'sstp', 'affine-cipher', 'ed25519', 'forward-secrecy', 'key-rotation', 'secure-storage', 'ssh', 'padding-oracle', 'skein', 's-des', 'steganography', 'mental-poker', 'idea', 'arithmetic', 'matrix-multiplication', 'cbc-mac', 'cryptdb', 'sha-512', 'montgomery-multiplication', 'hkdf', 'multi-prime-rsa', 'nist', 'voip', 'decryption-oracle', 'xts', 'ocb', 'feal', 'lattice-crypto', 'predicate-encryption', 'functional-encryption', 'identity-based-encryption', 'software-obfuscation', 'fortuna', 'abe', 'monotone-access-structure', 'modular-arithmetic', 'blinding', 'knapsack', 'transport-security', 'threefish', 'multiple-encryption', 'truecrypt', 'ccm', 'nonce', 'java', 'pol ...

# %%
y_val
# Out:
# [['block-cipher', 'linear-cryptanalysis'],
#  ['encryption', 'rsa', 'public-key', 'pki'],
#  ['wpa2-psk'],
#  ['aes', 'authenticated-encryption', 'initialization-vector', 'gcm', 'nonce'],
#  ['encryption', 'homomorphic-encryption'],
#  ['rsa', 'elliptic-curves', 'diffie-hellman'],
#  ['one-time-pad', 'xor'],
#  ['sha-256', 'bitcoin', 'ripemd'],
#  ['hash', 'passwords', 'padding', 'sha-512'],
#  ['number-theory', 'finite-field', 'quadratic-residuosity'],
#  ['encryption', 'aes', 'javascript'],
#  ['algorithm-design'],
#  ['aes', 's-boxes'],
#  ['rsa', 'signature', 'md5'],
#  ['rsa'],
#  ['rsa', 'padding'],
#  ['aes', 'keys', 'symmetric', 'passwords'],
#  ['rsa', 'finite-field'],
#  ['aes', 'ctr'],
#  ['cryptanalysis',
#   'classical-cipher',
#   'substitution-cipher',
#   'vigenere',
#   'multiple-encryption'],
#  ['diffie-hellman', 'tls', 'key-exchange'],
#  ['key-derivation', 'sha-3', 'memory-hard', 'password-hashing'],
#  ['encryption', 'hash', 'public-key', 'signature'],
#  ['hash', 'sha-256', 'sha-2'],
#  ['random-number-generator'],
#  ['aes', 'gcm', 'libsodium'],
#  ['rsa'],
#  ['protocol-design', 'authentication', 'certificates'],
#  ['diffie-hellman', 'key-exchange', 'logjam'],
#  ['sha-256', 'sha-2'],
#  ['cbc', 'padding', 'ecb', 'cfb'],
#  ['hash', 'sha-1'],
#  ['rsa', '3des', 'encoding', 'pkcs11', 'key-wrap'],
#  ['diffie-hellman', 'prime-numbers'],
#  ['encryption', 'homomorphic-encryption'],
#  ['encryption', 'rsa', 'key-exchange', 'nist', 'oaep'],
#  ['mac', 'sha-256', 'xor'],
#  ['encryption', 'public-key', 'signature', 'authenticated-encryption'],
#  ['encryption', 'homomorphic-encryption'],
#  ['untagged'],
#  ['encryption', 'signature', 'mac', 'authenticated-encryption'],
#  ['rsa', 'padding', 'padding-oracle'],
#  ['random-number-generator'],
#  ['randomness'],
#  ['public-key'],
#  ['aes', 'keys'],
#  ['hash', 'attack'],
#  ['hash', 'cryptanalysis', 'rainbow-table'],
#  ['cryptanalysis'],
#  ['block-cipher', 'algorithm-design', 'modes-of-operation'],
#  ['sha-256'],
#  ['ecies'],
#  ['cryptanalysis', 'entropy', 'classical-cipher'],
#  ['tls', 'cbc', 'padding'],
#  ['aes', 'hmac', 'cbc', 'cbc-mac'],
#  ['hmac', 'authenticated-encryption'],
#  ['block-cipher', 'avalanche'],
#  ['reference-request'],
#  ['homomorphic-encryption'],
#  ['signature'],
#  ['nonce', 'salsa20', 'chacha', 'xsalsa20'],
#  ['sha-1'],
#  ['discrete-logarithm'],
#  ['encryption'],
#  ['rsa', 'cryptanalysis', 'side-channel-attack'],
#  ['authentication'],
#  ['hash'],
#  ['sha-256', 'randomness'],
#  ['key-schedule'],
#  ['ntru'],
#  ['chacha', 'arx'],
#  ['diffie-hellman'],
#  ['encryption', 'algorithm-design', 'homomorphic-encryption', 'arithmetic'],
#  ['protocol-design', 'hmac'],
#  ['one-time-pad', 'key-reuse'],
#  ['stream-cipher', 'known-plaintext-attack'],
#  ['algorithm-design', 'known-plaintext-attack', 'attack'],
#  ['security-definition', 'semantic-security'],
#  ['encryption', 'ctr', 'file-encryption'],
#  ['multiparty-computation', 'perfect-secrecy'],
#  ['algorithm-design', 'crc'],
#  ['encryption', 'aes'],
#  ['implementation', 'randomness'],
#  ['des', 's-boxes'],
#  ['format-preserving', 'lightweight'],
#  ['diffie-hellman', 'certificates'],
#  ['modular-arithmetic', 'finite-field'],
#  ['public-key',
#   'diffie-hellman',
#   'elgamal-encryption',
#   'chosen-plaintext-attack'],
#  ['provable-security', 'distinguisher'],
#  ['elliptic-curves'],
#  ['encryption', 'signature', 'mac', 'authenticated-encryption'],
#  ['rsa', 'chosen-ciphertext-attack'],
#  ['keys', 'hmac'],
#  ['rsa', 'random-number-generator', 'key-derivation', 'padding'],
#  ['encryption', 'public-key', 'host-proof', 'key-recovery'],
#  ['encryption', 'cryptanalysis', 'signature'],
#  ['block-cipher', 'modes-of-operation', 'classical-cipher'],
#  ['encryption', 'keys', 'provable-security', 'perfect-secrecy'],
#  ['elgamal-signature'],
#  ['lattice-crypto'],
#  ['identity-based-encryption'],
#  ['encryption', 'cryptanalysis', 'homomorphic-encryption'],
#  ['algorithm-design', 'modular-arithmetic', 'factorization', 'group-theory'],
#  ['identity-based-encryption'],
#  ['provable-security'],
#  ['encryption', 'smartcard'],
#  ['multiparty-computation', 'perfect-secrecy'],
#  ['encryption',
#   'one-time-pad',
#   'chosen-plaintext-attack',
#   'chosen-ciphertext-attack'],
#  ['authenticated-encryption', 'ctr', 'cbc-mac', 'speck'],
#  ['aes', 'public-key'],
#  ['encryption'],
#  ['signature', 'provable-security', 'random-oracle-model'],
#  ['hash'],
#  ['random-number-generator'],
#  ['hash', 'symmetric', 'hmac', 'mac'],
#  ['algorithm-design', 'stream-cipher', 'chacha', 'blake2'],
#  ['hash', 'sha-3'],
#  ['passwords',
#   'brute-force-attack',
#   'secret-sharing',
#   'shamir-secret-sharing'],
#  ['protocol-design', 'voting', 'garbled-circuits'],
#  ['protocol-design', 'notation'],
#  ['rc4'],
#  ['keys', 'symmetric'],
#  ['rsa'],
#  ['identity-based-encryption'],
#  ['encryption', 'public-key', 'signature', 'key-derivation'],
#  ['modes-of-operation'],
#  ['encryption', 'rsa'],
#  ['aes', 'homomorphic-encryption'],
#  ['hash', 'collision-resistance', 'pseudo-random-function'],
#  ['encryption', 'hash', 'passwords', 'truecrypt'],
#  ['signature', 'hash-signature'],
#  ['encryption', 'cryptanalysis', 'key-derivation'],
#  ['provable-security', 'distinguisher', 'pseudo-random-generator'],
#  ['signature', 'keys'],
#  ['encryption', 'rsa', 'keys'],
#  ['stream-cipher'],
#  ['sha-256', 'brute-force-attack', 'rainbow-table'],
#  ['hash', 'merkle-damgaard'],
#  ['passwords', 'password-based-encryption'],
#  ['signature',
#   'provable-security',
#   'discrete-logarithm',
#   'dsa',
#   'random-oracle-model'],
#  ['encryption', 'cryptanalysis'],
#  ['diffie-hellman', 'elliptic-curves'],
#  ['encryption', 'database'],
#  ['key-exchange'],
#  ['reference-request', 'discrete-logarithm', 'group-theory'],
#  ['encryption',
#   'rsa',
#   'public-key',
#   'cryptanalysis',
#   'chosen-ciphertext-attack'],
#  ['elliptic-curves', 'tls', 'key-reuse', 'challenge-response'],
#  ['encryption', 'hash-signature'],
#  ['aes', 'terminology', 'rijndael'],
#  ['homomorphic-encryption', 'zero-knowledge-proofs', 'voting'],
#  ['encryption', 'block-cipher', 'modes-of-operation'],
#  ['encryption'],
#  ['des', 'history'],
#  ['random-number-generator',
#   'reference-request',
#   'multiparty-computation',
#   'perfect-secrecy'],
#  ['quantum-cryptography'],
#  ['modular-arithmetic', 'elgamal-encryption', 'safe-prime'],
#  ['block-cipher', 'keys', 'brute-force-attack', 'ecb'],
#  ['modular-arithmetic', 'finite-field'],
#  ['finite-field'],
#  ['hash', 'collision-resistance', 'pseudo-random-permutation', 'literature'],
#  ['post-quantum-cryptography'],
#  ['cryptanalysis', 'factorization'],
#  ['rsa', 'key-size'],
#  ['playfair'],
#  ['encryption', 'authentication', 'smartcard'],
#  ['rsa', 'public-key', 'tls', 'openssl'],
#  ['encryption', 'substitution-cipher'],
#  ['encryption', 'cryptanalysis', 'implementation'],
#  ['encryption', 'modular-arithmetic', 'perfect-secrecy'],
#  ['encryption', 'entropy', 'perfect-secrecy'],
#  ['encryption'],
#  ['encryption'],
#  ['hash', 'reference-request', 'collision-resistance', 'length-extension'],
#  ['rsa', 'aes', 'authentication'],
#  ['encryption', 'homomorphic-encryption'],
#  ['elliptic-curves',
#   'discrete-logarithm',
#   'pairings',
#   'identity-based-encryption'],
#  ['aes', 'cryptanalysis', 'side-channel-attack', 'dpa'],
#  ['hash', 'cryptanalysis', 'avalanche'],
#  ['symmetric', 'terminology'],
#  ['homomorphic-encryption'],
#  ['classical-cipher', 'vigenere'],
#  ['modes-of-operation', 'ecb'],
#  ['authenticated-encryption', 'disk-encryption', 'xts'],
#  ['random-number-generator', 'statistical-test'],
#  ['encryption', 'symmetric', 'cbc', 'initialization-vector'],
#  ['encryption', 'key-rotation'],
#  ['public-key', 'mac'],
#  ['encryption', 'database', 'data-privacy', 'secure-storage'],
#  ['encryption', 'hash', 'md5', 'coding-theory'],
#  ['hardness-assumptions'],
#  ['protocol-design', 'protocol-analysis'],
#  ['provable-security', 'verifiability'],
#  ['encryption',
#   'random-number-generator',
#   'pseudo-random-function',
#   'pseudo-random-generator'],
#  ['encryption', 'public-key'],
#  ['public-key', 'key-exchange'],
#  ['rsa', 'key-size'],
#  ['hash', 'sha-3'],
#  ['secret-sharing', 'shamir-secret-sharing', 'threshold-cryptography'],
#  ['diffie-hellman', 'authentication'],
#  ['rsa', 'modular-arithmetic'],
#  ['implementation', 'key-size', 'standards'],
#  ['hash', 'stream-cipher'],
#  ['rsa', 'diffie-hellman', 'one-time-pad'],
#  ['hash', 'implementation', 'openssl'],
#  ['random-number-generator', 'pseudo-random-generator', 'key-rotation'],
#  ['stream-cipher',
#   'chosen-plaintext-attack',
#   'factorization',
#   'hardness-assumptions'],
#  ['encryption', 'randomness'],
#  ['encryption', 'aes', 's-boxes', 'rijndael'],
#  ['encryption', 'algorithm-design'],
#  ['encryption', 'rc6'],
#  ['encryption', 'classical-cipher'],
#  ['aes', 'chacha', 'norx', 'keyak'],
#  ['authenticated-encryption'],
#  ['aes', 'block-cipher', 'stream-cipher', 'modes-of-operation', 'chacha'],
#  ['encryption', 'stream-cipher', 'cbc', 'xor'],
#  ['homomorphic-encryption'],
#  ['statistical-test', 'avalanche'],
#  ['post-quantum-cryptography', 'mceliece', 'niederreiter'],
#  ['aes', 'hmac'],
#  ['rsa', 'provable-security', 'oaep'],
#  ['pir'],
#  ['aes', 'cryptographic-hardware', 'performance'],
#  ['encryption', 'cryptanalysis', 'brute-force-attack'],
#  ['post-quantum-cryptography', 'lattice-crypto'],
#  ['tls', 'key-derivation'],
#  ['rsa'],
#  ['multiparty-computation', 'security-definition'],
#  ['aes', 'sha-256'],
#  ['block-cipher', 'key-size', 'blocksize'],
#  ['education'],
#  ['encryption', 'hash', 'rsa', 'public-key', 'bitcoin'],
#  ['lattice-crypto'],
#  ['rsa', 'public-key'],
#  ['random-number-generator', 'pseudo-random-function'],
#  ['hash', 'rainbow-table'],
#  ['elliptic-curves',
#   'tls',
#   'post-quantum-cryptography',
#   'quantum-cryptography'],
#  ['random-number-generator',
#   'pseudo-random-function',
#   'pseudo-random-generator'],
#  ['encryption', 'aes', 'brute-force-attack'],
#  ['aes', 'cbc', 'disk-encryption'],
#  ['rsa', 'aes', 'finite-field', 'schnorr-signature'],
#  ['hash', 'implementation'],
#  ['hash', 'md5', 'length-extension'],
#  ['hash', 'diffie-hellman', 'passwords', 'password-hashing'],
#  ['hmac', 'preimage-resistance'],
#  ['lattice-crypto'],
#  ['public-key', 'signature'],
#  ['encryption'],
#  ['aes', 'chacha', 'poly1305'],
#  ['authenticated-encryption',
#   'cbc',
#   'chosen-ciphertext-attack',
#   'key-reuse',
#   'cbc-mac'],
#  ['algorithm-design'],
#  ['authenticated-encryption', 'modes-of-operation'],
#  ['tls'],
#  ['rsa'],
#  ['authentication', 'protocol-analysis'],
#  ['chacha', 'poly1305', 'libsodium'],
#  ['aes', 'algorithm-design', 'permutation', 'differential-analysis'],
#  ['aes', 'keys', 's-boxes'],
#  ['symmetric', 'non-repudiation'],
#  ['hash', 'passwords', 'salt', 'password-hashing'],
#  ['rsa', 'elliptic-curves', 'dsa', 'certificates'],
#  ['attack'],
#  ['rc4'],
#  ['aes', 'random-number-generator', 'nonce'],
#  ['encryption', 'aes', 'key-recovery'],
#  ['encryption'],
#  ['hash', 'notation', 'certificateless-crypto'],
#  ['discrete-logarithm', 'protocol-analysis'],
#  ['hash'],
#  ['hash', 'finite-field', 'preimage-resistance'],
#  ['homomorphic-encryption', 'order-preserving'],
#  ['encoding'],
#  ['aes'],
#  ['aes', 'authenticated-encryption', 'modes-of-operation', 'gcm', 'ocb'],
#  ['keys', 'substitution-cipher'],
#  ['cryptanalysis', 'block-cipher', 'known-plaintext-attack', 'attack'],
#  ['secret-sharing', 'commitments'],
#  ['sha-1'],
#  ['elgamal-encryption'],
#  ['rsa', 'algorithm-design', 'congruence'],
#  ['homomorphic-encryption', 'security-definition'],
#  ['brute-force-attack', 'post-quantum-cryptography'],
#  ['hash', 'passwords', 'salt'],
#  ['rsa'],
#  ['provable-security', 'chosen-ciphertext-attack'],
#  ['elliptic-curves', 'dsa', 'openssl'],
#  ['symmetric', 'secret-sharing', 'complexity', 'multiple-encryption'],
#  ['elliptic-curves', 'discrete-logarithm', 'dsa', 'side-channel-attack'],
#  ['threefish'],
#  ['randomness'],
#  ['homomorphic-encryption',
#   'secret-sharing',
#   'multiparty-computation',
#   'shamir-secret-sharing'],
#  ['rsa', 'signature', 'rsa-pss'],
#  ['rsa', 'signature', 'openssl', 'pkcs11'],
#  ['encryption', 'wpa2-psk'],
#  ['symmetric', 'file-encryption', 'disk-encryption'],
#  ['elliptic-curves', 'elliptic-curve-generation'],
#  ['substitution-cipher', 'ciphertext-only-attack', 'affine-cipher'],
#  ['encryption', 'brute-force-attack'],
#  ['notation'],
#  ['aes', 'performance'],
#  ['sha-1', 'java'],
#  ['encryption', 'format-preserving'],
#  ['homomorphic-encryption'],
#  ['aes', 'block-cipher', 'password-based-encryption'],
#  ['hash', 'collision-resistance', 'preimage-resistance'],
#  ['homomorphic-encryption', 'voting'],
#  ['rsa', 'aes', 'elliptic-curves', 'dsa', 'chosen-ciphertext-attack'],
#  ['randomness', 'deniable-encryption'],
#  ['aes', 'mac', 'cbc', 'modes-of-operation', 'cbc-mac'],
#  ['homomorphic-encryption',
#   'provable-security',
#   'semantic-security',
#   'hardness-assumptions'],
#  ['aes', 'homomorphic-encryption', 'java'],
#  ['hash', 'symmetric', 'key-derivation', 'pbkdf'],
#  ['file-encryption', 'hotp'],
#  ['stream-cipher', 'lfsr'],
#  ['hash'],
#  ['elliptic-curves', 'pollard-rho'],
#  ['file-encryption'],
#  ['finite-field', 'identity-based-encryption', 'notation', 'prime-field'],
#  ['protocol-design', 'zero-knowledge-proofs'],
#  ['cryptanalysis', 'stream-cipher'],
#  ['stream-cipher',
#   'authenticated-encryption',
#   'cryptographic-hardware',
#   'lfsr'],
#  ['public-key', 'signature', 'algorithm-design', 'authenticated-encryption'],
#  ['chosen-plaintext-attack',
#   'one-way-function',
#   'permutation',
#   'random-oracle-model'],
#  ['encryption'],
#  ['protocol-design', 'oblivious-transfer'],
#  ['provable-security', 'hardness-assumptions'],
#  ['key-derivation', 'salt', 'pbkdf-2'],
#  ['md5', 'salt'],
#  ['format-preserving', 'pseudo-random-permutation'],
#  ['initialization-vector', 'rc4'],
#  ['software-obfuscation'],
#  ['factorization'],
#  ['rsa', 'prime-numbers', 'rainbow-table'],
#  ['block-cipher', 'random-number-generator'],
#  ['public-key', 'elliptic-curves', 'elliptic-curve-generation'],
#  ['public-key', 'identity-based-encryption', 'voting'],
#  ['diffie-hellman', 'tls', 'sha-1', 'sha-2'],
#  ['homomorphic-encryption', 'security-definition'],
#  ['block-cipher', 'cbc', 'chosen-plaintext-attack'],
#  ['signature', 'traitor-tracing'],
#  ['chosen-ciphertext-attack', 'security-definition'],
#  ['reference-request', 'entropy', 'history', 'enigma'],
#  ['random-number-generator', 'keys', 'entropy'],
#  ['aes', 'sha-1', 'pbkdf-2'],
#  ['hash', 'collision-resistance', 'one-way-function'],
#  ['encryption', 'reference-request', 'zero-knowledge-proofs'],
#  ['adversarial-model'],
#  ['encryption', 'keys', 'key-exchange', 'key-derivation'],
#  ['siphash'],
#  ['secret-sharing', 'visual-cryptography'],
#  ['keys', 'key-derivation'],
#  ['aes', 'hmac', 'key-derivation', 'sha-1', 'pbkdf-2'],
#  ['identity-based-encryption'],
#  ['terminology', 'nonce', 'bitcoin'],
#  ['rsa', 'one-way-function', 'trapdoor'],
#  ['discrete-logarithm', 'number-theory'],
#  ['encryption', 'homomorphic-encryption'],
#  ['aes', 'gcm'],
#  ['public-key', 'key-derivation', 'libsodium'],
#  ['diffie-hellman', 'authentication', 'man-in-the-middle'],
#  ['aes', 'block-cipher', 'performance', 'rijndael'],
#  ['aes', 'hmac', 'cbc', 'gcm'],
#  ['tls', 'openssl'],
#  ['timing-attack'],
#  ['implementation', 'tls', 'standards'],
#  ['cryptanalysis', 'file-encryption'],
#  ['zero-knowledge-proofs'],
#  ['keys', 'symmetric', 'file-encryption'],
#  ['passwords', 'key-exchange', 'security-definition'],
#  ['factorization'],
#  ['encryption', 'discrete-logarithm'],
#  ['encryption'],
#  ['public-key', 'elliptic-curves'],
#  ['symmetric', 'salsa20', 'chacha'],
#  ['elliptic-curves',
#   'reference-request',
#   'elgamal-encryption',
#   'attack',
#   'elgamal-signature'],
#  ['authenticated-encryption', 'performance', 'norx', 'keyak'],
#  ['backdoors', 'multi-prime-rsa'],
#  ['hash', 'signature'],
#  ['encryption', 'key-derivation', '3des'],
#  ['hash', 'rsa', 'aes', 'key-derivation', 'sha-256'],
#  ['hash'],
#  ['key-derivation'],
#  ['secure-storage', 'oblivious-ram'],
#  ['cryptanalysis', 'sha-256', 'length-extension'],
#  ['authenticated-encryption'],
#  ['hash', 'signature', 'integrity', 'transport-security'],
#  ['notation'],
#  ['hash', 'collision-resistance'],
#  ['rsa'],
#  ['keys', 'stream-cipher', 'alternating-step'],
#  ['rsa'],
#  ['encryption', 'key-recovery', 'ransomware'],
#  ['reference-request',
#   'secret-sharing',
#   'multiparty-computation',
#   'shamir-secret-sharing'],
#  ['hash', 'collision-resistance', 'birthday-attack'],
#  ['symmetric', 'lfsr'],
#  ['shamir-secret-sharing'],
#  ['encryption', 'searchable-encryption'],
#  ['cryptographic-hardware'],
#  ['homomorphic-encryption'],
#  ['encryption', 'hash', 'mac'],
#  ['hash', 'collision-resistance', 'birthday-attack'],
#  ['public-key', 'authentication', 'tls'],
#  ['hash',
#   'post-quantum-cryptography',
#   'one-way-function',
#   'hash-signature',
#   'key-size'],
#  ['passwords'],
#  ['hash'],
#  ['rsa', 'factorization'],
#  ['encryption'],
#  ['elliptic-curves', 'standards', 'schnorr-signature'],
#  ['hmac', 'sha-256'],
#  ['key-derivation'],
#  ['provable-security', 'complexity'],
#  ['aes', 'hmac', 'cbc-mac'],
#  ['reference-request', 'functional-encryption'],
#  ['encryption', 'rsa', 'aes', 'padding'],
#  ['elliptic-curves', 'pki', 'smartcard'],
#  ['dsa'],
#  ['random-number-generator', 'pseudo-random-generator', 'distinguisher'],
#  ['aes', 'password-based-encryption'],
#  ['kem'],
#  ['cbc', 'modes-of-operation', 'ctr'],
#  ['cbc'],
#  ['post-quantum-cryptography', 'factorization', 'group-theory'],
#  ['cryptanalysis'],
#  ['encryption'],
#  ['cryptanalysis', 'elliptic-curves'],
#  ['protocol-analysis'],
#  ['encryption', 'aes', 'otr'],
#  ['encryption', 'aes', 'pgp', 'file-encryption'],
#  ['blake2'],
#  ['aes', 'ctr'],
#  ['aes'],
#  ['encryption'],
#  ['hash', 'collision-resistance'],
#  ['homomorphic-encryption'],
#  ['rsa'],
#  ['aes', 'symmetric', 'twofish', 'camellia'],
#  ['algorithm-design', 'arx'],
#  ['rc4', 'wpa2-psk'],
#  ['rsa', 'public-key'],
#  ['modular-arithmetic'],
#  ['signature', 'hash-tree'],
#  ['diffie-hellman', 'elgamal-encryption'],
#  ['hash'],
#  ['rsa', 'cryptanalysis', 'attack'],
#  ['encryption',
#   'cryptanalysis',
#   'cbc',
#   'one-time-pad',
#   'chosen-ciphertext-attack'],
#  ['cryptanalysis', 'pseudo-random-generator', 'distinguisher'],
#  ['hash'],
#  ['encryption'],
#  ['hash', 'rsa', 'signature', 'sha-1'],
#  ['rsa'],
#  ['dsa'],
#  ['rsa'],
#  ['aes', 'block-cipher', 'deoxys'],
#  ['homomorphic-encryption'],
#  ['oblivious-transfer'],
#  ['hash', 'password-hashing'],
#  ['encryption', 'aes', 'cbc', 'attack'],
#  ['stream-cipher',
#   'pseudo-random-generator',
#   'terminology',
#   'random-number-generator'],
#  ['reference-request', 'history'],
#  ['gcm'],
#  ['hash', 'hmac', 'mac'],
#  ['pairings', 'abe'],
#  ['aes', 'algorithm-design', 'random-number-generator'],
#  ['pairings'],
#  ['hash',
#   'collision-resistance',
#   'key-derivation',
#   'key-size',
#   'preimage-resistance'],
#  ['encryption', 'des', 'attack', '3des', 'meet-in-the-middle-attack'],
#  ['block-cipher', 'des'],
#  ['elliptic-curves', 'reference-request', 'group-theory'],
#  ['elliptic-curves', 'pairings'],
#  ['block-cipher', 'provable-security', 'security-definition'],
#  ['reference-request', 'initialization-vector', 'sha-2', 'constants'],
#  ['tls'],
#  ['protocol-design', 'oblivious-transfer'],
#  ['cryptanalysis', 'salsa20'],
#  ['encryption'],
#  ['random-number-generator', 'one-time-pad'],
#  ['implementation', 's-boxes', 'bitslicing'],
#  ['encryption', 'key-rotation'],
#  ['tls', 'pseudo-random-function'],
#  ['universal-hash'],
#  ['authenticated-encryption', 'nonce', 'hs1-siv'],
#  ['encryption'],
#  ['elliptic-curves'],
#  ['encryption', 'hash-signature', 'bitcoin'],
#  ['pseudo-random-function', 'statistical-test'],
#  ['rsa', 'compression'],
#  ['mac', 'pseudo-random-function'],
#  ['protocol-design', 'homomorphic-encryption', 'semantic-security'],
#  ['passwords', 'password-hashing'],
#  ['matrix-multiplication'],
#  ['rsa', 'public-key', 'authentication'],
#  ['rsa', 'aes', 'public-key'],
#  ['reference-request', 'passwords', 'dictionary-attack'],
#  ['hash', 'mac', 'collision-resistance', 'siphash'],
#  ['encryption', 'rsa', 'key-generation'],
#  ['rsa',
#   'modular-arithmetic',
#   'factorization',
#   'rabin-cryptosystem',
#   'quadratic-residuosity'],
#  ['public-key', 'ssh', 'pkcs8'],
#  ['encryption', 'hmac', 'sha-1'],
#  ['aes', 'sha-256', 'chacha', 'fortuna', 'blake2b'],
#  ['multiparty-computation'],
#  ['encryption', 'hash', 'symmetric'],
#  ['algorithm-design', 'passwords'],
#  ['aes', 'cryptanalysis', 'keys'],
#  ['cryptanalysis', 'hmac', 'sha-3'],
#  ['post-quantum-cryptography', 'quantum-cryptography'],
#  ['aes', 'ctr', 'known-plaintext-attack', 'padding-oracle'],
#  ['aes',
#   'implementation',
#   'side-channel-attack',
#   'mixing-function',
#   'bitslicing'],
#  ['rsa'],
#  ['rsa', 'elliptic-curves', 'post-quantum-cryptography', 'ed25519'],
#  ['multiparty-computation', 'garbled-circuits'],
#  ['rsa'],
#  ['encryption', 'chosen-plaintext-attack', 'chosen-ciphertext-attack'],
#  ['provable-security',
#   'multiparty-computation',
#   'security-definition',
#   'perfect-secrecy'],
#  ['homomorphic-encryption'],
#  ['tls'],
#  ['tls', 'attack'],
#  ['diffie-hellman', 'java'],
#  ['chosen-plaintext-attack',
#   'chosen-ciphertext-attack',
#   'integrity',
#   'pseudo-random-permutation'],
#  ['hash', 'collision-resistance'],
#  ['rsa', 'aes', 'standards'],
#  ['encryption'],
#  ['multiparty-computation', 'garbled-circuits'],
#  ['hash'],
#  ['tls'],
#  ['encryption', 'aes', 'cryptanalysis'],
#  ['encryption', 'rsa'],
#  ['keys', 'key-derivation', 'cmac'],
#  ['zero-knowledge-proofs'],
#  ['secret-sharing', 'multiparty-computation'],
#  ['one-time-pad', 'xor'],
#  ['public-key', 'diffie-hellman', 'prime-numbers', 'nist', 'standards'],
#  ['reference-request', 'pseudo-random-function'],
#  ['hash', 'collision-resistance', 'sha-256', 'md5'],
#  ['encryption', 'hmac'],
#  ['multiparty-computation', 'searchable-encryption', 'pir', 'oblivious-ram'],
#  ['rsa', 'modular-arithmetic'],
#  ['encryption', 'authenticated-encryption', 'protocol-analysis'],
#  ['oblivious-transfer', 'access-control'],
#  ['public-key',
#   'protocol-design',
#   'provable-security',
#   'zero-knowledge-proofs'],
#  ['aes', 'block-cipher', 'twofish'],
#  ['tls', 'attack'],
#  ['aes', 'implementation', 'rijndael', 'matrix-multiplication', 'bitslicing'],
#  ['tls', 'transport-security'],
#  ['cryptanalysis', 'side-channel-attack', 'dpa'],
#  ['aes', 'symmetric', 'ctr'],
#  ['modular-arithmetic'],
#  ['encryption', 'hash', 'sha-256', 'hash-signature', 'key-rotation'],
#  ['implementation', 'srp'],
#  ['encryption', 'hash', 'elliptic-curves'],
#  ['encryption', 'cryptanalysis', 'pseudo-random-generator', 'distinguisher'],
#  ['implementation', 'prime-numbers'],
#  ['cryptanalysis', 'substitution-cipher', 'vigenere', 'frequency-analysis'],
#  ['signature', 'hash-signature'],
#  ['encryption', 'aes', 'ctr'],
#  ['mac', 'carter-wegman'],
#  ['rsa', 'signature', 'sha-1', 'forgery'],
#  ['encryption', 'data-privacy'],
#  ['s-boxes', 'feistel-network'],
#  ['one-time-pad', 'classical-cipher'],
#  ['provable-security', 'abe'],
#  ['cryptanalysis', 'block-cipher', 'blocksize', 'birthday-attack'],
#  ['elliptic-curves', 'modular-arithmetic', 'ed25519'],
#  ['block-cipher', 'algorithm-design', 'key-schedule'],
#  ['rsa', 'modular-arithmetic', 'decryption-oracle'],
#  ['random-number-generator'],
#  ['zero-knowledge-proofs'],
#  ['garbled-circuits'],
#  ['rsa', 'public-key'],
#  ['discrete-logarithm'],
#  ['pbkdf-2', 'sha-2'],
#  ['signature', 'number-theory', 'rabin-cryptosystem', 'quadratic-residuosity'],
#  ['encryption', 'elliptic-curves', 'implementation', 'pairings'],
#  ['initialization-vector', 'key-reuse'],
#  ['protocol-design', 'reference-request', 'mac', 'standards'],
#  ['rsa', 'prime-numbers', 'number-theory'],
#  ['hash', 'md5'],
#  ['elliptic-curves', 'salsa20', 'chacha', 'xsalsa20', 'x25519'],
#  ['timing-attack', 'isaac'],
#  ['stream-cipher', '3des'],
#  ['public-key', 'functional-encryption'],
#  ['encryption', 'keys'],
#  ['encryption', 'semantic-security'],
#  ['hash', 'one-time-pad', 'randomness'],
#  ['encryption', 'aes', 'cbc', 'initialization-vector'],
#  ['authenticated-encryption', 'cbc', 'ctr'],
#  ['aes', 'key-exchange'],
#  ['public-key', 'pgp'],
#  ['encryption', 'one-time-pad', 'modular-arithmetic', 'perfect-secrecy'],
#  ['encryption', 'aes', 'gcm'],
#  ['authenticated-encryption'],
#  ['cryptanalysis', 'xor', 'vigenere'],
#  ['encryption'],
#  ['aes', 'cbc', 'initialization-vector', 'lightweight'],
#  ['vigenere'],
#  ['rsa', 'public-key', 'passwords', 'xor', 'password-based-encryption'],
#  ['aes', 'avalanche'],
#  ['aes', 'homomorphic-encryption', 'side-channel-attack', 'simon', 'speck'],
#  ['aes'],
#  ['public-key', 'discrete-logarithm', 'modular-arithmetic'],
#  ['public-key', 'chosen-plaintext-attack', 'chosen-ciphertext-attack'],
#  ['encryption', 'aes', 'initialization-vector', 'attack'],
#  ['rsa'],
#  ['aes', 'authentication', 'key-derivation', 'gcm', 'pbkdf-2'],
#  ['hash', 'pbkdf-2', 'bcrypt', 'password-hashing', 'memory-hard'],
#  ['block-cipher', 'feistel-network', 'luby-rackoff'],
#  ['encryption', 'aes', 'initialization-vector', 'randomness', 'salt'],
#  ['signature', 'authentication', 'keys', 'key-exchange'],
#  ['rsa', 'elliptic-curves', 'modular-arithmetic'],
#  ['provable-security'],
#  ['reference-request', 'stream-cipher'],
#  ['cryptanalysis', 'differential-analysis'],
#  ['enigma'],
#  ['secret-sharing'],
#  ['elliptic-curves',
#   'signature',
#   'ed25519',
#   'timing-attack',
#   'schnorr-signature'],
#  ['aes', 'provable-security', 'modes-of-operation', 'nist', 'xts'],
#  ['elliptic-curves', 'post-quantum-cryptography'],
#  ['key-exchange', 'key-derivation'],
#  ['rsa', 'standards', 'fips-140'],
#  ['encryption', 'aes', 'public-key', 'symmetric', 'attack'],
#  ['encryption'],
#  ['hash', 'authentication', 'md5'],
#  ['block-cipher', 'tweakable-cipher'],
#  ['random-number-generator'],
#  ['hash'],
#  ['signature', 'algorithm-design', 'timestamping'],
#  ['hash', 'rainbow-table'],
#  ['multiparty-computation'],
#  ['complexity', 'rainbow-table'],
#  ['aes', 'multiple-encryption', 'serpent', 'twofish', 'truecrypt'],
#  ['multiparty-computation', 'universal-composability'],
#  ['notation'],
#  ['hash', 'commitments', '2nd-preimage-resistance'],
#  ['hash', 'scrypt'],
#  ['substitution-cipher', 'feistel-network'],
#  ['cryptanalysis', 'block-cipher'],
#  ['pgp', 'chosen-ciphertext-attack', 'cfb'],
#  ['rsa', 'public-key', 'prime-numbers'],
#  ['block-cipher', 'modes-of-operation'],
#  ['encryption', 'block-cipher', 'blocksize'],
#  ['authentication', 'mac', 'cbc-mac'],
#  ['rsa', 'public-key', 'pbkdf-2', 'known-plaintext-attack', 'distinguisher'],
#  ['public-key',
#   'elliptic-curves',
#   'diffie-hellman',
#   'key-exchange',
#   'openssl'],
#  ['protocol-design', 'reference-request'],
#  ['matrix-multiplication'],
#  ['permutation', 'feistel-network', 'blocksize'],
#  ['homomorphic-encryption', 'elgamal-encryption'],
#  ['keys', 'hmac', 'sha-1', 'key-size'],
#  ['implementation', 'collision-resistance', 'sha-1'],
#  ['differential-analysis', 'linear-cryptanalysis'],
#  ['elliptic-curves', 'post-quantum-cryptography'],
#  ['cryptanalysis'],
#  ['pgp', 'chosen-ciphertext-attack'],
#  ['protocol-design', 'post-quantum-cryptography', 'lattice-crypto'],
#  ['blocksize', 'xts'],
#  ['hash', 'compression'],
#  ['encryption', 'notation'],
#  ['rsa'],
#  ['rsa', 'signature', 'implementation', 'rsa-pss'],
#  ['feistel-network'],
#  ['public-key', 'padding', 'random-oracle-model'],
#  ['protocol-design'],
#  ['implementation', 'performance', 'norx'],
#  ['keys', 'timing-attack', 'encoding'],
#  ['rsa', 'signature'],
#  ['diffie-hellman', 'hardness-assumptions'],
#  ['lattice-crypto'],
#  ['modes-of-operation', 'gcm', 'disk-encryption', 'xts'],
#  ['hash', 'mac', 'sha-256', 'chosen-plaintext-attack', 'bcrypt'],
#  ['encryption', 'xts'],
#  ['public-key', 'keys', 'secure-storage'],
#  ['algorithm-design', 'lattice-crypto'],
#  ['s-boxes', 'timing-attack'],
#  ['encryption',
#   'public-key',
#   'authentication',
#   'keys',
#   'authenticated-encryption'],
#  ['keys', 'key-derivation', 'key-size'],
#  ['rsa', 'pgp', 'deterministic-encryption', 'oaep'],
#  ['elliptic-curves'],
#  ['cryptanalysis', 'group-theory', 'algebraic-attack'],
#  ['random-number-generator', 'entropy'],
#  ['secret-sharing', 'shamir-secret-sharing'],
#  ['tls'],
#  ['elgamal-encryption', 'elgamal-signature'],
#  ['modular-arithmetic', 'montgomery-multiplication'],
#  ['aes', 'cbc', 'initialization-vector'],
#  ['mac', 'stream-cipher', 'authenticated-encryption'],
#  ['mac', 'universal-hash'],
#  ['signature', 'performance', 'rabin-cryptosystem'],
#  ['public-key'],
#  ['diffie-hellman', 'discrete-logarithm', 'factorization'],
#  ['passwords', 'salt', 'random-number-generator', 'password-hashing'],
#  ['elliptic-curves', 'modular-arithmetic'],
#  ['homomorphic-encryption', 'implementation'],
#  ['rsa', 'implementation', 'cpu'],
#  ['public-key'],
#  ['discrete-logarithm'],
#  ['prime-numbers', 'factorization'],
#  ['key-generation', 'one-time-password'],
#  ['cryptanalysis', 'rc4'],
#  ['cryptanalysis', 'padding-oracle'],
#  ['notation'],
#  ['man-in-the-middle'],
#  ['certificates'],
#  ['factorization', 'quadratic-residuosity', 'sieve'],
#  ['encryption'],
#  ['post-quantum-cryptography'],
#  ['tls'],
#  ['random-number-generator', 'randomness'],
#  ['encryption'],
#  ['cryptanalysis', 'substitution-cipher'],
#  ['elliptic-curves'],
#  ['encryption', 'implementation', 'elgamal-encryption'],
#  ['encryption'],
#  ['hash', 'sha-256'],
#  ['encryption', 'cryptanalysis', 'brute-force-attack', 'md5'],
#  ['rsa', 'signature'],
#  ['rsa'],
#  ['tls'],
#  ['rsa', 'signature', 'attack'],
#  ['rsa',
#   'cryptanalysis',
#   'algorithm-design',
#   'implementation',
#   'quadratic-residuosity'],
#  ['signature', 'schnorr-signature', 'forgery'],
#  ['encryption', 'tls', 'openssl', 'transport-security'],
#  ['encryption', 'rsa', 'certificates'],
#  ['aes', 'cbc', 'ctr', 'ecb'],
#  ['attack', 'elgamal-signature'],
#  ['encryption', 'hash', 'collision-resistance', 'sha-1'],
#  ['elliptic-curves', 'finite-field'],
#  ['shamir-secret-sharing', 'threshold-cryptography'],
#  ['hash', 'implementation'],
#  ['encryption', 'encoding'],
#  ['twofish', 'key-schedule', 'camellia'],
#  ['aes', 's-boxes'],
#  ['hash'],
#  ['elgamal-signature', 'forgery'],
#  ['cryptanalysis', 'reference-request', 'post-quantum-cryptography', 'ntru'],
#  ['cryptanalysis'],
#  ['aes', 'known-plaintext-attack'],
#  ['encryption', 'cryptanalysis'],
#  ['encryption', 'cryptanalysis', 'algorithm-design'],
#  ['provable-security', 'chosen-plaintext-attack'],
#  ['encryption', 'aes', 'gcm'],
#  ['algorithm-design', 'keys', 'des', 'feistel-network'],
#  ['public-key', 'key-exchange', 'pgp'],
#  ['hash', 'elliptic-curves', 'one-way-function'],
#  ['quantum-cryptography'],
#  ['terminology', 'notation'],
#  ['encryption', 'pgp'],
#  ['hash', 'collision-resistance', 'md5'],
#  ['cryptanalysis', 'classical-cipher', 'known-plaintext-attack', 'playfair'],
#  ['rsa', 'cryptanalysis', 'factorization'],
#  ['encryption', 'aes', 'gcm'],
#  ['hash', 'preimage-resistance'],
#  ['tls'],
#  ['cryptanalysis', 's-boxes'],
#  ['reference-request', 'sha-1', 'standards', 'fips-140'],
#  ['modular-arithmetic', 'affine-cipher'],
#  ['public-key',
#   'protocol-design',
#   'authentication',
#   'key-exchange',
#   'protocol-analysis'],
#  ['hash', 'collision-resistance'],
#  ['hash', 'algorithm-design', 'performance'],
#  ['encryption', 'public-key', 'pki'],
#  ['public-key', 'keys'],
#  ['pseudo-random-function', 'pbkdf-2'],
#  ['authenticated-encryption', 'pbkdf-2', 'siv'],
#  ['homomorphic-encryption'],
#  ['aes', 'algorithm-design'],
#  ['hash', 'collision-resistance'],
#  ['homomorphic-encryption'],
#  ['encryption', 'terminology'],
#  ['hash', 'collision-resistance'],
#  ['public-key', 'elliptic-curves', 'dsa', 'attack'],
#  ['stream-cipher', 'java', 'salsa20'],
#  ['algorithm-design'],
#  ['public-key', 'random-number-generator', 'dsa', 'attack'],
#  ['encryption', 'rsa', 'public-key', 'signature', 'keys'],
#  ['elliptic-curves'],
#  ['aes', 'key-size'],
#  ['encryption', 'rsa', 'public-key'],
#  ['implementation', 'stream-cipher'],
#  ['diffie-hellman'],
#  ['encryption', 'xor'],
#  ['elliptic-curves', 'key-derivation'],
#  ['hash', 'provable-security', 'collision-resistance'],
#  ['authentication'],
#  ['aes', 'matrix-multiplication'],
#  ['signature', 'protocol-design'],
#  ['rsa', 'public-key', 'factorization'],
#  ['encryption', 'rsa', 'keys', 'prime-numbers', 'factorization'],
#  ['hash', 'preimage-resistance'],
#  ['substitution-cipher'],
#  ['hash', 'hmac', 'sha-256'],
#  ['encryption'],
#  ['one-time-pad'],
#  ['rsa', 'public-key', 'modular-arithmetic'],
#  ['elliptic-curves', 'pairings', 'identity-based-encryption'],
#  ['modular-arithmetic'],
#  ['cryptanalysis', 'algorithm-design', 'transposition-cipher'],
#  ['encryption', 'attack', 'history'],
#  ['passwords', 'entropy', 'key-size', 'password-hashing'],
#  ['rsa', 'elgamal-signature'],
#  ['encryption', 'attack', 'quantum-cryptography'],
#  ['hash', 'password-hashing'],
#  ['encryption', 'symmetric', 'implementation', 'performance', 'bitslicing'],
#  ['public-key'],
#  ['visual-cryptography'],
#  ['random-number-generator'],
#  ['encryption', 'visual-cryptography'],
#  ['encryption'],
#  ['symmetric'],
#  ['encryption', 'secure-storage', 'digital-rights-management'],
#  ['pseudo-random-function', 'chosen-plaintext-attack', 'lfsr'],
#  ['mac'],
#  ['affine-cipher'],
#  ['encryption', 'brute-force-attack'],
#  ['key-exchange'],
#  ['mac'],
#  ['elliptic-curves'],
#  ['aes'],
#  ['white-box'],
#  ['rsa', 'public-key', 'pgp'],
#  ['key-exchange', 'key-distribution'],
#  ['hash'],
#  ['diffie-hellman'],
#  ['identity-based-encryption', 'broadcast-encryption'],
#  ['protocol-design', 'authentication', 'hmac'],
#  ['complexity'],
#  ['protocol-design'],
#  ['encryption', 'cryptanalysis', 'transposition-cipher'],
#  ['pseudo-random-function'],
#  ['hmac', 'mac', 'sha-3'],
#  ['hash', 'hash-tree'],
#  ['homomorphic-encryption'],
#  ['pseudo-random-function', 'pseudo-random-generator'],
#  ['encryption', 'passwords', 'password-based-encryption', 'database'],
#  ['sha-256', 'preimage-resistance'],
#  ['public-key'],
#  ['identity-based-encryption'],
#  ['protocol-design',
#   'reference-request',
#   'authenticated-encryption',
#   'embedded'],
#  ['openssl'],
#  ['authentication', 'passwords', 'salt'],
#  ['cryptanalysis', 'sat'],
#  ['aes', 'finite-field'],
#  ['aes', 'rijndael'],
#  ['encryption', 'pki', 'snake-oil-cryptography'],
#  ['s-boxes', 'linear-cryptanalysis'],
#  ['public-key', 'symmetric'],
#  ['3des'],
#  ['encryption', 'cryptanalysis', 'identity-based-encryption'],
#  ['certificates'],
#  ['key-exchange', 'digital-rights-management'],
#  ['aes'],
#  ['homomorphic-encryption', 'prime-numbers'],
#  ['key-derivation', 'openssl', 'pbkdf-2', 'pbkdf'],
#  ['post-quantum-cryptography', 'key-size', 'isogeny'],
#  ['cryptanalysis', 'block-cipher', 'differential-analysis', 'camellia'],
#  ['hash', 'collision-resistance', 'sha-256', 'sha-1', 'md5'],
#  ['hash', 'algorithm-design'],
#  ['keys', 'one-time-pad'],
#  ['homomorphic-encryption', 'paillier'],
#  ['modular-arithmetic', 'number-theory'],
#  ['secret-sharing', 'shamir-secret-sharing'],
#  ['aes', 'side-channel-attack', 'timing-attack', 'statistical-test'],
#  ['rsa'],
#  ['rsa', 'post-quantum-cryptography', 'quantum-cryptography'],
#  ['encryption', 'aes', 'one-time-pad', 'password-based-encryption', 'serpent'],
#  ['discrete-logarithm'],
#  ['public-key', 'dsa', 'ssh'],
#  ['public-key', 'tls', 'ssh'],
#  ['identity-based-encryption'],
#  ['encryption', 'rsa'],
#  ['encryption', 'identity-based-encryption'],
#  ['cryptanalysis', 'one-time-pad', 'key-size', 'key-reuse'],
#  ['cryptanalysis', 'xor', 'vigenere', 'ciphertext-only-attack'],
#  ['public-key', 'authentication', 'pgp', 'integrity'],
#  ['aes', 'public-key', 'diffie-hellman', 'key-exchange'],
#  ['encryption', 'frequency-analysis'],
#  ['rsa', 'provable-security'],
#  ['linear-cryptanalysis'],
#  ['zero-knowledge-proofs'],
#  ['multiparty-computation', 'data-privacy'],
#  ['diffie-hellman', 'key-recovery'],
#  ['implementation', 'java', 'ntru'],
#  ['homomorphic-encryption', 'paillier'],
#  ['authenticated-encryption', 'deterministic-encryption', 'siv'],
#  ['hash', 'sha-1', 'md5'],
#  ['rsa', 'keys'],
#  ['public-key', 'diffie-hellman', 'key-exchange'],
#  ['rsa', 'padding'],
#  ['lattice-crypto', 'hardness-assumptions'],
#  ['secret-sharing', 'shamir-secret-sharing'],
#  ['random-number-generator', 'stream-cipher'],
#  ['signature', 'certificates', 'cms'],
#  ['encryption', 'aes', 'cbc', 'attack'],
#  ['encryption', 'public-key', 'protocol-design'],
#  ['encryption'],
#  ['encryption', 'encoding'],
#  ['enigma'],
#  ['encryption', 'openssl', '3des', 's-mime'],
#  ['homomorphic-encryption', 'finite-field'],
#  ['identity-based-encryption'],
#  ['encryption', 'aes', 'ctr', 'nonce'],
#  ['aes'],
#  ['elliptic-curves'],
#  ['key-derivation', 'key-size', 'pgp'],
#  ['diffie-hellman'],
#  ['encryption', 'aes'],
#  ['encryption', 'protocol-design'],
#  ['implementation', 'passwords', 'password-hashing', 'argon2'],
#  ['encryption', 'tls'],
#  ['encryption', 'cryptanalysis'],
#  ['key-derivation', 'pbkdf', 'password-hashing', 'memory-hard'],
#  ['encryption', 'classical-cipher', 'encoding'],
#  ['aes', 'initialization-vector', 'openssl', 'gcm', 'nonce'],
#  ['rsa', 'public-key'],
#  ['rsa', 'prime-numbers', 'factorization'],
#  ['notation', 'coding-theory'],
#  ['hash', 'sha-2', 'sha-512'],
#  ['lattice-crypto', 'ntru'],
#  ['elliptic-curves', 'pairings'],
#  ['encryption'],
#  ['rsa', 'diffie-hellman', 'dsa', 'man-in-the-middle'],
#  ['rsa', 'signature', 'message-recovery'],
#  ['homomorphic-encryption', 'post-quantum-cryptography', 'lattice-crypto'],
#  ['rsa', 'keys'],
#  ['vigenere'],
#  ['vigenere'],
#  ['provable-security', 'abe'],
#  ['encryption', 'hash', 'public-key', 'password-hashing'],
#  ['cryptanalysis', 'discrete-logarithm', 'factorization'],
#  ['post-quantum-cryptography',
#   'factorization',
#   'complexity',
#   'lattice-crypto'],
#  ['passwords', 'key-derivation', 'password-hashing'],
#  ['post-quantum-cryptography', 'lattice-crypto'],
#  ['encryption', 'aes', 'implementation'],
#  ['reference-request', 'pgp', 'steganography', 'file-format'],
#  ['rsa', 'elliptic-curves', 'diffie-hellman', 'key-exchange'],
#  ['encryption'],
#  ['secret-sharing', 'shamir-secret-sharing'],
#  ['modular-arithmetic'],
#  ['hash', 'certificates', 'man-in-the-middle'],
#  ['blowfish'],
#  ['rsa', 'elliptic-curves', 'hybrid'],
#  ['algorithm-design'],
#  ['multiparty-computation', 'protocol-analysis', 'complexity'],
#  ['mac', 'key-derivation'],
#  ['provable-security', 'security-definition', 'adversarial-model'],
#  ['cryptanalysis', 'elliptic-curves', 'diffie-hellman', 'pairings'],
#  ['encryption', 'cryptanalysis', 'ciphertext-only-attack'],
#  ['implementation', 'side-channel-attack', 'timing-attack'],
#  ['identity-based-encryption'],
#  ['random-number-generator', 'lfsr'],
#  ['zero-knowledge-proofs',
#   'terminology',
#   'security-definition',
#   'random-oracle-model'],
#  ['encryption'],
#  ['key-derivation'],
#  ['protocol-design'],
#  ['plausible-deniability'],
#  ['encryption', 'aes', 'xor', 's-boxes'],
#  ['rsa', 'public-key', 'encoding'],
#  ['implementation', 'multiparty-computation', 'oblivious-ram'],
#  ['algorithm-design',
#   'reference-request',
#   'multiparty-computation',
#   'oblivious-ram'],
#  ['encryption', 'des'],
#  ['scrypt', 'memory-hard', 'timing-attack'],
#  ['attack', 'ccm'],
#  ['des', 'feistel-network'],
#  ['provable-security'],
#  ['hash'],
#  ['factorization'],
#  ['hash', 'collision-resistance', 'random-oracle-model'],
#  ['hash'],
#  ['hash', 'sha-256', 'group-theory', 'access-control'],
#  ['elliptic-curves', 'finite-field', 'group-theory'],
#  ['padding', 'sha-3'],
#  ['hash', 'notation'],
#  ['public-key', 'homomorphic-encryption', 'paillier'],
#  ['rsa', 'public-key', 'elliptic-curves'],
#  ['encryption', 'integrity'],
#  ['hash', 'access-control', 'sha-256'],
#  ['encryption', 'hash', 'salt', 'pbkdf-2', 'password-hashing'],
#  ['authentication'],
#  ['public-key', 'homomorphic-encryption', 'paillier'],
#  ['stream-cipher', 'lightweight'],
#  ['hash', 'scrypt', 'encoding'],
#  ['encryption', 'aes', 'symmetric'],
#  ['public-key'],
#  ['encryption', 'cryptanalysis', 'linear-cryptanalysis'],
#  ['random-number-generator'],
#  ['wpa2-psk'],
#  ['lattice-crypto'],
#  ['encryption'],
#  ['hash', 'protocol-design', 'collision-resistance', 'protocol-analysis'],
#  ['hash', 'block-cipher', 'collision-resistance', 'simon'],
#  ['hash', 'entropy', 'security-definition'],
#  ['cryptographic-hardware', 'fips-140'],
#  ['hash', 'signature', 'hmac'],
#  ['encryption', 'algorithm-design', 'terminology'],
#  ['encryption', 'entropy'],
#  ['hash', 'terminology', 'password-hashing'],
#  ['order-preserving'],
#  ['stream-cipher', 'xor', 'encoding'],
#  ['3des', 'key-check-value'],
#  ['public-key', 'post-quantum-cryptography', 'sat'],
#  ['reference-request', 'side-channel-attack'],
#  ['mac', 'forgery'],
#  ['stream-cipher', 'encoding'],
#  ['encryption', 'symmetric'],
#  ...]

# %%
mlb = MultiLabelBinarizer(classes=sorted(tags_counts.keys()))
y_train = mlb.fit_transform(y_train)
y_val = mlb.fit_transform(y_val)

# %%
y_train.shape
# Out:
# (10000, 392)

# %% [markdown]
# Train the classifiers for different data transformations: *bag-of-words* and *tf-idf*.

# %%
# %%time
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression, RidgeClassifier
clf = OneVsRestClassifier(RidgeClassifier(normalize=True))
clf.fit(X_train_tfidf, y_train)
# classifier_tfidf = train_classifier(X_train_tfidf, y_train)
# Out:
# E:\intelpython3\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 19 is present in all training examples.
#   str(classes[c]))
# E:\intelpython3\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 113 is present in all training examples.
#   str(classes[c]))
# E:\intelpython3\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 180 is present in all training examples.
#   str(classes[c]))
# E:\intelpython3\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 258 is present in all training examples.
#   str(classes[c]))
# Wall time: 14.7 s
# E:\intelpython3\lib\site-packages\sklearn\multiclass.py:76: UserWarning: Label not 387 is present in all training examples.
#   str(classes[c]))

# %% [markdown]
# Now you can create predictions for the data. You will need two types of predictions: labels and scores.

# %%
# %%time
y_val_predicted_labels_tfidf = clf.predict(X_val_tfidf)
# y_val_predicted_scores_tfidf = classifier_tfidf.decision_function(X_val_tfidf)
# Out:
# Wall time: 29.4 ms

# %% [markdown]
# Now take a look at how classifier, which uses TF-IDF, works for a few examples:

# %%
que = ['How do I stop pasta from clumping/sticking together?','What is a stick of butter?','how to do tadka in daal?', 'how to make chocolate brownie?']
que = [text_prepare(i) for i in que]
# que = [que]
que = tfidf_vectorizer.transform(que)
yp = clf.predict(que)
print(mlb.inverse_transform(yp))
# Out:
# [(), (), (), ('encryption',)]

# %%
import pickle
import os 
pickle.dump(clf, open('model-crypto.pkl', 'wb'))
pickle.dump(mlb, open('tags-crypto.pkl', 'wb'))
pickle.dump(tfidf_vectorizer, open('tf-crypto.pkl', 'wb'))
