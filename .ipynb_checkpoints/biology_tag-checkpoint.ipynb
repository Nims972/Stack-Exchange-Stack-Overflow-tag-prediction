# %%
import nltk
#nltk.download('stopwords')
from ast import literal_eval
import pandas as pd
import numpy as np
from nltk.corpus import stopwords

# %%
def read_data(filename):
    data = pd.read_csv(filename, sep='\t')
    data['tags'] = data['tags'].apply(literal_eval)
    return data

# %%
tmp = pd.read_csv('biology/biology.csv')
#train = read_data('cooking.csv')
#validation = read_data('validation.tsv')
#test = pd.read_csv('test.tsv', sep='\t')

# %%
test = tmp.tail(3904)
train = tmp.head(11500)
validation = tmp.head(11500).tail(1500)

# %%
validation.head()
# Out:
#           id                                              title  \
# 10000  40851  How to Determine the Most Conserved Sequence f...
# 10001  40853      Question about proto-oncogenes and oncogenes?
# 10002  40854   Are both chromosomes transcribed and translated?
# 10003  40860  Effects of HRT on transgender(M to F) physiolo...
# 10004  40863                              Animal gene in plants
#
#                                                  content  \
# 10000  <p>I used BLAST to find the best aligned DNA s...
# 10001  <p>My textbook says:</p>\n\n<blockquote>\n  <p...
# 10002  <p>Or is it somehow regulated if both or only ...
# 10003  <p>I often heard of athletes in the Olympics w...
# 10004  <p>Usually only microbes, specifically bacteri...
#
#                                                     tags
# 10000            bioinformatics sequence-alignment blast
# 10001  genetics molecular-biology cell-biology cancer...
# 10002               chromosome transcription translation
# 10003       human-anatomy endocrinology human-physiology
# 10004                      genetics gene-expression gene

# %%
train.head()
# Out:
#    id                                              title  \
# 0   1  What is the criticality of the ribosome bindin...
# 1   2  How is RNAse contamination in RNA based experi...
# 2   3      Are lymphocyte sizes clustered in two groups?
# 3   4  How long does antibiotic-dosed LB maintain goo...
# 4   5        Is exon order always preserved in splicing?
#
#                                              content  \
# 0  <p>In prokaryotic translation, how critical fo...
# 1  <p>Does anyone have any suggestions to prevent...
# 2  <p>Tortora writes in <em>Principles of Anatomy...
# 3  <p>Various people in our lab will prepare a li...
# 4  <p>Are there any cases in which the splicing m...
#
#                                                 tags
# 0  ribosome binding-sites translation synthetic-b...
# 1                                   rna biochemistry
# 2                 immunology cell-biology hematology
# 3                                       cell-culture
# 4            splicing mrna spliceosome introns exons

# %%
test.head()
# Out:
#          id                                              title  \
# 9292  39077  By What Mechanism Does Heat Cause Muscle Relax...
# 9293  39081    3D model - ant brain - precision and laboratory
# 9294  39082  How is it decided what type of food we want to...
# 9295  39083                    Refer to Ran-GEF as a coenzyme?
# 9296  39085  How do two parents, recessive and dominant gen...
#
#                                                 content  \
# 9292  <p>Heat is commonly used "loosen" muscles, but...
# 9293  <p>I have some question. Is today's modern lab...
# 9294  <p>How is it decided what type of food we want...
# 9295  <p>Ran-GEF facilitates an exchange of GDP for ...
# 9296  <p>In the basic school, I was taught that half...
#
#                                 tags
# 9292  muscles blood-circulation heat
# 9293                       brain ant
# 9294                            food
# 9295               molecular-biology
# 9296            genetics dna meiosis

# %%
X_train, y_train = train['title'].values, train['tags'].values
X_val, y_val = validation['title'].values, validation['tags'].values
X_test = test['title'].values

# %%
y_train[1]
# Out:
# 'rna biochemistry'

# %%
import re

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))

def text_prepare(text):
    text = text.lower()
    text = REPLACE_BY_SPACE_RE.sub(' ', text)
    text = BAD_SYMBOLS_RE.sub('', text)
    text = ' '.join(word for word in text.split() if word not in STOPWORDS)
    #print(text)
    return text

# %%
# prepared_questions = []
# for line in open('text_prepare_tests.tsv', encoding='utf-8'):
#     line = text_prepare(line.strip())
#     prepared_questions.append(line)
# text_prepare_results = '\n'.join(prepared_questions)

# %%
X_train = [text_prepare(x) for x in X_train]
X_val = [text_prepare(x) for x in X_val]
X_test = [text_prepare(x) for x in X_test]

# %%
y_train[:3]
# Out:
# array(['ribosome binding-sites translation synthetic-biology',
#        'rna biochemistry', 'immunology cell-biology hematology'],
#       dtype=object)

# %%
from collections import defaultdict
tags_counts = defaultdict(int)
words_counts = defaultdict(int)
tmp=[]

for tags in y_train:
    tt = tags.split()
    tmp.append(tt)
    for tag in tt:
        #print(tag)
        tags_counts[tag] += 1
y_train=tmp
tmp=[]

for text in X_train:
    for word in text.split():
        #print(word)
        words_counts[word] += 1
        
for tags in y_val:
    tt = tags.split()
    tmp.append(tt)
    for tag in tt:
        #print(tag)
        tags_counts[tag] += 1
y_val=tmp
tmp=[]
for text in X_val:
    for word in text.split():
        #print(word)
        words_counts[word] += 1

# %%
most_common_tags = sorted(tags_counts.items(), key=lambda x: x[1], reverse=True)[:10]
most_common_words = sorted(words_counts.items(), key=lambda x: x[1], reverse=True)[:3]

# %%
most_common_words
# Out:
# [('dna', 552), ('human', 493), ('cells', 433)]

# %%
most_common_tags
# Out:
# [('human-biology', 1479),
#  ('genetics', 1192),
#  ('evolution', 1118),
#  ('biochemistry', 1011),
#  ('molecular-biology', 863),
#  ('cell-biology', 770),
#  ('bioinformatics', 668),
#  ('dna', 663),
#  ('neuroscience', 627),
#  ('physiology', 558)]

# %%
from scipy import sparse as sp_sparse
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
??TfidVectorizer
# Out:
# Object `TfidVectorizer` not found.

# %%
#X_val

# %%
tfidf_vectorizer = TfidfVectorizer(min_df=5, max_df=0.9, ngram_range=(1, 2),token_pattern='(\S+)')
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_val_tfidf = tfidf_vectorizer.transform(X_val)
X_test_tfidf = tfidf_vectorizer.transform(X_test)
tfidf_vocab = tfidf_vectorizer.vocabulary_
#X_train_tfidf, X_val_tfidf, X_test_tfidf, tfidf_vocab = tfidf_features(X_train, X_val, X_test)

# %%
tfidf_reversed_vocab = {i:word for word,i in tfidf_vocab.items()}

# %%
tfidf_vocab['make']
# Out:
# 1449

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# %%
tags_counts.keys()
# Out:
# dict_keys(['ribosome', 'binding-sites', 'translation', 'synthetic-biology', 'rna', 'biochemistry', 'immunology', 'cell-biology', 'hematology', 'cell-culture', 'splicing', 'mrna', 'spliceosome', 'introns', 'exons', 'dna', 'molecular-biology', 'neuroscience', 'synapses', 'plasmids', 'molecular-genetics', 'gene-expression', 'experimental-design', 'evolution', 'mitochondria', 'chloroplasts', 'high-throughput', 'cell-based', 'bioinformatics', 'homework', 'histone', 'genomics', 'gene-annotation', 'microbiology', 'virology', 'influenza', 'epigenetics', 'dna-isolation', 'cell-membrane', 'adaptation', 'transcription', 'chromatin', 'rna-interference', 'endocrinology', 'human-biology', 'phylogenetics', 'genetics', 'astrobiology', 'primer', 'history', 'bacteriology', 'mycology', 'enzymes', 'human-anatomy', 'histology', 'staining', 'zoology', 'radiation', 'entomology', 'abiogenesis', 'green-fluorescent-protein', 'cloning', 'anatomy', 'hearing', 'organic-chemistry', 'histone-modifications', 'ethology', 'ecology', 'extremophiles', 't7-promoter', 'yeast', 'physiology', 'metabolism', 'epidemiology', 'antibody', 'telomere', 'neuroanatomy', 'pharmacology', 'bioluminescence', 'palaeontology', 'learning', 'receptor', 'pathology', 'joints', 'plant-physiology', 'botany', 'vaccination', 'theoretical-biology', 'sexual-selection', 'extinction', 'human-genome', 'homeostasis', 'renal-physiology', 'organs', 'cardiology', 'electrocardiography', 'dna-sequencing', 'structural-biology', 'population-dynamics', 'conservation-biology', 'proteins', '3d-structure', 'sleep', 'natural-selection', 'cancer', 'statistics', 'senescence', 'aspirin', 'fluorescent-microscopy', 'temperature', 'parasitism', 'life-history', 'microscopy', 'taxonomy', 'vitamins', 'electrophysiology', 'biophysics', 'pigmentation', 'gel-electrophoresis', 'nucleic-acids', 'photosynthesis', 'speculative', 'cellular-respiration', 'auxology', 'eukaryotic-cells', 'replication', 'polymerase', 'digestive-system', 'mutations', 'vision', 'eyes', 'microbiome', 'biotechnology', 'book-recommendation', 'general-biology', 'reproduction', 'sensation', 'perception', 'amino-acids', 'chirality', 'reverse-transcription', 'pcr', 'plant-anatomy', 'climate-change', 'sex', 'human-genetics', 'pymol', 'mitosis', 'mathematical-models', 'collective-behaviour', 'anaerobic-respiration', 'touch', 'sex-ratio', 'memory', 'blood-brain-barrier', 'coot', 'scales', 'muscles', 'gene-synthesis', 'codon-usage', 'antibiotics', 'behaviour', 'psychology', 'ecoli', 'meiosis', 'oogenesis', 'ccp4', 'growth', 'thermodynamics', 'lab-techniques', 'embryology', 'chromosome', 'polyploidy', 'teratology', 'development', 'copy-number-variation', 'chickens', 'ornithology', 'genomes', 'hiv', 'xray-crystallography', 'bioinorganic-chemistry', 'cytogenetics', 'protocol', 'antipredator-adaptation', 'rodents', 'circadian-rhythms', 'chronobiology', 'ichthyology', 'breathing', 'restriction-enzymes', 'food', 'protein-folding', 'biostatistics', 'dissociation-constant', 'protein-binding', 'assay-development', 'network', 'visualization', 'gene-regulation', 'teeth', 'chemical-communication', 'species-identification', 'genetic-diagrams', 'communication', 'linguistics', 'sociality', 'ethnobiology', 'toxicology', 'flight', 'vestigial', 'nomenclature', 'parasitology', 'pdb', 'neurology', 'transformation', 'growth-media', 'pathophysiology', 'population-biology', 'marine-biology', 'speciation', 'cranial-nerves', 'fruit', 'experimental', 'sds-page', 'safety', 'protein-engineering', 'protein-evolution', 'structure-prediction', 'locomotion', 'sequence-assembly', 'tissue-repair', 'stem-cells', 'nutrition', 'horizontal-gene-transfer', 'rna-sequencing', 'respiration', 'imaging', 'software', 'addiction', 'evolutionary-game-theory', 'reflexes', 'lab-reagents', 'minipreps', 'human-ear', 'human-physiology', 'gastroenterology', 'altruism', 'systems-biology', 'language', 'environment', 'chip', 'homology', 'hybridization', 'ecophysiology', 'terminology', 'gwas', 'brain', 'dreaming ...

# %%
y_val
# Out:
# [['bioinformatics', 'sequence-alignment', 'blast'],
#  ['genetics', 'molecular-biology', 'cell-biology', 'cancer', 'mutations'],
#  ['chromosome', 'transcription', 'translation'],
#  ['human-anatomy', 'endocrinology', 'human-physiology'],
#  ['genetics', 'gene-expression', 'gene'],
#  ['growth'],
#  ['cell-biology'],
#  ['human-biology'],
#  ['bioinformatics', 'dna-sequencing'],
#  ['evolution'],
#  ['bioinformatics', 'genomics'],
#  ['genetics', 'proteins', 'molecular-genetics', 'gene-expression', 'operons'],
#  ['evolution', 'terminology', 'mutations'],
#  ['homeostasis', 'osmosis', 'osmoregulation'],
#  ['evolution',
#   'natural-selection',
#   'theoretical-biology',
#   'evolutionary-game-theory'],
#  ['human-biology', 'pharmacology', 'hematology', 'medicine'],
#  ['biochemistry', 'molecular-biology', 'western-blot'],
#  ['human-biology', 'immunology', 'medicine', 'organs', 'mhc'],
#  ['molecular-biology', 'proteins', 'protein-binding', 'binding-sites'],
#  ['bioinformatics', 'bacteriology', 'genomics', 'genomes'],
#  ['cancer'],
#  ['immunology', 'elisa'],
#  ['dna', 'mutations', 'dna-damage', 'dna-replication'],
#  ['neuroscience', 'dreaming'],
#  ['neuroscience', 'development', 'central-nervous-system'],
#  ['cell-biology'],
#  ['genetics', 'human-genetics', 'database', 'gene', 'data'],
#  ['biochemistry'],
#  ['theoretical-biology', 'infection', 'pathogenesis', 'cytokinesis'],
#  ['bioinformatics', 'dna', 'homework', 'structural-biology', 'pymol'],
#  ['immunology', 'cancer'],
#  ['evolution', 'development', 'embryology', 'visualization'],
#  ['cell-biology', 'cell-signaling'],
#  ['sequence-analysis', 'cloning', 'plasmids'],
#  ['biochemistry', 'olfaction', 'nose'],
#  ['genetics', 'human-genetics'],
#  ['molecular-biology', 'genomics', 'pseudogenes'],
#  ['dna', 'pcr', 'primer', 'dna-replication', 'dnapolymerase'],
#  ['human-biology', 'cell-biology', 'cardiology', 'electrophysiology'],
#  ['electrocardiography'],
#  ['sequence-alignment', 'measurement', 'sequence-assembly'],
#  ['cell-biology', 'dna', 'dna-sequencing', 'human-genome'],
#  ['molecular-biology'],
#  ['cell-biology', 'cancer'],
#  ['biochemistry'],
#  ['lab-techniques', 'antibody', 'flow-cytometry'],
#  ['dna', 'pcr', 'dna-replication'],
#  ['dna', 'human-genetics', 'epigenetics'],
#  ['proteins', 'rna', 'protein-binding', 'translation', 'biosynthesis'],
#  ['hiv', 'retrovirus', 'aids', 'lentivirus'],
#  ['physiology', 'homework', 'ecology', 'homeostasis'],
#  ['bioinformatics', 'dna', 'dna-sequencing', 'sequence-alignment'],
#  ['bioinformatics', 'dna-sequencing', 'genomics', 'pcr', 'cloning'],
#  ['human-biology', 'teeth', 'saliva'],
#  ['transplantation'],
#  ['entomology', 'methods'],
#  ['cell-biology', 'hematology'],
#  ['genetics', 'rna', 'microrna', 'rna-interference', 'noncoding-rna'],
#  ['biochemistry', 'metabolism', 'energy', 'fat-metabolism', 'cholesterol'],
#  ['human-biology',
#   'epigenetics',
#   'microarray',
#   'data',
#   'neurodegerative-disorders'],
#  ['entomology', 'ant'],
#  ['bioinformatics', 'population-genetics'],
#  ['cell-biology', 'metabolism', 'cellular-respiration', 'chemistry'],
#  ['reproduction', 'dna-damage'],
#  ['cell-biology', 'cryonics'],
#  ['sequence-alignment'],
#  ['biochemistry', 'medicinal-chemistry', 'waste-disposal'],
#  ['genetics'],
#  ['genetics'],
#  ['genetics', 'sex', 'reproductive-biology', 'gender'],
#  ['biochemistry', 'molecular-biology', 'bioinformatics', 'botany'],
#  ['genetics', 'molecular-biology'],
#  ['biochemistry', 'biophysics', 'cell-membrane', 'reference-request'],
#  ['neurotransmitter', 'epigenetics', 'stress', 'serotonin'],
#  ['human-biology',
#   'cell-biology',
#   'immunology',
#   'pathogenesis',
#   'hypersensitivity'],
#  ['human-biology',
#   'immunology',
#   'parasitology',
#   'pathogenesis',
#   'hypersensitivity'],
#  ['metabolism', 'theoretical-biology', 'skin', 'temperature'],
#  ['diy-biology', 'extremophiles'],
#  ['human-biology', 'cell-biology', 'dna', 'development', 'embryology'],
#  ['genetics', 'rna', 'epigenetics', 'mrna', 'microrna'],
#  ['molecular-biology', 'bioinformatics', 'language'],
#  ['molecular-biology',
#   'molecular-genetics',
#   'gene-expression',
#   'gene-regulation'],
#  ['zoology'],
#  ['protein-interaction'],
#  ['cell-biology', 'telomere', 'cell-division'],
#  ['terminology'],
#  ['microbiology'],
#  ['neuroscience', 'neurotransmitter', 'pain', 'touch'],
#  ['vegetable', 'vegetation'],
#  ['gene'],
#  ['zoology', 'locomotion'],
#  ['neuroscience', 'cell-membrane', 'action-potential'],
#  ['genetics', 'dna', 'gene-expression'],
#  ['zoology', 'mammals', 'perception', 'echolocation'],
#  ['cell-biology', 'metabolism', 'endocrinology', 'cell-signaling', 'pathway'],
#  ['genetics', 'bioinformatics', 'dna-sequencing'],
#  ['cell-biology'],
#  ['neuroscience', 'brain', 'vision', 'cognition'],
#  ['botany', 'species-identification'],
#  ['genetics', 'molecular-biology', 'molecular-genetics'],
#  ['neuroscience', 'brain', 'neurophysiology'],
#  ['population-genetics', 'fitness', 'altruism'],
#  ['cloning', 'protein-interaction'],
#  ['immunology',
#   'development',
#   'receptor',
#   'drosophila',
#   'transcription-factor'],
#  ['botany', 'trees'],
#  ['physiology', 'human-anatomy'],
#  ['biochemistry',
#   'microbiology',
#   'experimental-design',
#   'data',
#   'agriculture'],
#  ['food', 'nutrition', 'diet'],
#  ['human-biology', 'physiology', 'zoology', 'chemistry', 'senses'],
#  ['immunology', 'bacteriology'],
#  ['neuroscience', 'neurophysiology', 'molecular-evolution'],
#  ['biochemistry'],
#  ['evolution', 'human-evolution'],
#  ['cell-membrane'],
#  ['biochemistry'],
#  ['metabolism', 'eyes', 'light'],
#  ['cancer', 'genomics', 'sequence-analysis', 'data'],
#  ['genetics', 'molecular-biology', 'cell-biology', 'dna', 'mitosis'],
#  ['proteins', 'sensation', 'protein-binding', 'odour'],
#  ['human-biology', 'medicine'],
#  ['rna', 'polymerase'],
#  ['biochemistry',
#   'endocrinology',
#   'toxicology',
#   'reference-request',
#   'children'],
#  ['development', 'stem-cells'],
#  ['genetics', 'theoretical-biology'],
#  ['human-biology', 'vision', 'neurophysiology', 'human-eye', 'neuroanatomy'],
#  ['gene-expression', 'transcription', 'gene-regulation'],
#  ['microbiology', 'biophysics', 'cell-membrane', 'yeast'],
#  ['diet', 'fat-metabolism'],
#  ['transcription', 'spliceosome'],
#  ['decomposition'],
#  ['lab-techniques', 'pcr'],
#  ['genetics', 'behaviour'],
#  ['cardiology', 'action-potential'],
#  ['genetics', 'gene', 'sexual-selection'],
#  ['biochemistry', 'molecular-biology', 'molecular-genetics', 'pcr'],
#  ['physiology', 'hematology', 'pathophysiology'],
#  ['lab-techniques', 'chemistry', 'lab-reagents'],
#  ['biochemistry', 'lab-techniques', 'lab-reagents'],
#  ['cell-culture'],
#  ['bioinformatics', 'homework', 'sequence-alignment'],
#  ['evolution'],
#  ['evolution', 'epigenetics'],
#  ['botany'],
#  ['endocrinology', 'liver', 'blood-sugar'],
#  ['animal-models', 'surgery', 'salt'],
#  ['botany', 'plant-physiology'],
#  ['respiration',
#   'pathophysiology',
#   'homeostasis',
#   'ph',
#   'anaerobic-respiration'],
#  ['carbohydrates'],
#  ['biochemistry', 'proteins', 'ph'],
#  ['cell-biology', 'neuroscience'],
#  ['human-biology', 'cell-biology', 'metabolism', 'endocrinology'],
#  ['genetics', 'molecular-biology', 'molecular-genetics', 'human-genetics'],
#  ['human-biology', 'human-anatomy', 'development'],
#  ['genetics', 'human-genetics'],
#  ['plant-physiology', 'rna', 'lab-techniques'],
#  ['retrovirus'],
#  ['metabolism', 'diet', 'carbohydrates'],
#  ['physiology', 'cardiology'],
#  ['dna', 'bacteriology', 'dna-replication'],
#  ['dna', 'proteins', 'bacteriology', 'mrna'],
#  ['molecular-biology', 'dna', 'homework', 'cdna'],
#  ['fermentation'],
#  ['genetics', 'bacteriology', 'plasmids'],
#  ['human-biology', 'reproduction', 'sex'],
#  ['botany', 'circadian-rhythms'],
#  ['evolution'],
#  ['metabolism', 'lipids', 'fat-metabolism', 'cholesterol'],
#  ['genetics', 'virology', 'translation', 'hiv'],
#  ['molecular-biology', 'homework', 'plasmids', 'restriction-enzymes'],
#  ['molecular-biology', 'molecular-genetics'],
#  ['zoology', 'mammals', 'photography', 'image-processing'],
#  ['cell-biology', 'human-anatomy', 'organs'],
#  ['cell-biology', 'carbohydrates'],
#  ['botany', 'metabolism', 'plant-physiology', 'nutrition', 'amino-acids'],
#  ['physiology', 'pathology', 'endocrinology', 'homeostasis'],
#  ['human-biology', 'reproduction', 'development'],
#  ['human-biology', 'reproduction', 'endocrinology'],
#  ['human-biology', 'physiology', 'development'],
#  ['cell-biology'],
#  ['microbiology', 'theoretical-biology', 'growth', 'computational-model'],
#  ['microbiology', 'bacteriology'],
#  ['botany', 'plant-physiology'],
#  ['biochemistry', 'pharmacology', 'reference-request', 'pharmacodynamics'],
#  ['biochemistry', 'metabolism', 'photosynthesis'],
#  ['cell-biology', 'lab-reagents'],
#  ['ecology'],
#  ['neuroscience', 'brain'],
#  ['evolution', 'neuroscience', 'psychology'],
#  ['species-identification', 'reptile', 'herpetology', 'snake'],
#  ['genetics', 'homosexuality'],
#  ['pathophysiology', 'energy', 'cholesterol'],
#  ['cell-biology', 'meiosis', 'mitosis'],
#  ['biochemistry', 'metabolism', 'biophysics', 'temperature', 'heat'],
#  ['ecology', 'photosynthesis'],
#  ['biochemistry',
#   'molecular-biology',
#   'bioinformatics',
#   'botany',
#   'molecular-genetics'],
#  ['immunology', 'cancer', 'immunosuppression'],
#  ['molecular-biology', 'lab-techniques', 'pcr'],
#  ['bacteriology', 'antibiotics'],
#  ['evolution', 'bioinformatics', 'terminology', 'reference-request'],
#  ['terminology'],
#  ['biochemistry', 'bioinformatics', 'proteins', 'pdb'],
#  ['cancer', 'cell-signaling'],
#  ['proteins', 'amino-acids'],
#  ['neuroscience', 'theoretical-biology'],
#  ['cell-membrane', 'mitochondria', 'membrane-transport'],
#  ['entomology'],
#  ['sensation', 'senses', 'peripheral-nervous-system'],
#  ['human-biology', 'neurophysiology', 'sex', 'human-physiology'],
#  ['human-physiology', 'taste'],
#  ['botany', 'fruit', 'agriculture', 'vegetable'],
#  ['proteins'],
#  ['human-genetics', 'embryology', 'growth'],
#  ['hematology', 'stem-cells'],
#  ['biochemistry', 'proteins'],
#  ['human-biology', 'hydration'],
#  ['molecular-biology', 'mrna', 'microrna'],
#  ['toxicology', 'vitamins'],
#  ['enzymes'],
#  ['experimental-design', 'assay-development'],
#  ['cell-biology', 'dna', 'microbiology'],
#  ['human-biology', 'vitamins'],
#  ['dna', 'radiation'],
#  ['human-biology', 'digestive-system', 'immune-system', 'microbiome'],
#  ['bioinformatics', 'molecular-genetics'],
#  ['dna', 'transcription'],
#  ['evolution', 'human-evolution', 'immunity', 'immune-system'],
#  ['transcription', 'dna-replication'],
#  ['evolution', 'theoretical-biology', 'evolutionary-game-theory'],
#  ['human-biology', 'reproduction', 'development'],
#  ['human-biology', 'genetics', 'vision'],
#  ['neuroscience'],
#  ['life', 'astrobiology'],
#  ['cell-biology', 'organs'],
#  ['ornithology'],
#  ['life', 'astrobiology'],
#  ['cell-biology', 'endocrinology'],
#  ['human-biology',
#   'genetics',
#   'bacteriology',
#   'microbiome',
#   'biology-misconceptions'],
#  ['botany'],
#  ['genetics', 'bioinformatics', 'human-genetics'],
#  ['bioinformatics'],
#  ['biochemistry', 'chemistry'],
#  ['botany', 'species-identification', 'trees'],
#  ['entomology', 'ecology', 'behaviour', 'breathing', 'respiration'],
#  ['minerals'],
#  ['biochemistry', 'molecular-biology', 'botany', 'seeds', 'germination'],
#  ['human-biology', 'physiology', 'fat-metabolism', 'biology-misconceptions'],
#  ['ecology', 'food-web'],
#  ['genetics', 'botany', 'molecular-genetics', 'definitions', 'inheritance'],
#  ['zoology', 'palaeontology', 'lifespan'],
#  ['dna', 'dna-sequencing', 'sequence-analysis'],
#  ['dna', 'human-genome', 'crispr'],
#  ['human-biology', 'reflexes'],
#  ['botany', 'respiration'],
#  ['genetics',
#   'bioinformatics',
#   'molecular-genetics',
#   'drosophila',
#   'gene-annotation'],
#  ['human-biology', 'reference-request', 'fitness'],
#  ['botany',
#   'zoology',
#   'structural-biology',
#   'eukaryotic-cells',
#   'prokaryotic-cells'],
#  ['brain', 'food', 'central-nervous-system', 'saliva'],
#  ['trees'],
#  ['botany', 'taxonomy', 'phylogenetics'],
#  ['entomology', 'ethology', 'drosophila'],
#  ['evolution', 'bioenergetics'],
#  ['bacteriology', 'health', 'experimental', 'microbiome'],
#  ['bioinformatics', 'cell-membrane', 'database'],
#  ['biochemistry'],
#  ['brain', 'neurophysiology', 'sociality', 'injury'],
#  ['trees'],
#  ['bioinformatics', 'software', 'gene-annotation'],
#  ['evolution', 'adaptation', 'addiction'],
#  ['human-biology', 'behaviour'],
#  ['endocrinology', 'gynecology', 'menstrual-cycle'],
#  ['physiology', 'immunology', 'vaccination', 'immune-system'],
#  ['human-biology', 'cell-biology', 'neuroscience', 'neurophysiology', 'pain'],
#  ['evolution', 'zoology'],
#  ['human-biology', 'human-anatomy', 'endocrinology', 'development'],
#  ['gene', 'snp'],
#  ['cancer', 'microscopy', 'staining', 'image-processing'],
#  ['ecology', 'mammals', 'ecosystem', 'invasive-species'],
#  ['immunology', 'cardiology', 'gynecology'],
#  ['zoology', 'taxonomy', 'phylogenetics'],
#  ['gene-regulation', 'transcription-factor', 'prokaryotes'],
#  ['bioinformatics', 'sequence-alignment', 'blast'],
#  ['evolution', 'genetics', 'memory', 'general-biology'],
#  ['neuroscience', 'brain', 'neurophysiology', 'reference-request', 'synapses'],
#  ['population-biology', 'ichthyology'],
#  ['evolution', 'virus'],
#  ['molecular-biology', 'dna', 'pcr', 'primer', 'recombinant'],
#  ['enzymes', 'methods', 'assay-development'],
#  ['biochemistry', 'immunology', 'bacteriology', 'virology', 'immune-system'],
#  ['evolution'],
#  ['molecular-biology', 'cell-biology', 'bioinformatics', 'molecular-genetics'],
#  ['human-biology', 'pathology', 'infection'],
#  ['vision', 'human-eye'],
#  ['human-biology', 'breathing'],
#  ['metabolism', 'muscles', 'cellular-respiration'],
#  ['human-biology', 'zoology', 'pathology'],
#  ['dna'],
#  ['ornithology', 'pain', 'chickens', 'animal-husbandry'],
#  ['biochemistry',
#   'cell-biology',
#   'proteins',
#   'cell-membrane',
#   'membrane-transport'],
#  ['species-identification'],
#  ['ecology'],
#  ['plant-physiology'],
#  ['lab-techniques', 'gel-electrophoresis'],
#  ['virus', 'infection', 'ebola'],
#  ['biochemistry',
#   'molecular-biology',
#   'botany',
#   'microbiology',
#   'bacteriology'],
#  ['enzymes'],
#  ['cell-biology', 'cell-division'],
#  ['species-identification', 'entomology'],
#  ['human-biology', 'microbiology', 'virology', 'virus'],
#  ['bioinformatics', 'dna-sequencing'],
#  ['neuroscience', 'brain', 'biophysics', 'electroencephalography'],
#  ['botany', 'entomology', 'ecology', 'parasitism', 'symbiosis'],
#  ['parasitology'],
#  ['human-anatomy', 'mammals', 'anatomy', 'kidney'],
#  ['evolution', 'genetics', 'theoretical-biology', 'population-genetics'],
#  ['virus'],
#  ['genetics', 'gene-therapy'],
#  ['genetics', 'chromosome'],
#  ['bioinformatics', 'molecular-genetics', 'genomics', 'theoretical-biology'],
#  ['immunology', 'antibiotics', 'allergies', 'hypersensitivity'],
#  ['homework', 'digestive-system', 'gastroenterology'],
#  ['evolution'],
#  ['immunology', 'cancer'],
#  ['neuroscience', 'brain', 'neurotransmitter'],
#  ['bioinformatics', 'blast'],
#  ['botany'],
#  ['botany', 'plant-physiology', 'plant-anatomy'],
#  ['evolution', 'prion'],
#  ['molecular-biology', 'dna', 'light'],
#  ['evolutionary-game-theory', 'astrobiology'],
#  ['agriculture'],
#  ['lab-techniques', 'parasitology', 'lab-reagents'],
#  ['cell-biology', 'botany', 'zoology', 'gamete'],
#  ['neurophysiology',
#   'human-physiology',
#   'receptor',
#   'homeostasis',
#   'digestion'],
#  ['human-biology', 'brain', 'human-physiology', 'taste', 'gustation'],
#  ['evolution', 'genetics', 'population-genetics', 'population-biology'],
#  ['dna', 'experimental-design'],
#  ['bioinformatics', 'blast'],
#  ['brain', 'sleep', 'hearing'],
#  ['human-biology',
#   'immunology',
#   'hematology',
#   'reproductive-biology',
#   'blood-group'],
#  ['microbiology'],
#  ['molecular-biology', 'dna', 'gene-expression', 'transcription'],
#  ['genetics', 'zoology', 'eyes', 'dogs'],
#  ['botany', 'plant-anatomy'],
#  ['human-biology', 'hematology', 'history'],
#  ['biochemistry',
#   'proteins',
#   'protein-folding',
#   'protein-interaction',
#   'protein-structure'],
#  ['trees', 'global-warming'],
#  ['genetics', 'molecular-biology', 'receptor'],
#  ['meiosis', 'mitosis', 'polyploidy'],
#  ['metabolism', 'cellular-respiration', 'bioenergetics', 'glucose'],
#  ['evolution', 'natural-selection'],
#  ['human-biology', 'metabolism', 'blood-circulation', 'liver', 'alcohol'],
#  ['proteins', 'lab-techniques', 'protein-structure', 'xray-crystallography'],
#  ['neurology', 'surgery', 'electroencephalography', 'lymphatic'],
#  ['virology', 'virus'],
#  ['neurology', 'central-nervous-system', 'lymphatic'],
#  ['evolution', 'metabolism', 'ecology', 'extinction'],
#  ['human-genetics',
#   'chromosome',
#   'development',
#   'dna-replication',
#   'sex-chromosome'],
#  ['nucleic-acids'],
#  ['bioinformatics', 'transcription', 'snp', 'yeast', 'binding-sites'],
#  ['human-biology', 'human-anatomy', 'sexual-selection', 'milk', 'gender'],
#  ['biochemistry',
#   'microbiome',
#   'host-pathogen-interaction',
#   'bacterial-toxins',
#   'immune-system'],
#  ['food', 'nutrition', 'database', 'amino-acids'],
#  ['senescence', 'death', 'dna-damage'],
#  ['cardiology', 'human-physiology', 'health', 'fitness', 'biofeedback'],
#  ['neuroscience', 'neurophysiology', 'central-nervous-system'],
#  ['bioinformatics', 'dna-sequencing', 'sequence-analysis', 'microbiome'],
#  ['cancer', 'human-physiology', 'pathophysiology'],
#  ['microbiology', 'virology', 'virus', 'histopathology'],
#  ['biochemistry'],
#  ['immunology', 'allergies'],
#  ['evolution', 'natural-selection', 'species'],
#  ['evolution', 'genetics', 'terminology', 'mutations', 'population-genetics'],
#  ['metabolism', 'lipids', 'kinetics', 'cholesterol'],
#  ['genetics', 'cell-biology', 'gene-expression', 'eukaryotic-cells'],
#  ['food', 'mycology', 'mushroom'],
#  ['ornithology'],
#  ['zoology'],
#  ['human-anatomy', 'bone-biology'],
#  ['brain', 'neurology'],
#  ['molecular-biology', 'pain'],
#  ['biochemistry', 'yeast', 'pathogenesis', 'microbiome', 'alcohol'],
#  ['physiology', 'blood-circulation', 'kidney'],
#  ['biochemistry', 'molecular-biology', 'botany', 'carbohydrates'],
#  ['dna', 'digestion'],
#  ['species-identification', 'entomology'],
#  ['genetics', 'terminology'],
#  ['human-biology', 'skin', 'injury', 'surgery'],
#  ['brain'],
#  ['evolution'],
#  ['development', 'anatomy'],
#  ['evolution', 'genetics', 'physiology', 'homology'],
#  ['human-biology', 'genetics', 'stem-cells', 'reproductive-biology'],
#  ['microbiology',
#   'brain',
#   'pathology',
#   'neurology',
#   'neurodegerative-disorders'],
#  ['immunology', 'receptor', 'hiv', 'immune-system'],
#  ['eggs'],
#  ['red-blood-cell'],
#  ['neuroscience', 'learning'],
#  ['molecular-biology', 'dna', 'homework', 'pcr', 'gel-electrophoresis'],
#  ['immunology', 'hiv', 'aids'],
#  ['molecular-biology', 'dna', 'homework', 'stem-cells', 'transfection'],
#  ['terminology', 'history'],
#  ['dna',
#   'human-genetics',
#   'population-genetics',
#   'human-genome',
#   'human-evolution'],
#  ['evolution'],
#  ['proteins',
#   'homework',
#   'protein-binding',
#   'protein-folding',
#   'protein-interaction'],
#  ['human-biology', 'zoology', 'entomology'],
#  ['muscles', 'temperature'],
#  ['proteins', 'homework', 'rna', 'gel-electrophoresis', 'rna-interference'],
#  ['cancer', 'autoimmune', 'immunosuppression'],
#  ['anatomy'],
#  ['genetics', 'mouse'],
#  ['human-biology'],
#  ['zoology', 'taxonomy', 'classification'],
#  ['proteins',
#   'homework',
#   'protein-binding',
#   'protein-interaction',
#   'purification'],
#  ['cell-biology', 'zoology'],
#  ['bacteriology', 'antibiotics', 'antibiotic-resistance'],
#  ['development', 'anatomy'],
#  ['brain', 'pathology', 'neurology', 'neurodegerative-disorders'],
#  ['biochemistry', 'bioinformatics', 'proteins', 'biophysics', 'cell-membrane'],
#  ['human-biology', 'human-anatomy', 'bone-biology'],
#  ['hearing', 'senses'],
#  ['human-biology', 'zoology', 'human-anatomy', 'ornithology'],
#  ['genetics', 'population-genetics', 'genetic-linkage', 'fst'],
#  ['evolution', 'bioinformatics', 'theoretical-biology', 'computational-model'],
#  ['molecular-biology',
#   'proteins',
#   'protein-binding',
#   'protein-interaction',
#   'bio-mechanics'],
#  ['taxonomy', 'nomenclature', 'classification', 'biology-misconceptions'],
#  ['zoology'],
#  ['zoology', 'ethology', 'snake'],
#  ['eyes', 'light', 'optics'],
#  ['evolution'],
#  ['immunology'],
#  ['bioinformatics', 'rna'],
#  ['botany', 'homework', 'plant-physiology', 'seeds', 'germination'],
#  ['genetics', 'molecular-biology', 'molecular-genetics'],
#  ['species-identification', 'entomology'],
#  ['ethology', 'herpetology', 'antipredator-adaptation', 'snake'],
#  ['cancer'],
#  ['botany', 'fruit'],
#  ['biochemistry', 'pathway'],
#  ['virology', 'virus'],
#  ['human-biology', 'human-physiology'],
#  ['imaging'],
#  ['human-anatomy'],
#  ['behaviour'],
#  ['neuroscience', 'brain'],
#  ['hematology', 'mrna'],
#  ['bioluminescence'],
#  ['cancer', 'autoimmune', 'allergies'],
#  ['cell-biology'],
#  ['endocrinology', 'muscles'],
#  ['bioinformatics', 'protein-interaction'],
#  ['human-biology', 'human-anatomy', 'endocrinology', 'sexual-dimorphism'],
#  ['species', 'extinction'],
#  ['zoology', 'vision', 'eyes', 'sensory-systems'],
#  ['photosynthesis', 'agriculture', 'growth-media'],
#  ['dna-sequencing', 'genomes', 'human-genome'],
#  ['genetics', 'dna', 'crossover'],
#  ['neuroscience', 'measurement'],
#  ['genetics', 'evolution', 'speciation', 'eggs'],
#  ['evolution', 'artificial-life'],
#  ['dna-sequencing'],
#  ['biochemistry', 'nucleic-acids'],
#  ['zoology', 'species-identification', 'species', 'identification'],
#  ['biochemistry', 'organic-chemistry'],
#  ['metabolism'],
#  ['cell-biology', 'symbiosis'],
#  ['peripheral-nervous-system'],
#  ['medicine', 'skin', 'tissue', 'surgery'],
#  ['human-biology', 'endocrinology', 'human-physiology', 'pregnancy', 'gender'],
#  ['biochemistry', 'metabolism', 'respiration'],
#  ['biochemistry', 'photosynthesis'],
#  ['molecular-genetics', 'lab-techniques'],
#  ['evolution', 'artificial-life'],
#  ['bacteriology'],
#  ['cell-biology', 'meiosis', 'mitosis'],
#  ['sequence-analysis'],
#  ['evolution'],
#  ['ornithology', 'temperature'],
#  ['vision', 'neurophysiology', 'sensation', 'perception'],
#  ['bioenergetics'],
#  ['species'],
#  ['chemistry', 'membrane-transport', 'osmosis'],
#  ['evolution', 'bacteriology', 'classification'],
#  ['bioinformatics', 'sequence-analysis', 'nucleic-acids'],
#  ['species-identification',
#   'bacteriology',
#   'species-distribution',
#   'biofilms'],
#  ['hair'],
#  ['pathology'],
#  ['biochemistry'],
#  ['biochemistry', 'endocrinology', 'neurophysiology', 'inflammation'],
#  ['neuroscience',
#   'terminology',
#   'biophysics',
#   'electrophysiology',
#   'electrical-stimulation'],
#  ['zoology', 'species-identification', 'arachnology'],
#  ['genetics', 'molecular-genetics'],
#  ['genetics', 'biochemistry', 'molecular-biology'],
#  ['vision', 'neurophysiology'],
#  ['genetics', 'homework', 'inheritance'],
#  ['human-biology', 'molecular-biology', 'cell-biology'],
#  ['cardiology', 'circulatory-system'],
#  ['dna', 'primer'],
#  ['plant-anatomy'],
#  ['menstrual-cycle'],
#  ['genetics'],
#  ['bioinformatics'],
#  ['genetics'],
#  ['evolution', 'theoretical-biology', 'phylogenetics'],
#  ['genetics', 'inheritance'],
#  ['evolution', 'bioinformatics', 'phylogenetics', 'computational-model'],
#  ['human-biology', 'sleep'],
#  ['behaviour', 'animal-models', 'behavior'],
#  ['plant-physiology', 'vitamins'],
#  ['evolution', 'reproduction', 'ecology', 'life-history'],
#  ['genetics', 'molecular-biology', 'reproduction'],
#  ['taxonomy', 'species'],
#  ['cell-biology', 'dna', 'telomere', 'dna-damage'],
#  ['neuroscience', 'neuroanatomy'],
#  ['biochemistry'],
#  ['ecology', 'theoretical-biology', 'landscape-ecology'],
#  ['proteins', 'sds-page'],
#  ['biochemistry', 'enzymes', 'enzyme-kinetics'],
#  ['cell-biology', 'gene-expression', 'differentiation'],
#  ['homework', 'immunity'],
#  ['genetics', 'evolution'],
#  ['cell-biology', 'meiosis', 'cell-division'],
#  ['bioinformatics', 'dna', 'theoretical-biology', '3d-structure'],
#  ['brain'],
#  ['genetics', 'homework', 'inheritance'],
#  ['terminology', 'biogeography'],
#  ['neurophysiology'],
#  ['vitamins', 'definitions'],
#  ['neuroscience', 'vision', 'perception'],
#  ['physiology', 'vision', 'eyes'],
#  ['biochemistry', 'microbiology', 'bacteriology', 'immune-system'],
#  ['human-genetics'],
#  ['dna'],
#  ['molecular-biology', 'bioinformatics', 'database'],
#  ['endocrinology'],
#  ['evolution', 'human-anatomy', 'development', 'anatomy'],
#  ['sequence-analysis', 'software', 'nucleic-acids', 'transcription-factor'],
#  ['evolution', 'natural-selection'],
#  ['evolution', 'zoology', 'bio-mechanics'],
#  ['zoology', 'species-identification'],
#  ['electrophysiology', 'electromuscular'],
#  ['nomenclature', 'gene'],
#  ['microbiology', 'bacteriology'],
#  ['biochemistry', 'nutrition'],
#  ['biochemistry', 'blood-group'],
#  ['vision'],
#  ['cancer', 'tcga'],
#  ['biochemistry', 'proteins', 'ichthyology'],
#  ['cell-biology', 'cell-culture'],
#  ['human-biology', 'cell-biology', 'mitosis', 'cell-division', 'cell-cycle'],
#  ['yeast', 'fermentation'],
#  ['biochemistry', 'botany', 'homework', 'plant-physiology', 'photosynthesis'],
#  ['human-biology', 'genetics', 'cell-biology', 'dna', 'molecular-genetics'],
#  ['human-anatomy'],
#  ['zoology', 'food'],
#  ['molecular-genetics',
#   'rna-sequencing',
#   'histone',
#   'chip',
#   'histone-modifications'],
#  ['population-biology'],
#  ['cell-biology', 'mitosis', 'cell-cycle'],
#  ['genetics'],
#  ['human-biology', 'physiology', 'blood-circulation'],
#  ['immunology', 'antibody', 'immune-system'],
#  ['dna', 'molecular-genetics', 'transcription'],
#  ['cell-biology', 'electrophysiology', 'ph'],
#  ['sequence-alignment', 'ncbi'],
#  ['bioinformatics', 'database', 'gene', 'snp'],
#  ['cell-biology', 'cytoskeleton'],
#  ['genetics', 'dna', 'dna-replication'],
#  ['genetics', 'cell-biology', 'molecular-genetics', 'pathology'],
#  ['biochemistry', 'protein-binding', 'assay-development'],
#  ['cell-biology', 'immunology', 'immune-system'],
#  ['genetics', 'microbiology', 'dna-sequencing'],
#  ['homework', 'population-genetics'],
#  ['human-biology', 'human-physiology'],
#  ['dna-isolation'],
#  ['electrical-stimulation', 'neuromodulation', 'neural-engineering'],
#  ['botany', 'species-identification', 'trees'],
#  ['human-biology', 'biochemistry', 'cell-biology', 'metabolism'],
#  ['microbiology', 'antibiotics'],
#  ['human-biology', 'human-anatomy'],
#  ['genetics',
#   'biochemistry',
#   'molecular-biology',
#   'cell-biology',
#   'neuroscience'],
#  ['dna', 'dna-replication'],
#  ['cancer', 'nomenclature'],
#  ['ecology', 'ethology', 'behaviour', 'predation'],
#  ['bioinformatics', 'database', 'software'],
#  ['molecular-biology', 'proteins', 'homework', 'receptor', 'insulin'],
#  ['bioinformatics', 'gene-expression'],
#  ['genetics',
#   'biochemistry',
#   'molecular-biology',
#   'cell-biology',
#   'neuroscience'],
#  ['cell-biology', 'mitosis', 'energy'],
#  ['dna', 'organs', 'transplantation'],
#  ['microbiology', 'bacteriology'],
#  ['genetics', 'homework', 'molecular-genetics', 'gene'],
#  ['senescence'],
#  ['cancer', 'pathology', 'treatment'],
#  ['biochemistry', 'botany', 'zoology'],
#  ['homework', 'plant-anatomy'],
#  ['bioinformatics', 'ecology', 'theoretical-biology'],
#  ['human-biology', 'evolution'],
#  ['dna', 'mrna', 'dna-replication', 'splicing', 'introns'],
#  ['reproduction', 'behavior'],
#  ['biochemistry', 'enzymes', 'biotechnology'],
#  ['evolution'],
#  ['biochemistry'],
#  ['cell-biology',
#   'neuroscience',
#   'neurophysiology',
#   'neurodegerative-disorders'],
#  ['biochemistry', 'mitochondria', 'phosphorylation'],
#  ['species-identification', 'entomology'],
#  ['biochemistry'],
#  ['evolution', 'natural-selection', 'speciation'],
#  ['neuroscience', 'brain', 'neurophysiology'],
#  ['biochemistry', 'proteins', 'enzymes'],
#  ['biochemistry'],
#  ['cancer'],
#  ['cancer'],
#  ['biochemistry', 'movement'],
#  ['genetics', 'dna'],
#  ['cardiology'],
#  ['genetics', 'reproduction'],
#  ['human-biology', 'molecular-biology', 'neuroscience', 'psychophysics'],
#  ['botany'],
#  ['brain', 'human-ear', 'language'],
#  ['protein-folding', 'protein-interaction', 'pdb'],
#  ['human-anatomy', 'brain'],
#  ['cancer'],
#  ['epidemiology', 'hiv'],
#  ['gene', 'gene-regulation', 'network'],
#  ['botany', 'biosynthesis'],
#  ['identification'],
#  ['biochemistry', 'botany', 'plant-physiology', 'photosynthesis'],
#  ['virus'],
#  ['dna'],
#  ['genetics', 'homework', 'pathology'],
#  ['biochemistry'],
#  ['proteins', 'toxicology'],
#  ['evolution', 'zoology', 'ethology', 'behavior'],
#  ['human-biology', 'immunology', 'immune-system', 'lymphatic'],
#  ['zoology', 'entomology', 'ethology', 'sensation'],
#  ['human-anatomy', 'anatomy', 'bone-biology', 'joints'],
#  ['dna-sequencing', 'pcr', 'blast'],
#  ['human-biology', 'pharmacology', 'medicinal-chemistry'],
#  ['zoology', 'life-history', 'central-nervous-system'],
#  ['zoology', 'food'],
#  ['zoology', 'brain', 'central-nervous-system', 'senses', 'sensory-systems'],
#  ['biochemistry', 'physiology', 'cardiology', 'senescence', 'imaging'],
#  ['bioinformatics'],
#  ['lab-techniques'],
#  ['evolution', 'zoology', 'anatomy'],
#  ['biochemistry', 'entomology', 'biophysics', 'anatomy'],
#  ['proteins', 'purification'],
#  ['cell-biology', 'respiration'],
#  ['plant-physiology', 'plant-anatomy'],
#  ['senescence', 'hair'],
#  ['genetics', 'human-genetics', 'population-genetics'],
#  ['evolution', 'biochemistry', 'botany', 'plant-physiology'],
#  ['human-biology'],
#  ['genetics', 'biochemistry', 'molecular-biology', 'dna', 'bioinformatics'],
#  ['definitions'],
#  ['biochemistry', 'enzymes'],
#  ['biochemistry', 'molecular-biology', 'toxicology'],
#  ['ecology', 'species', 'species-distribution'],
#  ['bio-mechanics'],
#  ['food', 'psychology', 'health', 'taste', 'children'],
#  ['pharmacology', 'enzymes', 'aspirin'],
#  ['botany'],
#  ['neuroscience', 'neurophysiology', 'neurotransmitter'],
#  ['neuroscience', 'vision', 'neurophysiology'],
#  ['bioinformatics', 'database', 'biopython'],
#  ['cell-biology', 'tissue'],
#  ['cell-biology', 'organs', 'tissue'],
#  ['proteins', 'hematology', 'digestive-system', 'liver'],
#  ['human-evolution'],
#  ['metabolism', 'tissue'],
#  ['cell-biology',
#   'cell-membrane',
#   'homeostasis',
#   'kidney',
#   'membrane-transport'],
#  ['biochemistry', 'enzymes'],
#  ['biochemistry', 'zoology'],
#  ['digestive-system'],
#  ['human-biology', 'microbiology', 'reference-request'],
#  ['synthetic-biology'],
#  ['endocrinology', 'terminology'],
#  ['molecular-biology'],
#  ['molecular-biology'],
#  ['evolution', 'food', 'nutrition', 'perception', 'taste'],
#  ['human-biology', 'virus', 'death'],
#  ['species-identification', 'invertebrates'],
#  ['human-biology'],
#  ['biochemistry', 'neuroscience'],
#  ['biochemistry', 'hair', 'bio-mechanics', 'biomedical-engineering'],
#  ['gastroenterology', 'immune-system', 'influenza'],
#  ['vitamins', 'dna-damage'],
#  ['taxonomy', 'nomenclature'],
#  ['genetics'],
#  ['plant-anatomy'],
#  ['biochemistry', 'enzyme-kinetics', 'kinetics', 'units'],
#  ['bioinformatics', 'sequence-alignment'],
#  ['evolution'],
#  ['cancer', 'mutations', 'mammals'],
#  ['dna-sequencing'],
#  ['microbiology', 'prokaryotic-cells'],
#  ['microbiology'],
#  ['dna-sequencing', 'rna-sequencing'],
#  ['neuroscience', 'brain', 'development', 'neurology', 'synapses'],
#  ['immunology', 'vaccination'],
#  ['bioinformatics', 'microbiology'],
#  ['genetics'],
#  ['human-biology', 'physiology', 'eyes', 'human-eye', 'human-physiology'],
#  ['bioinformatics', 'blast'],
#  ['ichthyology'],
#  ['bioinformatics', 'dna'],
#  ['human-biology', 'biochemistry', 'cell-biology', 'cell-signaling'],
#  ['human-biology', 'genetics', 'cell-biology', 'terminology'],
#  ['genetics', 'theoretical-biology', 'inheritance'],
#  ['human-anatomy', 'definitions', 'bone-biology'],
#  ['human-biology', 'hearing', 'human-ear', 'learning'],
#  ['metabolism', 'cancer'],
#  ['genetics', 'dna-sequencing', 'genomics', 'restriction-enzymes'],
#  ['entomology', 'mammals'],
#  ['palaeontology'],
#  ['skin', 'human-physiology', 'health', 'light', 'uv'],
#  ['development', 'embryology'],
#  ['entomology', 'ecology', 'neurology', 'cognition', 'behavior'],
#  ['radiation'],
#  ['genetics', 'evolution', 'dna'],
#  ['human-biology', 'eyes', 'human-eye'],
#  ['genetics'],
#  ['biophysics'],
#  ['evolution', 'macroevolution'],
#  ['human-biology', 'molecular-biology', 'immunology', 'autoimmune'],
#  ['cell-biology', 'hematology', 'biophysics', 'blood-circulation'],
#  ['development'],
#  ['embryology', 'cloning', 'cytogenetics', 'developmental-biology'],
#  ['natural-selection', 'malaria'],
#  ['zoology'],
#  ['molecular-biology', 'molecular-evolution'],
#  ['stem-cells'],
#  ['photosynthesis', 'cellular-respiration', 'energy', 'sugar'],
#  ['virus', 'infection'],
#  ['human-biology', 'bacteriology', 'medicine'],
#  ['botany', 'electrical-stimulation'],
#  ['cell-biology', 'symbiosis'],
#  ['molecular-genetics', 'dna-sequencing', 'biomedical-engineering'],
#  ['genetics', 'molecular-genetics'],
#  ['zoology'],
#  ['botany'],
#  ['pathology', 'hiv'],
#  ['saliva'],
#  ['genetics', 'molecular-genetics'],
#  ['cell-biology', 'antibody'],
#  ['biochemistry'],
#  ['physiology', 'zoology', 'ichthyology'],
#  ['evolution'],
#  ['botany', 'taxonomy'],
#  ['melanin'],
#  ['pcr', 'dna-isolation'],
#  ['cell-biology'],
#  ['virus'],
#  ['adaptation'],
#  ['cell-biology', 'microbiology', 'bacteriology'],
#  ['human-biology', 'senses', 'olfaction', 'nose', 'chemical-communication'],
#  ['terminology', 'anatomy'],
#  ['evolution',
#   'biochemistry',
#   'molecular-biology',
#   'molecular-genetics',
#   'molecular-evolution'],
#  ['human-biology', 'molecular-biology', 'hiv', 'nucleic-acids'],
#  ['genetics'],
#  ['homework', 'kidney'],
#  ['ornithology', 'temperature'],
#  ['immunology', 'virus', 'vaccination', 'immune-system', 'influenza'],
#  ['gene-expression', 'red-blood-cell', 'pathway', 'differentiation'],
#  ['biochemistry', 'molecular-biology'],
#  ['molecular-biology'],
#  ['human-biology'],
#  ['physiology', 'digestion'],
#  ['genetics', 'molecular-biology', 'molecular-genetics', 'synthetic-biology'],
#  ['eyes'],
#  ['lab-techniques', 'lab-reagents'],
#  ['dna-sequencing'],
#  ['human-biology', 'cell-culture', 'skin'],
#  ['eyes', 'human-eye', 'human-evolution'],
#  ['genetics'],
#  ['embryology'],
#  ['evolution', 'botany', 'epigenetics', 'growth', 'trees'],
#  ['embryology'],
#  ['dna', 'dna-sequencing', 'biotechnology'],
#  ['antibiotics', 'microbiome'],
#  ['microbiology', 'death', 'homeostasis', 'extremophiles'],
#  ['dna'],
#  ['microbiology', 'virus', 'environment'],
#  ['cell-culture', 'infection', 'parasitology', 'pathogenesis'],
#  ['cell-biology'],
#  ['homework', 'lab-techniques', 'cell-membrane'],
#  ['photosynthesis', 'respiration'],
#  ['eyes', 'ornithology', 'behaviour', 'collective-behaviour'],
#  ['genetics', 'homework'],
#  ['pcr'],
#  ['human-biology', 'virus'],
#  ['ecology', 'ichthyology'],
#  ['botany'],
#  ['human-biology'],
#  ['plant-physiology', 'photosynthesis', 'organic-chemistry'],
#  ['metabolism', 'cancer'],
#  ['genetics', 'dna', 'reproduction', 'human-genetics', 'development'],
#  ['metabolism', 'diabetes-mellitus', 'insulin', 'blood-sugar'],
#  ['immunology', 'bacteriology', 'antibiotics'],
#  ['physiology'],
#  ['human-biology', 'human-anatomy'],
#  ['cell-biology', 'homework', 'life', 'death'],
#  ['biochemistry',
#   'dna',
#   'molecular-evolution',
#   'dna-replication',
#   'prokaryotes'],
#  ['muscles', 'fitness'],
#  ['learning', 'instinct'],
#  ['physiology', 'metabolism', 'endocrinology', 'carbohydrates'],
#  ['biotechnology', 'recombination'],
#  ['human-biology', 'eyes', 'adaptation'],
#  ['evolution', 'cell-biology', 'eukaryotic-cells', 'prokaryotic-cells'],
#  ['evolution', 'cell-biology'],
#  ['biochemistry'],
#  ['neuroscience', 'vision', 'eyes', 'neurophysiology'],
#  ['organic-chemistry', 'seeds'],
#  ['human-physiology'],
#  ['genetics',
#   'human-genetics',
#   'population-genetics',
#   'statistics',
#   'inheritance'],
#  ['endocrinology', 'behaviour', 'children'],
#  ['botany', 'taxonomy'],
#  ['molecular-biology'],
#  ['species-identification', 'entomology'],
#  ['human-biology',
#   'genetics',
#   'evolution',
#   'molecular-biology',
#   'molecular-genetics'],
#  ['genetics', 'molecular-biology', 'molecular-genetics'],
#  ['genetics', 'dna', 'statistics'],
#  ['nucleic-acids'],
#  ['molecular-biology', 'proteins', 'microbiology', 'lipids', 'carbohydrates'],
#  ['biochemistry', 'rna-sequencing', 'nucleic-acids'],
#  ['biochemistry', 'fat-metabolism', 'carbohydrates'],
#  ['human-biology', 'cell-biology', 'physiology', 'medicine'],
#  ['ichthyology', 'gender'],
#  ['human-biology', 'brain', 'health'],
#  ['human-anatomy', 'cardiology', 'ventricles'],
#  ['microbiology', 'lab-techniques', 'transcription-factor'],
#  ['vision', 'neurophysiology', 'human-eye'],
#  ['skin'],
#  ['biochemistry'],
#  ['biochemistry', 'cell-biology', 'pharmacology'],
#  ['lab-techniques', 'pcr'],
#  ['genetics', 'definitions'],
#  ['brain', 'electrophysiology', 'electroencephalography', 'signal-processing'],
#  ['human-biology'],
#  ['neurophysiology', 'neurodegerative-disorders'],
#  ['cell-biology'],
#  ['human-biology', 'neuroscience', 'blood-pressure'],
#  ['pharmacology'],
#  ['biochemistry', 'kinetics'],
#  ['human-biology', 'biochemistry'],
#  ['cardiology', 'gynecology'],
#  ['pathology', 'death'],
#  ['pcr', 'cloning'],
#  ['bioinformatics', 'pdb', 'xray-crystallography'],
#  ['entomology', 'ethology'],
#  ['brain'],
#  ['evolution', 'data', 'methods', 'macroevolution'],
#  ['botany'],
#  ['human-biology',
#   'human-physiology',
#   'reproductive-biology',
#   'sexual-reproduction'],
#  ['molecular-biology', 'cell-biology', 'proteins', 'rna', 'mrna'],
#  ['terminology'],
#  ['pcr', 'primer'],
#  ['cell-biology'],
#  ['cell-biology'],
#  ['human-biology', 'respiration'],
#  ['bioinformatics', 'image-processing'],
#  ['genetics', 'bioinformatics'],
#  ['botany', 'entomology', 'conservation-biology', 'waste-disposal'],
#  ['radiation', 'research-process'],
#  ['food', 'nutrition', 'food-web'],
#  ['human-biology',
#   'electrophysiology',
#   'electrocardiography',
#   'methods',
#   'signal-processing'],
#  ['genetics'],
#  ['mammals'],
#  ['human-biology', 'mycology', 'human-physiology'],
#  ['eyes', 'light'],
#  ['evolution', 'cancer', 'ecology', 'growth'],
#  ['microbiology', 'yeast', 'growth-media'],
#  ['genetics', 'book-recommendation', 'sexual-selection'],
#  ['virus', 'vaccination'],
#  ['cell-biology', 'microrna'],
#  ['metabolism', 'cancer', 'cell-culture'],
#  ['human-biology', 'death'],
#  ['electrophysiology', 'methods', 'electroencephalography'],
#  ['botany', 'plant-physiology'],
#  ['human-biology', 'evolution', 'zoology'],
#  ['human-eye'],
#  ['cell-biology'],
#  ['evolution'],
#  ['biochemistry',
#   'cell-biology',
#   'botany',
#   'plant-physiology',
#   'photosynthesis'],
#  ['human-eye', 'human-evolution', 'fitness'],
#  ['genetics', 'evolution', 'species-identification', 'development'],
#  ['pathology', 'virology', 'medicine', 'cell-division'],
#  ['species-identification', 'bioluminescence'],
#  ['neuroscience', 'brain', 'electroencephalography'],
#  ['proteins', 'cell-membrane', 'human-physiology', 'membrane-transport'],
#  ['ornithology', 'ethology'],
#  ['biochemistry', 'molecular-biology', 'cell-biology', 'microbiology'],
#  ['genetics', 'theoretical-biology', 'inheritance'],
#  ['biochemistry', 'photosynthesis', 'glucose'],
#  ['botany', 'classification'],
#  ['genetics'],
#  ['sexual-dimorphism'],
#  ['ecology', 'extinction', 'malaria'],
#  ['genetics', 'evolution', 'species', 'horizontal-gene-transfer'],
#  ['genetics', 'molecular-genetics', 'mutations'],
#  ['human-physiology', 'osmosis'],
#  ['immunology', 'pathology'],
#  ['biochemistry', 'bioinformatics', 'protein-folding', 'protein-structure'],
#  ['growth'],
#  ['evolution', 'mammals'],
#  ['taxonomy', 'phylogenetics'],
#  ['gene-expression', 'chip-seq'],
#  ['immunology', 'transcription', 'transcription-factor'],
#  ['zoology', 'mammals'],
#  ['neuroscience', 'mammals', 'behavior'],
#  ['human-biology'],
#  ['cell-biology', 'cell-division'],
#  ['cell-biology', 'cell-division'],
#  ['genetics', 'mammals'],
#  ['bioinformatics'],
#  ['biochemistry', 'bioinformatics', 'protein-structure'],
#  ['physiology', 'plant-physiology', 'biophysics'],
#  ['bioinformatics',
#   'proteins',
#   'protein-folding',
#   'computational-model',
#   'protein-structure'],
#  ['human-biology', 'cell-biology'],
#  ['human-biology', 'blood-circulation'],
#  ['human-biology', 'breathing', 'heart-output'],
#  ['dna', 'polymerase', 'dnapolymerase'],
#  ['biochemistry', 'proteins', 'protein-folding', 'protein-structure'],
#  ['neuroscience', 'biophysics'],
#  ['human-biology', 'physiology', 'psychology'],
#  ['human-biology', 'blood-circulation'],
#  ['human-biology', 'brain', 'pathology', 'terminology'],
#  ['physiology', 'proteins', 'virus'],
#  ['neuroscience'],
#  ['botany', 'food', 'plant-anatomy'],
#  ['biochemistry', 'microbiology', 'bacteriology', 'environment'],
#  ['mitochondria', 'chloroplasts'],
#  ['biochemistry', 'nomenclature', 'amino-acids'],
#  ['neuroscience', 'neuroanatomy', 'autonomic-nervous-system'],
#  ['cell-biology', 'cancer', 'experimental-design', 'reference-request'],
#  ['proteins', 'gel-electrophoresis'],
#  ['molecular-biology', 'dna-sequencing'],
#  ['proteins', 'biosynthesis'],
#  ['nutrition', 'reference-request', 'health'],
#  ['antigen'],
#  ['species-identification'],
#  ['bioinformatics'],
#  ['pcr'],
#  ['botany', 'species-identification', 'dendrology'],
#  ['cell-culture', 'mouse'],
#  ['molecular-biology', 'systems-biology'],
#  ['human-biology'],
#  ['vaccination', 'immune-system'],
#  ['sleep'],
#  ['human-biology', 'kidney', 'osmoregulation'],
#  ['cardiology', 'action-potential'],
#  ['molecular-biology', 'dna-isolation', 'restriction-enzymes'],
#  ['molecular-biology'],
#  ['genetics',
#   'evolution',
#   'natural-selection',
#   'sexual-selection',
#   'sexual-dimorphism'],
#  ['physiology', 'zoology', 'entomology', 'hematology', 'parasitology'],
#  ['osmoregulation'],
#  ['cell-biology', 'zoology', 'entomology', 'toxicology', 'chemistry'],
#  ['human-biology', 'evolution'],
#  ['brain', 'electroencephalography'],
#  ['entomology', 'arachnology'],
#  ['biochemistry', 'underwater'],
#  ['physiology', 'kidney'],
#  ['human-biology'],
#  ['lab-techniques', 'cell-culture', 'mycology', 'sterilisation'],
#  ['human-biology', 'molecular-biology', 'cell-biology'],
#  ['taxonomy', 'phylogenetics', 'trees', 'network'],
#  ['human-biology', 'molecular-biology', 'cell-biology'],
#  ['physiology', 'invertebrates'],
#  ['reproduction', 'population-dynamics', 'pregnancy', 'children'],
#  ['genetics', 'genetic-linkage'],
#  ['neuroscience', 'pathology', 'human-genetics', 'neurology'],
#  ['taxonomy', 'ornithology', 'species'],
#  ['biochemistry', 'proteins', 'neurophysiology', 'electrophysiology'],
#  ['biochemistry', 'physiology', 'metabolism', 'energy'],
#  ['human-biology', 'human-anatomy'],
#  ['cardiology', 'psychology'],
#  ['biochemistry', 'homework', 'amino-acids'],
#  ['brain', 'development', 'mammals'],
#  ['cardiology', 'electrocardiography', 'signal-processing', 'heart-output'],
#  ['biochemistry', 'proteins'],
#  ['biochemistry'],
#  ['human-biology', 'evolution'],
#  ['zoology', 'population-genetics', 'population-dynamics', 'extinction'],
#  ['food', 'cell-membrane', 'digestion', 'membrane-transport'],
#  ['climate-change', 'phenology'],
#  ['genetics',
#   'molecular-biology',
#   'dna',
#   'molecular-genetics',
#   'dna-replication'],
#  ['genetics',
#   'molecular-biology',
#   'dna',
#   'molecular-genetics',
#   'transcription'],
#  ['genetics', 'human-genetics', 'sequence-analysis'],
#  ['biophysics',
#   'electrophysiology',
#   'methods',
#   'electroencephalography',
#   'signal-processing'],
#  ['neuroscience',
#   'electrophysiology',
#   'electroencephalography',
#   'signal-processing'],
#  ['definitions'],
#  ['entomology', 'pathology', 'parasitology'],
#  ['nutrition', 'fruit'],
#  ['microarray'],
#  ['neurophysiology', 'muscles', 'peripheral-nervous-system'],
#  ['reproduction', 'gamete'],
#  ['neuroscience', 'neurophysiology'],
#  ['botany'],
#  ['human-biology', 'zoology', 'brain'],
#  ['genetics', 'codon'],
#  ['human-biology', 'reflexes'],
#  ...]

# %%
mlb = MultiLabelBinarizer(classes=sorted(tags_counts.keys()))
y_train = mlb.fit_transform(y_train)
y_val = mlb.fit_transform(y_val)

# %%
y_train.shape
# Out:
# (11500, 659)

# %% [markdown]
# Train the classifiers for different data transformations: *bag-of-words* and *tf-idf*.

# %%
# %%time
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression, RidgeClassifier
clf = OneVsRestClassifier(RidgeClassifier(normalize=True))
clf.fit(X_train_tfidf, y_train)
# classifier_tfidf = train_classifier(X_train_tfidf, y_train)

# %% [markdown]
# Now you can create predictions for the data. You will need two types of predictions: labels and scores.

# %%
# %%time
y_val_predicted_labels_tfidf = clf.predict(X_val_tfidf)
# y_val_predicted_scores_tfidf = classifier_tfidf.decision_function(X_val_tfidf)

# %% [markdown]
# Now take a look at how classifier, which uses TF-IDF, works for a few examples:

# %%
que = ['Refer to Ran-GEF as a coenzyme?','What is a stick of butter?','how to do tadka in daal?', 'how to make chocolate brownie?']
que = [text_prepare(i) for i in que]
# que = [que]
que = tfidf_vectorizer.transform(que)
yp = clf.predict(que)
print(mlb.inverse_transform(yp))
# Out:
# [('pasta',), ('butter',), (), ('baking', 'brownies', 'chocolate')]

# %%
import pickle
import os 
pickle.dump(clf, open('model-cooking.pkl', 'wb'))
pickle.dump(mlb, open('tags-cooking.pkl', 'wb'))
pickle.dump(tfidf_vectorizer, open('tf-coking.pkl', 'wb'))
