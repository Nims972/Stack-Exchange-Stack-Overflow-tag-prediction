# %%
import nltk
#nltk.download('stopwords')
from ast import literal_eval
import pandas as pd
import numpy as np
from nltk.corpus import stopwords

# %%
def read_data(filename):
    data = pd.read_csv(filename, sep='\t')
    data['tags'] = data['tags'].apply(literal_eval)
    return data

# %%
tmp = pd.read_csv('cooking.csv')
#train = read_data('cooking.csv')
#validation = read_data('validation.tsv')
#test = pd.read_csv('test.tsv', sep='\t')

# %%
test = tmp.tail(3904)
train = tmp.head(11500)
validation = tmp.head(11500).tail(1500)

# %%
validation.head()
# Out:
#           id                                              title  \
# 10000  45870  What is the most cost effective way at home to...
# 10001  45871         Pork chops: low and slow or high and fast?
# 10002  45872  Can you make nut butters without dehydrating n...
# 10003  45878                Why commercial gummies do not melt?
# 10004  45882  Will a grill pan reduce oil splatter when pan-...
#
#                                                  content  \
# 10000  <p>I have recently been looking to make some n...
# 10001  <p>How hot/long should I bake my porkchops (bo...
# 10002  <p>It's normally recommended to soak nuts, the...
# 10003  <p>I've noticed that commercial gummies do not...
# 10004  <p>I have recently started cooking steaks at h...
#
#                                       tags
# 10000         nuts dehydrating nut-butters
# 10001                          baking pork
# 10002                     nuts nut-butters
# 10003  food-science gelatin gelling-agents
# 10004                              oil pan

# %%
train.head()
# Out:
#    id                                              title  \
# 0   1        How can I get chewy chocolate chip cookies?
# 1   2                How should I cook bacon in an oven?
# 2   3  What is the difference between white and brown...
# 3   4  What is the difference between baking soda and...
# 4   5  In a tomato sauce recipe, how can I cut the ac...
#
#                                              content  \
# 0  <p>My chocolate chips cookies are always too c...
# 1  <p>I've heard of people cooking bacon in an ov...
# 2  <p>I always use brown extra large eggs, but I ...
# 3  <p>And can I use one in place of the other in ...
# 4  <p>It seems that every time I make a tomato sa...
#
#                                                 tags
# 0                             baking cookies texture
# 1                            oven cooking-time bacon
# 2                                               eggs
# 3  substitutions please-remove-this-tag baking-so...
# 4               sauce pasta tomatoes italian-cuisine

# %%
test.head()
# Out:
#           id                                              title  \
# 11500  54965    substitute for shiso leaf in umeboshi makizushi
# 11501  54967  Why did my pork center cut loin turn out tende...
# 11502  54968       Is this chicken safe? silkie chicken edition
# 11503  54972                                 Cookie dough crust
# 11504  54974                     Getting seasoning into a roast
#
#                                                  content  \
# 11500  <p>I would like to make umeboshi makizushi, bu...
# 11501  <p>Why did my pork center cut loin turn out te...
# 11502  <p>First off, I am a pastry chef, and my first...
# 11503  <p>I want to make a dessert using a sugar cook...
# 11504  <p>I'm getting into braising a lot of pork and...
#
#                                        tags
# 11500  substitutions japanese-cuisine sushi
# 11501                                  pork
# 11502     food-safety chicken asian-cuisine
# 11503                                baking
# 11504                        roast braising

# %%
X_train, y_train = train['title'].values, train['tags'].values
X_val, y_val = validation['title'].values, validation['tags'].values
X_test = test['title'].values

# %%
y_train[1]
# Out:
# 'oven cooking-time bacon'

# %%
import re

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))

def text_prepare(text):
    text = text.lower()
    text = REPLACE_BY_SPACE_RE.sub(' ', text)
    text = BAD_SYMBOLS_RE.sub('', text)
    text = ' '.join(word for word in text.split() if word not in STOPWORDS)
    #print(text)
    return text

# %%
# prepared_questions = []
# for line in open('text_prepare_tests.tsv', encoding='utf-8'):
#     line = text_prepare(line.strip())
#     prepared_questions.append(line)
# text_prepare_results = '\n'.join(prepared_questions)

# %%
X_train = [text_prepare(x) for x in X_train]
X_val = [text_prepare(x) for x in X_val]
X_test = [text_prepare(x) for x in X_test]

# %%
y_train[:3]
# Out:
# array(['baking cookies texture', 'oven cooking-time bacon', 'eggs'],
#       dtype=object)

# %%
from collections import defaultdict
tags_counts = defaultdict(int)
words_counts = defaultdict(int)
tmp=[]

for tags in y_train:
    tt = tags.split()
    tmp.append(tt)
    for tag in tt:
        #print(tag)
        tags_counts[tag] += 1
y_train=tmp
tmp=[]

for text in X_train:
    for word in text.split():
        #print(word)
        words_counts[word] += 1
        
for tags in y_val:
    tt = tags.split()
    tmp.append(tt)
    for tag in tt:
        #print(tag)
        tags_counts[tag] += 1
y_val=tmp
tmp=[]
for text in X_val:
    for word in text.split():
        #print(word)
        words_counts[word] += 1

# %%
most_common_tags = sorted(tags_counts.items(), key=lambda x: x[1], reverse=True)[:10]
most_common_words = sorted(words_counts.items(), key=lambda x: x[1], reverse=True)[:3]

# %%
most_common_words
# Out:
# [('make', 888), ('cooking', 590), ('use', 536)]

# %%
most_common_tags
# Out:
# [('baking', 1202),
#  ('food-safety', 946),
#  ('substitutions', 780),
#  ('equipment', 710),
#  ('bread', 572),
#  ('chicken', 430),
#  ('storage-method', 419),
#  ('eggs', 356),
#  ('meat', 343),
#  ('cake', 339)]

# %%
from scipy import sparse as sp_sparse
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
??TfidVectorizer
# Out:
# Object `TfidVectorizer` not found.

# %%
#X_val

# %%
tfidf_vectorizer = TfidfVectorizer(min_df=5, max_df=0.9, ngram_range=(1, 2),token_pattern='(\S+)')
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_val_tfidf = tfidf_vectorizer.transform(X_val)
X_test_tfidf = tfidf_vectorizer.transform(X_test)
tfidf_vocab = tfidf_vectorizer.vocabulary_
#X_train_tfidf, X_val_tfidf, X_test_tfidf, tfidf_vocab = tfidf_features(X_train, X_val, X_test)

# %%
tfidf_reversed_vocab = {i:word for word,i in tfidf_vocab.items()}

# %%
tfidf_vocab['make']
# Out:
# 1270

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# %%
tags_counts.keys()
# Out:
# dict_keys(['baking', 'cookies', 'texture', 'oven', 'cooking-time', 'bacon', 'eggs', 'substitutions', 'please-remove-this-tag', 'baking-soda', 'baking-powder', 'sauce', 'pasta', 'tomatoes', 'italian-cuisine', 'herbs', 'parsley', 'food-safety', 'beef', 'basics', 'poaching', 'ice-cream', 'chicken', 'grilling', 'salmon', 'cedar-plank', 'flour', 'measurements', 'sifting', 'storage-method', 'storage-lifetime', 'fats', 'canning', 'pressure-canner', 'food-preservation', 'spices', 'resources', 'learning', 'butter', 'bread', 'dough', 'rice', 'risotto', 'food-science', 'vinegar', 'knife-skills', 'cutting', 'nutrient-composition', 'calories', 'organization', 'pantry', 'conversion', 'meat', 'chicken-breast', 'tenderizing', 'pancakes', 'waffle', 'equipment', 'wok', 'seasoning-pans', 'ripe', 'avocados', 'barbecue', 'condiments', 'software', 'starter', 'pie', 'cornstarch', 'milk', 'allergy', 'sour-cream', 'dairy-free', 'knives', 'frying', 'sauteing', 'salt', 'classification', 'steak', 'cilantro', 'hamburgers', 'ground-beef', 'freezing', 'bulk-cooking', 'drying', 'oregano', 'fruit', 'citrus', 'comparisons', 'chopping', 'cutting-boards', 'roast', 'spaghetti', 'american-cuisine', 'mushrooms', 'stove', 'pepper', 'alfredo', 'budget-cooking', 'vegetarian', 'vegan', 'kosher', 'pizza', 'mango', 'meringue', 'fish', 'sushi', 'crudo', 'flavor', 'cleaning', 'cast-iron', 'maintenance', 'sugar', 'garlic', 'raw-meat', 'carpaccio', 'vanilla', 'coconut', 'cheese', 'shopping', 'fire', 'flambe', 'cheesecake', 'ingredient-selection', 'onions', 'soup', 'sodium', 'blender', 'smoothie', 'eggplant', 'middle-eastern-cuisine', 'mayonnaise', 'pastry', 'egg-whites', 'mixing', 'stock', 'cookbook', 'potatoes', 'cheese-making', 'gluten-free', 'beans', 'soaking', 'lettuce', 'basil', 'pumpkin', 'slow-cooking', 'hard-boiled-eggs', 'chinese-cuisine', 'restaurant-mimicry', 'ribs', 'cookware', 'copper-cookware', 'stainless-steel', 'teflon', 'chocolate', 'ganache', 'bones', 'deep-frying', 'french-fries', 'chips', 'temperature', 'bell-peppers', 'vegetables', 'steaming', 'carrots', 'juice', 'dessert', 'gelatin', 'utensils', 'blind-baking', 'custard', 'oil', 'tasting', 'alcohol', 'additives', 'sharpening', 'peeling', 'peaches', 'nuts', 'chestnuts', 'puree', 'cake', 'pop-rocks', 'gelling-agents', 'hollandaise', 'thickening', 'scottish-cuisine', 'defrosting', 'roasting', 'language', 'cultural-difference', 'glucose-syrup', 'lasagna', 'boiling', 'jam', 'molecular-gastronomy', 'experimental', 'meatballs', 'asian-cuisine', 'yeast', 'smell', 'refrigerator', 'beer', 'beverages', 'grating', 'pineapple', 'cut-of-meat', 'shortcuts', 'watermelon', 'kitchen', 'fresh', 'pork', 'lamb', 'butchering', 'batter', 'drinks', 'cocktails', 'coffee', 'mint', 'lemonade', 'seeds', 'soy', 'scrambled-eggs', 'mexican-cuisine', 'lime', 'pasteurization', 'mustard', 'lemon-juice', 'melting-chocolate', 'scallops', 'shellfish', 'culinary-uses', 'roux', 'heat', 'skin', 'spicy-hot', 'honey', 'sourdough', 'buttermilk', 'microwave', 'charcuterie', 'corned-beef', 'jalapeno', 'jelly', 'cajun-cuisine', 'mussels', 'brownies', 'aging', 'breakfast', 'pairing', 'syrup', 'kettle', 'pork-chops', 'tahini', 'hummus', 'wine', 'pan', 'non-stick', 'reheating', 'apples', 'turkey', 'seasoning', 'brining', 'chilling', 'camping', 'gnocchi', 'zucchini', 'soda', 'corn', 'kohlrabi', 'pizza-stone', 'marinade', 'crust', 'tortilla', 'ketchup', 'oranges', 'cream', 'dairy', 'free-range', 'duck', 'quickbread', 'sardines', 'blueberries', 'high-altitude', 'braising', 'produce', 'cold-brew', 'caffeine', 'fermentation', 'chili-peppers', 'kimchi', 'cherries', 'sprinkles', 'decorating', 'shallots', 'fondue', 'yogurt', 'sous-vide', 'kiwifruit', 'untagged', 'korean-cuisine', 'creme-anglaise', 'celery', 'plums', 'smoking', 'quinoa', 'chili', 'indian-cuisine', 'basting', 'cooking-myth', 'pita', 'broiler', 'kosher-salt', 'liver', 'sausages', 'proofing', 'outdoor-cooking', 'leeks', 'shrimp', 'spinach', 'flatbread', 'gravy', 'caramelization', 'squash', 'low-c ...

# %%
y_val
# Out:
# [['nuts', 'dehydrating', 'nut-butters'],
#  ['baking', 'pork'],
#  ['nuts', 'nut-butters'],
#  ['food-science', 'gelatin', 'gelling-agents'],
#  ['oil', 'pan'],
#  ['safety', 'blowtorch'],
#  ['vegetables', 'stock', 'vegan', 'gravy'],
#  ['fruit', 'potatoes', 'microwave', 'fire'],
#  ['pickling'],
#  ['caramelization', 'caramel'],
#  ['sugar', 'boiling', 'candy'],
#  ['lettuce'],
#  ['history', 'doughnuts'],
#  ['equipment'],
#  ['chicken', 'food-identification'],
#  ['baking', 'equipment', 'french-cuisine'],
#  ['grilling', 'barbecue'],
#  ['equipment', 'cookware'],
#  ['sauce', 'storage-lifetime', 'thai-cuisine', 'mold'],
#  ['honey', 'balkan-cuisine'],
#  ['butter', 'margarine'],
#  ['substitutions', 'pasta', 'storage'],
#  ['food-safety', 'meat', 'freezing', 'raw-meat'],
#  ['recipe-scaling', 'gelatin', 'watermelon'],
#  ['sauce', 'chinese-cuisine', 'food-identification', 'chili-peppers'],
#  ['salt', 'candy'],
#  ['thickening', 'chili'],
#  ['meat'],
#  ['food-safety', 'coconut', 'salmonella'],
#  ['milk', 'yogurt'],
#  ['chicken'],
#  ['asian-cuisine', 'italian-cuisine', 'food-history'],
#  ['flavor', 'citrus', 'soda'],
#  ['chocolate-truffles'],
#  ['pasta', 'rice'],
#  ['sauce', 'cheese', 'chemistry'],
#  ['food-safety'],
#  ['flavor', 'chinese-cuisine', 'food-identification', 'cabbage', 'celery'],
#  ['marinade', 'chinese-cuisine', 'tenderizing'],
#  ['eggs', 'custard', 'mistakes'],
#  ['raw', 'curing', 'salami'],
#  ['flavor', 'cutting'],
#  ['baking', 'potatoes'],
#  ['bread', 'potatoes', 'starch'],
#  ['food-safety'],
#  ['baking'],
#  ['food-identification', 'squash'],
#  ['baking'],
#  ['equipment'],
#  ['rice', 'food-processing'],
#  ['food-safety', 'chicken'],
#  ['bread', 'yeast'],
#  ['cooking-time', 'electric-stoves'],
#  ['equipment', 'utensils', 'thawing'],
#  ['food-science', 'utensils', 'thawing'],
#  ['steaming', 'cooking-myth'],
#  ['jalapeno'],
#  ['chicken', 'freezing', 'storage'],
#  ['baking', 'equipment', 'cookware', 'pan', 'brownies'],
#  ['food-safety', 'coffee'],
#  ['fruit', 'smell'],
#  ['pork'],
#  ['ganache', 'chocolate-truffles'],
#  ['nutrient-composition'],
#  ['cocktails'],
#  ['ingredient-selection', 'cocktails'],
#  ['milk', 'dulce-de-leche'],
#  ['cast-iron', 'seasoning-pans'],
#  ['bread', 'eggs'],
#  ['breadcrumbs'],
#  ['baking', 'margarine'],
#  ['resources'],
#  ['cleaning', 'ice-cream', 'utensils'],
#  ['food-safety'],
#  ['pressure-cooker', 'grains'],
#  ['storage-method',
#   'storage-lifetime',
#   'food-preservation',
#   'refrigerator',
#   'carrots'],
#  ['chocolate', 'calories'],
#  ['eggs', 'american-cuisine', 'food-history'],
#  ['eggs', 'frying', 'fried-eggs'],
#  ['bread'],
#  ['sauce', 'restaurant-mimicry'],
#  ['dessert', 'nuts', 'raspberries'],
#  ['cleaning'],
#  ['freezing', 'cucumbers'],
#  ['onions'],
#  ['baking'],
#  ['ingredient-selection'],
#  ['grilling', 'hamburgers'],
#  ['souffle'],
#  ['baking', 'bread', 'food-history'],
#  ['spices'],
#  ['food-preservation', 'fresh'],
#  ['canning'],
#  ['substitutions', 'tamarind'],
#  ['cast-iron', 'seasoning-pans', 'carbon-steel'],
#  ['noodles', 'broth'],
#  ['drinks', 'korean-cuisine'],
#  ['coffee', 'drinks'],
#  ['ingredient-selection', 'frosting'],
#  ['coffee', 'foam', 'turkish-cuisine'],
#  ['yogurt', 'curry'],
#  ['storage-method', 'celery'],
#  ['corn', 'fresh', 'frozen'],
#  ['knives'],
#  ['drinks', 'mixing', 'organization'],
#  ['baking'],
#  ['flavor'],
#  ['salt', 'seasoning'],
#  ['flour', 'starch'],
#  ['baking', 'equipment'],
#  ['eggs', 'cake', 'batter'],
#  ['cleaning', 'stove'],
#  ['flavor', 'spices', 'grains'],
#  ['food-safety', 'eggs', 'storage'],
#  ['chicken', 'sous-vide'],
#  ['frying', 'cleaning', 'safety'],
#  ['temperature', 'water'],
#  ['food-safety', 'food-science', 'food-preservation'],
#  ['toffee', 'honeycomb'],
#  ['fish', 'chemistry'],
#  ['sauce', 'language', 'bechamel', 'food-history'],
#  ['rice', 'rice-cooker'],
#  ['fruit'],
#  ['baking', 'chocolate'],
#  ['mexican-cuisine', 'fresh', 'salsa'],
#  ['food-science', 'boiling', 'water'],
#  ['yeast'],
#  ['meat', 'smoking'],
#  ['oven', 'microwave'],
#  ['barbecue', 'smoking', 'duck'],
#  ['juice', 'citrus'],
#  ['sauce', 'food-science', 'thickening'],
#  ['culinary-uses', 'lettuce'],
#  ['utensils', 'caramel'],
#  ['eggs', 'french-cuisine', 'omelette'],
#  ['chicken', 'meat', 'spices', 'indian-cuisine', 'roasting'],
#  ['lemon', 'acidity', 'lime'],
#  ['temperature'],
#  ['flavor', 'tasting'],
#  ['duck'],
#  ['fruit', 'alcohol', 'drinks', 'mint'],
#  ['baking', 'cake', 'recipe-scaling'],
#  ['ingredient-selection'],
#  ['substitutions'],
#  ['equipment'],
#  ['sugar'],
#  ['substitutions', 'bread', 'butter', 'shortening'],
#  ['canning'],
#  ['vanilla'],
#  ['cake', 'batter'],
#  ['rice', 'crockpot'],
#  ['fire'],
#  ['pasta'],
#  ['storage-method', 'acidity', 'avocados'],
#  ['honey'],
#  ['garlic'],
#  ['baking', 'cookies'],
#  ['food-safety', 'sous-vide', 'salmon'],
#  ['barbecue'],
#  ['chocolate', 'squash', 'toasting'],
#  ['onions', 'knife-skills', 'cutting', 'dicing'],
#  ['baking', 'cake', 'color', 'coloring'],
#  ['eggs'],
#  ['sauce', 'pasta', 'ingredient-selection'],
#  ['substitutions', 'oil', 'olive-oil'],
#  ['pork', 'roast'],
#  ['cheese', 'yogurt', 'cheese-making', 'cream-cheese', 'cultured-food'],
#  ['breadcrumbs', 'salmonella'],
#  ['icing'],
#  ['chocolate', 'emulsion', 'low-carb'],
#  ['food-safety', 'fish'],
#  ['steak', 'frozen'],
#  ['baking', 'muffins', 'avocados'],
#  ['food-safety', 'food-science', 'food-preservation'],
#  ['sugar'],
#  ['equipment', 'knives'],
#  ['baking', 'bread', 'kneading'],
#  ['pork', 'slow-cooking', 'pork-shoulder'],
#  ['substitutions', 'coffee'],
#  ['food-safety', 'chicken'],
#  ['bread'],
#  ['substitutions', 'ginger'],
#  ['equipment'],
#  ['cast-iron'],
#  ['baking'],
#  ['kitchen'],
#  ['beans', 'mexican-cuisine'],
#  ['knives', 'knife-skills'],
#  ['quinoa'],
#  ['chicken', 'japanese-cuisine'],
#  ['chicken', 'meat'],
#  ['baking', 'cake', 'chocolate', 'cupcakes'],
#  ['salt', 'japanese-cuisine', 'fermentation'],
#  ['fermentation', 'cultured-food'],
#  ['temperature', 'oven'],
#  ['pasta', 'language', 'noodles'],
#  ['kebab', 'skewers'],
#  ['food-safety', 'sausages'],
#  ['spices', 'ratio'],
#  ['corn'],
#  ['food-safety', 'food-preservation', 'potatoes', 'dehydrating'],
#  ['food-preservation', 'jam'],
#  ['meat', 'frying', 'flour'],
#  ['meat', 'marinade'],
#  ['language', 'blanching'],
#  ['cheese', 'lentils'],
#  ['salt', 'curry'],
#  ['herbs', 'garlic', 'seasoning'],
#  ['bread', 'vinegar'],
#  ['asian-cuisine'],
#  ['freezing', 'ground-beef'],
#  ['food-preservation', 'herbs', 'dehydrating'],
#  ['measurements', 'professional'],
#  ['equipment', 'mayonnaise', 'emulsion'],
#  ['meat', 'reheating'],
#  ['food-safety', 'storage-lifetime'],
#  ['chocolate', 'espresso'],
#  ['chicken', 'water'],
#  ['equipment', 'wine'],
#  ['salt', 'gammon'],
#  ['chili-peppers'],
#  ['baking'],
#  ['salt'],
#  ['food-safety', 'storage-lifetime', 'root'],
#  ['food-safety', 'bacon'],
#  ['chicken', 'refrigerator', 'raw'],
#  ['language'],
#  ['pork'],
#  ['garlic', 'flavour-pairings'],
#  ['food-safety'],
#  ['substitutions', 'cake', 'milk'],
#  ['chicken'],
#  ['food-safety', 'dessert'],
#  ['food-safety', 'steak'],
#  ['roasting', 'poultry'],
#  ['sauce', 'spaghetti'],
#  ['equipment', 'salad', 'cutting'],
#  ['food-safety'],
#  ['boiling', 'canning'],
#  ['stove', 'electric-stoves', 'reduction'],
#  ['food-safety', 'beef', 'refrigerator', 'slow-cooking'],
#  ['food-safety', 'oil'],
#  ['butter'],
#  ['chocolate', 'melting-chocolate', 'tempering'],
#  ['rice'],
#  ['rice'],
#  ['food-safety', 'food-science'],
#  ['food-safety', 'allergy'],
#  ['food-safety', 'eggs', 'pasteurization'],
#  ['bread', 'storage-method', 'storage'],
#  ['honey'],
#  ['shopping', 'fresh', 'lettuce'],
#  ['crab'],
#  ['slow-cooking'],
#  ['cookies', 'mistakes'],
#  ['honey'],
#  ['batter', 'mixing'],
#  ['vegetables', 'salt', 'food-preservation', 'alcohol'],
#  ['baking', 'glaze', 'doughnuts'],
#  ['substitutions', 'baking-powder'],
#  ['chicken', 'salt', 'brining'],
#  ['coffee', 'alcohol', 'drinks', 'whiskey'],
#  ['temperature'],
#  ['chicken', 'soup'],
#  ['muffins'],
#  ['salt', 'steak'],
#  ['food-safety'],
#  ['oil'],
#  ['equipment', 'pan', 'frying-pan'],
#  ['coffee', 'cold-brew'],
#  ['sauteing'],
#  ['substitutions', 'olive-oil'],
#  ['italian-cuisine', 'french-cuisine', 'food-history', 'tart'],
#  ['meat', 'refrigerator', 'marinade'],
#  ['meat', 'fish', 'language'],
#  ['sausages', 'batter'],
#  ['chicken', 'chicken-breast', 'pressure-cooker'],
#  ['fruit', 'cutting', 'peeling'],
#  ['brining'],
#  ['food-safety', 'oven', 'mustard'],
#  ['bread'],
#  ['cheese'],
#  ['food-safety', 'shopping'],
#  ['pasta', 'chinese-cuisine', 'noodles', 'spaghetti'],
#  ['food-safety', 'oil', 'basics'],
#  ['chinese-cuisine'],
#  ['food-safety'],
#  ['sauce', 'cheese'],
#  ['vegetables', 'salt', 'jam'],
#  ['baking', 'cake', 'honey'],
#  ['flavor'],
#  ['food-safety', 'storage-method'],
#  ['eggs', 'food-safety', 'hard-boiled-eggs'],
#  ['baking', 'pizza', 'italian-cuisine'],
#  ['smoking', 'ribs', 'tenderizing'],
#  ['flavor', 'msg'],
#  ['food-safety', 'food-preservation', 'beans', 'canning'],
#  ['vinegar'],
#  ['chocolate'],
#  ['vegetables', 'nutrient-composition'],
#  ['baking', 'dough'],
#  ['chicken', 'deep-frying'],
#  ['seasoning', 'restaurant-mimicry', 'chips'],
#  ['mushrooms', 'risotto'],
#  ['cake'],
#  ['bagels'],
#  ['oats'],
#  ['noodles', 'gluten-free', 'dumplings'],
#  ['salt'],
#  ['fish', 'cooking-time', 'steaming'],
#  ['milk', 'yogurt', 'frozen-yogurt'],
#  ['food-safety', 'dehydrating', 'sweet-potatoes'],
#  ['food-safety', 'meat', 'slow-cooking', 'chemistry'],
#  ['baking', 'dough', 'food-science', 'batter', 'chemistry'],
#  ['substitutions', 'soup'],
#  ['soup'],
#  ['frying', 'grilling', 'steak'],
#  ['food-safety'],
#  ['meat', 'freezing', 'gravy'],
#  ['flavor'],
#  ['bread', 'sourdough', 'mold'],
#  ['equipment', 'pasta'],
#  ['candy', 'cornstarch'],
#  ['cake', 'fruit'],
#  ['japanese-cuisine', 'korean-cuisine'],
#  ['frying', 'fried-eggs'],
#  ['meat', 'flour', 'stews', 'braising'],
#  ['oil', 'boiling', 'lemon', 'extracts'],
#  ['thickening', 'mustard'],
#  ['food-safety', 'chicken', 'vacuum'],
#  ['baking', 'cookies', 'consistency'],
#  ['beans'],
#  ['sharpening'],
#  ['fruit', 'jelly'],
#  ['oven', 'grilling'],
#  ['sourdough', 'crust'],
#  ['puff-pastry'],
#  ['language', 'thanksgiving'],
#  ['oil', 'oven', 'salmon'],
#  ['restaurant', 'griddle'],
#  ['slow-cooking'],
#  ['knives', 'sharpening', 'carbon-steel'],
#  ['bones'],
#  ['food-preservation', 'canning', 'pickling'],
#  ['dough', 'pizza'],
#  ['baking', 'flour'],
#  ['chili-peppers', 'mortar', 'pestle'],
#  ['storage-method', 'fruit', 'refrigerator', 'pomegranate'],
#  ['food-safety', 'chicken'],
#  ['brining'],
#  ['food-preservation', 'potatoes', 'onions'],
#  ['bread', 'freezing', 'crust'],
#  ['chili-peppers', 'ripe'],
#  ['steak'],
#  ['substitutions', 'mexican-cuisine'],
#  ['soup', 'cauliflower'],
#  ['food-science', 'flour'],
#  ['cheese', 'food-science'],
#  ['storage-method', 'herbs'],
#  ['baking', 'food-science', 'flour', 'baking-soda'],
#  ['substitutions', 'bread', 'flour'],
#  ['measurements', 'measuring-scales'],
#  ['baking'],
#  ['cookware'],
#  ['molecular-gastronomy'],
#  ['food-safety', 'frozen'],
#  ['baking', 'food-safety', 'potatoes', 'peeling'],
#  ['eggs', 'salt'],
#  ['dough', 'potatoes', 'gnocchi'],
#  ['freezing', 'pie'],
#  ['sauce', 'vanilla', 'pudding'],
#  ['storage-method', 'fruit', 'texture', 'dairy', 'blueberries'],
#  ['nuts'],
#  ['freezing', 'defrosting'],
#  ['equipment', 'maintenance', 'wok', 'seasoning-pans'],
#  ['deep-frying'],
#  ['baking', 'bread'],
#  ['cooking-time', 'garlic'],
#  ['fats', 'soy', 'tofu', 'low-carb'],
#  ['frying', 'sauteing'],
#  ['food-preservation'],
#  ['storage-method', 'freezing', 'ginger', 'thawing'],
#  ['spices'],
#  ['sauce', 'herbs'],
#  ['soup', 'vegetarian'],
#  ['food-preservation'],
#  ['food-safety', 'canning', 'cooking-myth'],
#  ['food-safety', 'sausages'],
#  ['dough'],
#  ['food-safety', 'culinary-uses', 'egg-whites'],
#  ['scallops'],
#  ['baking', 'bread', 'starter', 'brown-sugar'],
#  ['baking', 'bread', 'starter', 'buttermilk'],
#  ['language', 'food-processing'],
#  ['food-safety', 'food-preservation', 'sauteing'],
#  ['gelatin'],
#  ['bechamel'],
#  ['muffins'],
#  ['corn'],
#  ['chicken'],
#  ['avocados'],
#  ['frying', 'dough', 'sandwich'],
#  ['tea', 'boiling', 'water'],
#  ['vegetables', 'food-preservation', 'chili-peppers'],
#  ['food-safety', 'storage-method', 'storage-lifetime', 'ginger'],
#  ['storage-method', 'storage-lifetime', 'ginger'],
#  ['ingredient-selection'],
#  ['bread', 'italian-cuisine', 'rising'],
#  ['bread', 'dough', 'yeast'],
#  ['popcorn'],
#  ['freezing', 'potatoes', 'german-cuisine'],
#  ['baking'],
#  ['steak', 'pan'],
#  ['food-safety', 'rice'],
#  ['refrigerator', 'storage'],
#  ['bread', 'eggs'],
#  ['meat'],
#  ['meat', 'vegetables', 'soup'],
#  ['sandwich', 'jelly', 'containers'],
#  ['roasting', 'marshmallow', 'melting'],
#  ['chicken', 'vegetables', 'frying', 'boiling', 'pressure-cooker'],
#  ['spices', 'herbs', 'storage'],
#  ['food-science', 'additives'],
#  ['temperature', 'refrigerator'],
#  ['substitutions'],
#  ['cookies', 'mixing', 'stand-mixer'],
#  ['fire'],
#  ['baking', 'frying', 'doughnuts'],
#  ['bread', 'microwave', 'yeast', 'biga'],
#  ['beef', 'steak', 'chinese-cuisine'],
#  ['rice'],
#  ['ground-beef'],
#  ['food-safety', 'storage-lifetime', 'roast', 'ham'],
#  ['cleaning', 'steak', 'frying-pan', 'stainless-steel'],
#  ['potatoes', 'color'],
#  ['food-preservation', 'strawberries'],
#  ['roasting', 'honey', 'peanuts'],
#  ['baking'],
#  ['spices'],
#  ['equipment', 'sandwich'],
#  ['bread'],
#  ['cookware'],
#  ['flour', 'storage'],
#  ['meat', 'beef', 'japanese-cuisine', 'butchering'],
#  ['tart'],
#  ['bread'],
#  ['freezing', 'cheese', 'fish', 'salmon'],
#  ['equipment', 'electric-stoves', 'skillet'],
#  ['knives', 'sharpening'],
#  ['pastry', 'organization'],
#  ['meat', 'charcuterie', 'pate'],
#  ['baking', 'cake', 'muffins'],
#  ['baking', 'cake', 'ratio'],
#  ['baking', 'equipment'],
#  ['apples', 'caramelization', 'caramel', 'apple-pie'],
#  ['pork', 'pork-belly'],
#  ['beef', 'slow-cooking'],
#  ['beef', 'roast', 'lamb', 'roast-beef'],
#  ['baking', 'bread', 'hamburgers'],
#  ['cookware'],
#  ['cookware', 'boiling'],
#  ['baking', 'cake', 'sugar', 'butter'],
#  ['chickpeas'],
#  ['substitutions', 'evaporated-milk'],
#  ['sous-vide', 'vacuum'],
#  ['sous-vide'],
#  ['chicken', 'pork', 'roast', 'roast-beef'],
#  ['fruit', 'food-preservation', 'decorating'],
#  ['equipment', 'sugar', 'indian-cuisine', 'grinding'],
#  ['baking', 'cheese', 'pie'],
#  ['baking', 'bread', 'freezing'],
#  ['risotto'],
#  ['slow-cooking'],
#  ['baking', 'substitutions', 'wheat'],
#  ['soup', 'utensils'],
#  ['baking', 'temperature'],
#  ['chocolate', 'fudge'],
#  ['cookies', 'food-identification'],
#  ['sugar', 'butter', 'shortening'],
#  ['food-preservation', 'pickling'],
#  ['chicken'],
#  ['salt', 'fermentation', 'german-cuisine', 'sauerkraut'],
#  ['baking', 'substitutions', 'cake', 'brown-sugar'],
#  ['baking'],
#  ['equipment', 'tea'],
#  ['baking', 'bread', 'sourdough', 'utensils'],
#  ['candy', 'vanilla', 'caramel', 'fudge'],
#  ['honey'],
#  ['molecular-gastronomy', 'extracts'],
#  ['professional'],
#  ['food-preservation', 'sushi'],
#  ['bread', 'dough', 'pizza', 'yeast', 'sourdough'],
#  ['food-safety', 'seafood'],
#  ['baking', 'bread', 'dough', 'yeast'],
#  ['cream', 'fats'],
#  ['substitutions'],
#  ['storage-lifetime', 'cream-cheese'],
#  ['freezing', 'herbs'],
#  ['vegetables'],
#  ['food-safety', 'storage-lifetime', 'spoilage', 'kombucha'],
#  ['stock'],
#  ['food-safety', 'microwave'],
#  ['food-preservation'],
#  ['flavor', 'freezing', 'cleaning', 'alcohol', 'drinks'],
#  ['beets'],
#  ['oven', 'broiler'],
#  ['food-safety', 'temperature', 'slow-cooking'],
#  ['vegetables', 'vegetarian'],
#  ['cookware', 'cast-iron', 'seasoning'],
#  ['substitutions', 'wine', 'spaghetti'],
#  ['potatoes', 'boiling'],
#  ['food-safety'],
#  ['bread', 'dough', 'pizza', 'sourdough', 'leavening'],
#  ['dough', 'pizza', 'sourdough'],
#  ['food-safety'],
#  ['chicken', 'rice', 'japanese-cuisine'],
#  ['flavor'],
#  ['coffee', 'turkish-cuisine'],
#  ['salt'],
#  ['equipment', 'coffee', 'measurements', 'drinks'],
#  ['pie', 'crust', 'crumb-crust'],
#  ['substitutions', 'frosting'],
#  ['baking', 'substitutions', 'bread', 'yeast'],
#  ['sausages', 'skin'],
#  ['baking'],
#  ['grilling', 'slow-cooking', 'smoking', 'charcoal'],
#  ['consistency'],
#  ['pot'],
#  ['cookies'],
#  ['pasta', 'presentation', 'plating'],
#  ['pasta'],
#  ['shopping', 'organization'],
#  ['cooking-time', 'sauteing', 'pork-chops'],
#  ['salmon'],
#  ['carrots'],
#  ['slow-cooking'],
#  ['sous-vide', 'venison'],
#  ['temperature', 'tea', 'boiling', 'water'],
#  ['veal', 'venison'],
#  ['cheese-making'],
#  ['baking'],
#  ['cheese', 'storage'],
#  ['baking', 'oven', 'fire'],
#  ['temperature', 'crockpot'],
#  ['beef', 'crockpot'],
#  ['tomatoes', 'marinade'],
#  ['food-safety', 'rice', 'korean-cuisine'],
#  ['chicken', 'boiling', 'chicken-breast'],
#  ['storage', 'freezing'],
#  ['soup', 'utensils'],
#  ['oil', 'french-fries'],
#  ['oil', 'pizza'],
#  ['pickling'],
#  ['steak'],
#  ['eggs', 'storage'],
#  ['baking', 'meringue'],
#  ['sourdough', 'sourdough-starter'],
#  ['cheese', 'pasta', 'onions', 'german-cuisine'],
#  ['chocolate'],
#  ['freezing', 'chili-peppers'],
#  ['spices', 'ground-beef', 'chili'],
#  ['water', 'containers'],
#  ['sugar', 'tea', 'cocktails', 'presentation'],
#  ['temperature', 'cooking-time', 'pork', 'slow-cooking', 'ribs'],
#  ['dough', 'pizza'],
#  ['dough'],
#  ['substitutions', 'corn', 'tamales'],
#  ['milk', 'pork', 'mexican-cuisine'],
#  ['clotted-cream'],
#  ['baking', 'cake'],
#  ['ingredient-selection', 'salad-dressing', 'emulsion'],
#  ['food-safety', 'curry', 'coconut'],
#  ['beef', 'barbecue', 'smoking'],
#  ['chocolate', 'emulsion'],
#  ['soup'],
#  ['soup'],
#  ['spinach'],
#  ['meat', 'shopping', 'seafood'],
#  ['wine'],
#  ['decorating'],
#  ['eggplant'],
#  ['butter', 'mustard'],
#  ['food-safety', 'chicken', 'meat', 'beef', 'pork'],
#  ['apples', 'apple-pie'],
#  ['chicken', 'frying'],
#  ['ham'],
#  ['sour-cream'],
#  ['storage-method', 'coffee', 'freezing'],
#  ['storage-method', 'coffee'],
#  ['temperature'],
#  ['fire'],
#  ['freezing', 'refrigerator', 'history'],
#  ['baking-powder'],
#  ['vegetables', 'fruit'],
#  ['knives', 'cutting'],
#  ['sugar', 'ground-beef'],
#  ['kebab', 'skewers'],
#  ['equipment', 'fermentation', 'containers', 'crock'],
#  ['food-safety'],
#  ['food-safety'],
#  ['baking', 'temperature'],
#  ['dough', 'condiments', 'focaccia'],
#  ['coffee', 'spices', 'alcohol', 'beverages', 'fire'],
#  ['carrots', 'spinach'],
#  ['tenderizing'],
#  ['slow-cooking', 'raw-meat'],
#  ['milk', 'cheese-making'],
#  ['eggs', 'greens'],
#  ['additives'],
#  ['coconut', 'brownies', 'coloring'],
#  ['grilling', 'garlic', 'ribs'],
#  ['coffee', 'beans', 'caffeine'],
#  ['paneer'],
#  ['baking', 'cake', 'language'],
#  ['milk', 'butter', 'cream', 'coconut'],
#  ['chicken', 'indian-cuisine'],
#  ['recipe-scaling'],
#  ['slow-cooking', 'sushi', 'sticky-rice'],
#  ['baking', 'gluten-free', 'muffins'],
#  ['baking', 'oven', 'gas'],
#  ['cake', 'food-science', 'pudding'],
#  ['baking', 'soda', 'legumes'],
#  ['sauce'],
#  ['quickbread', 'doughnuts', 'baker-percentage'],
#  ['chicken', 'indian-cuisine', 'curry'],
#  ['food-safety', 'pickling'],
#  ['sous-vide'],
#  ['equipment'],
#  ['bread', 'dough', 'oven'],
#  ['cake', 'icing'],
#  ['blender', 'safety'],
#  ['roast'],
#  ['food-safety', 'lamb', 'kebab'],
#  ['broth'],
#  ['candy', 'food-identification'],
#  ['chicken', 'frozen'],
#  ['food-safety', 'bell-peppers'],
#  ['fruit', 'sugar', 'infusion'],
#  ['calories'],
#  ['food-safety'],
#  ['food-safety', 'chicken'],
#  ['tea'],
#  ['chestnuts'],
#  ['food-safety', 'temperature', 'soup', 'food-preservation'],
#  ['tuna', 'casserole'],
#  ['butter'],
#  ['food-identification'],
#  ['potatoes'],
#  ['freezing'],
#  ['food-safety'],
#  ['chili-peppers'],
#  ['baking', 'oven', 'broiler'],
#  ['flavor', 'seasoning', 'msg'],
#  ['eggs'],
#  ['flour', 'pizza', 'neapolitan-pizza'],
#  ['mexican-cuisine'],
#  ['beer'],
#  ['cookbook'],
#  ['sugar', 'cubes'],
#  ['pasta', 'spaghetti'],
#  ['tea'],
#  ['food-safety', 'lamb'],
#  ['equipment', 'cleaning', 'tea'],
#  ['language', 'ketchup'],
#  ['sauce', 'cheese', 'pasta', 'bechamel'],
#  ['cookies', 'texture'],
#  ['sharpening'],
#  ['pastry'],
#  ['equipment', 'cast-iron'],
#  ['beef', 'roast'],
#  ['candy'],
#  ['food-safety', 'temperature', 'reheating', 'frozen'],
#  ['yogurt', 'cheese-making'],
#  ['bread', 'storage-method'],
#  ['bread'],
#  ['food-safety', 'water'],
#  ['baking', 'sugar', 'butter', 'frosting'],
#  ['vegetables', 'canning'],
#  ['substitutions'],
#  ['baking', 'cake', 'temperature'],
#  ['baking'],
#  ['yeast', 'rising', 'proofing'],
#  ['whipped-cream'],
#  ['equipment', 'frying', 'deep-frying'],
#  ['texture', 'moisture'],
#  ['baking'],
#  ['food-safety', 'water', 'drinks'],
#  ['vegetables'],
#  ['baking'],
#  ['steak', 'cast-iron', 'pan', 'hamburgers'],
#  ['oven', 'turkey'],
#  ['equipment', 'pan'],
#  ['food-safety'],
#  ['flavor', 'spices', 'salt', 'pepper'],
#  ['pineapple'],
#  ['cheese'],
#  ['dough', 'sourdough', 'focaccia', 'sourdough-starter'],
#  ['herbs'],
#  ['yeast', 'proofing'],
#  ['marshmallow'],
#  ['food-identification', 'thai-cuisine'],
#  ['cut-of-meat'],
#  ['substitutions'],
#  ['pork', 'sous-vide', 'chinese-cuisine'],
#  ['chicken'],
#  ['food-safety', 'salmon', 'frozen'],
#  ['kneading'],
#  ['substitutions', 'wine', 'sourdough'],
#  ['soup'],
#  ['equipment'],
#  ['chicken', 'soup'],
#  ['boiling', 'steaming', 'dumplings'],
#  ['meat', 'sauce', 'pasta'],
#  ['grilling', 'barbecue', 'salmon'],
#  ['thai-cuisine'],
#  ['soup'],
#  ['yogurt'],
#  ['eggs', 'hard-boiled-eggs'],
#  ['seafood'],
#  ['meat'],
#  ['oven', 'heat', 'waffle', 'safety'],
#  ['soup'],
#  ['bread', 'pita'],
#  ['freezing', 'raw'],
#  ['fruit'],
#  ['food-safety'],
#  ['food-science', 'milk', 'soy'],
#  ['turkey', 'brining'],
#  ['rice'],
#  ['smell', 'beets'],
#  ['bacon'],
#  ['indian-cuisine', 'steaming', 'batter', 'fermentation'],
#  ['beef', 'steak'],
#  ['vegetables', 'sauteing'],
#  ['sugar', 'candy', 'fudge'],
#  ['substitutions', 'oven', 'cleaning'],
#  ['slow-cooking', 'candy', 'almonds'],
#  ['food-safety', 'pan', 'olive-oil', 'teflon'],
#  ['baking'],
#  ['freezing', 'food-science'],
#  ['equipment', 'coffee'],
#  ['food-science'],
#  ['equipment', 'oven', 'smell'],
#  ['dutch-oven', 'casserole'],
#  ['baking', 'chocolate', 'cookies', 'baking-soda'],
#  ['venison'],
#  ['sweet-potatoes'],
#  ['eggs', 'food-science', 'heat', 'omelette', 'scrambled-eggs'],
#  ['chicken', 'meat', 'freezing', 'liver'],
#  ['candy', 'caramel'],
#  ['roasting', 'turkey'],
#  ['sauce', 'fruit'],
#  ['oven', 'turkey', 'thanksgiving'],
#  ['sauce', 'soup', 'ramen'],
#  ['food-safety', 'crockpot'],
#  ['baking', 'bread'],
#  ['filtering'],
#  ['toffee'],
#  ['mixing'],
#  ['temperature'],
#  ['food-safety'],
#  ['chicken-breast'],
#  ['duck', 'thanksgiving'],
#  ['baking', 'cookies', 'baking-soda'],
#  ['food-safety', 'broccoli'],
#  ['chickpeas'],
#  ['butter', 'ice-cream', 'emulsion'],
#  ['knives'],
#  ['turkey'],
#  ['sushi'],
#  ['baking', 'gingerbread'],
#  ['oil', 'cooking-myth'],
#  ['baking', 'cheesecake'],
#  ['breakfast'],
#  ['pie', 'pumpkin', 'evaporated-milk'],
#  ['cake', 'batter'],
#  ['baking'],
#  ['dough', 'pizza', 'non-stick', 'wheat', 'kneading'],
#  ['chicken', 'brining'],
#  ['chicken', 'wine', 'spicy-hot', 'citrus', 'pairing'],
#  ['food-safety', 'slow-cooking', 'turkey'],
#  ['beef', 'bones'],
#  ['storage-method', 'vegetables', 'cucumbers'],
#  ['sugar'],
#  ['dough'],
#  ['pie', 'crust', 'frozen'],
#  ['pumpkin'],
#  ['turkey'],
#  ['gelatin', 'recipe-scaling'],
#  ['dough', 'oven', 'pizza', 'thickening', 'peel'],
#  ['microwave'],
#  ['food-safety', 'deep-frying', 'turkey'],
#  ['noodles', 'broth', 'ramen'],
#  ['frying', 'flowers'],
#  ['thermometer'],
#  ['turkey'],
#  ['potatoes'],
#  ['ceramic'],
#  ['storage', 'organization'],
#  ['baking'],
#  ['noodles', 'japanese-cuisine', 'ceramic', 'ramen', 'plating'],
#  ['storage-method', 'food-preservation', 'food-safety'],
#  ['food-safety', 'equipment', 'bones'],
#  ['substitutions'],
#  ['baking', 'convection', 'apple-pie'],
#  ['equipment', 'grinding'],
#  ['pasta', 'rice', 'reheating'],
#  ['potatoes', 'alcohol', 'fermentation', 'vodka', 'rum'],
#  ['substitutions', 'oven', 'broiler'],
#  ['pork', 'roasting', 'pork-belly'],
#  ['food-safety', 'storage-method', 'chocolate', 'nuts', 'olive-oil'],
#  ['equipment', 'utensils'],
#  ['salt'],
#  ['frying-pan'],
#  ['chicken', 'curry'],
#  ['texture'],
#  ['flavor', 'tomatoes', 'italian-cuisine'],
#  ['jam'],
#  ['dough', 'yeast', 'cinnamon'],
#  ['ham'],
#  ['broth'],
#  ['storage-method', 'storage-lifetime', 'pasta'],
#  ['spoilage', 'avocados'],
#  ['food-safety', 'sous-vide'],
#  ['chicken', 'spices', 'skin'],
#  ['food-safety', 'serving', 'plating'],
#  ['food-safety', 'chicken'],
#  ['cookies'],
#  ['substitutions', 'chocolate'],
#  ['beef', 'turkey'],
#  ['storage-method', 'food-preservation', 'bananas'],
#  ['oil', 'cookies', 'butter'],
#  ['food-safety'],
#  ['baking'],
#  ['goose'],
#  ['roasting', 'turkey', 'brining'],
#  ['stock', 'turkey', 'broth'],
#  ['cookware', 'stove', 'frying-pan', 'ceramic'],
#  ['roast', 'duck'],
#  ['sauce', 'marinade', 'vinegar', 'juice', 'lime'],
#  ['cheese-making'],
#  ['food-safety', 'meat'],
#  ['japanese-cuisine', 'noodles', 'broth', 'ramen'],
#  ['substitutions', 'wasabi'],
#  ['cheese', 'grilling', 'sandwich'],
#  ['cheese'],
#  ['substitutions', 'squash'],
#  ['chestnuts'],
#  ['tea'],
#  ['cheese-making'],
#  ['rice'],
#  ['beef', 'slow-cooking', 'crockpot', 'pot-roast'],
#  ['baking', 'eggs', 'cookies'],
#  ['substitutions', 'graham-crackers'],
#  ['beans'],
#  ['language', 'smoking', 'ham', 'raw', 'gammon'],
#  ['vodka'],
#  ['pan'],
#  ['vegetables', 'raw', 'korean-cuisine', 'kale'],
#  ['sour-cream'],
#  ['baking', 'bacon', 'low-fat'],
#  ['vegetables'],
#  ['bread'],
#  ['food-safety', 'garlic'],
#  ['candy'],
#  ['fish', 'smell'],
#  ['melting-chocolate'],
#  ['cookies'],
#  ['food-science', 'cookware', 'non-stick', 'seasoning-pans'],
#  ['freezing', 'cheese', 'vacuum', 'botulism'],
#  ['pork', 'slow-cooking', 'ribs'],
#  ['cookbook', 'spanish-cuisine'],
#  ['sourdough', 'mold', 'starter'],
#  ['fruit'],
#  ['sauce', 'language'],
#  ['storage-method', 'bananas'],
#  ['equipment'],
#  ['freezing', 'storage-lifetime', 'chocolate'],
#  ['baking', 'salt', 'potatoes'],
#  ['food-safety', 'chicken', 'pie'],
#  ['substitutions', 'herbs', 'flowers'],
#  ['fruit', 'culinary-uses', 'citrus', 'seeds'],
#  ['pasta', 'pork', 'slow-cooking', 'italian-cuisine'],
#  ['fermentation', 'beets'],
#  ['boiling', 'liver'],
#  ['eggs'],
#  ['oats'],
#  ['coffee', 'milk'],
#  ['food-safety'],
#  ['spoilage'],
#  ['baking', 'food-safety', 'cheese'],
#  ['gravy'],
#  ['yorkshire-puddings'],
#  ['turkey', 'smoking'],
#  ['meat', 'color'],
#  ['chicken', 'seasoning'],
#  ['rice', 'rice-cooker', 'lentils'],
#  ['baking', 'cheesecake'],
#  ['creme-brulee', 'blowtorch'],
#  ['baking', 'microwave'],
#  ['baking', 'eggs', 'egg-whites'],
#  ['substitutions', 'meat'],
#  ['food-safety', 'clothing'],
#  ['storage-method', 'lasagna'],
#  ['food-safety', 'fruit', 'chemistry', 'seeds'],
#  ['substitutions', 'cake'],
#  ['meat', 'sugar'],
#  ['beans', 'pressure-cooker'],
#  ['food-safety', 'vinegar'],
#  ['substitutions', 'bread', 'dough', 'pastry', 'filling'],
#  ['bread', 'flour', 'corn'],
#  ['pie', 'apples'],
#  ['dough', 'food-science', 'baking-soda'],
#  ['seeds', 'food-processing'],
#  ['storage-method', 'soup'],
#  ['soup', 'bananas'],
#  ['baking', 'substitutions', 'flour'],
#  ['recipe-scaling', 'pressure-cooker'],
#  ['equipment', 'cookies'],
#  ['sauce', 'rice', 'chinese-cuisine', 'restaurant-mimicry'],
#  ['baking', 'cake', 'cupcakes'],
#  ['cheese'],
#  ['barley'],
#  ['dessert', 'nuts', 'whipped-cream', 'pudding', 'flavour-pairings'],
#  ['asian-cuisine', 'food-identification'],
#  ['baking'],
#  ['beef', 'cut-of-meat', 'russian-cuisine'],
#  ['beef', 'steak'],
#  ['chicken', 'frying', 'oil', 'deep-frying'],
#  ['equipment', 'history'],
#  ['fish', 'salt'],
#  ['food-safety'],
#  ['soup', 'salt', 'chinese-cuisine'],
#  ['meringue'],
#  ['fruit'],
#  ['sauce', 'chips'],
#  ['eggs'],
#  ['bread', 'seeds'],
#  ['pasta'],
#  ['bread', 'rye'],
#  ['ham'],
#  ['freezing', 'thawing'],
#  ['baking', 'bread', 'oven', 'heat'],
#  ['baking'],
#  ['refrigerator', 'pastry'],
#  ['cookies'],
#  ['meat', 'freezing', 'turkey', 'frozen', 'raw-meat'],
#  ['flour'],
#  ['cheese'],
#  ['boiling', 'canning', 'fresh'],
#  ['baking', 'cake', 'oven', 'dessert', 'meringue'],
#  ['baking', 'chocolate', 'tempering'],
#  ['meat', 'cooking-time', 'thermometer'],
#  ['meat'],
#  ['whipped-cream'],
#  ['sauce', 'tomatoes'],
#  ['frying'],
#  ['sugar', 'cookies', 'texture'],
#  ['meat', 'freezing'],
#  ['food-safety', 'chocolate', 'raw'],
#  ['untagged'],
#  ['cream'],
#  ['substitutions', 'yeast', 'fermentation', 'creme-fraiche'],
#  ['chocolate'],
#  ['baking', 'parchment'],
#  ['baking', 'cookies'],
#  ['chocolate'],
#  ['vegetables'],
#  ['temperature', 'candy'],
#  ['bread', 'sourdough'],
#  ['fudge'],
#  ['pork'],
#  ['roasting', 'foil-cooking'],
#  ['food-safety', 'crockpot'],
#  ['chicken', 'salt'],
#  ['meat', 'food-preservation'],
#  ['cake', 'cupcakes', 'filling'],
#  ['potatoes', 'boiling'],
#  ['substitutions', 'pumpkin'],
#  ['freezing', 'stock'],
#  ['oven', 'pate'],
#  ['syrup'],
#  ['pancakes'],
#  ['barbecue'],
#  ['baking', 'cake'],
#  ['language'],
#  ['oil'],
#  ['food-safety', 'freezing', 'cookware', 'convenience-foods'],
#  ['brining', 'lamb'],
#  ['storage-lifetime'],
#  ['fudge', 'cocoa'],
#  ['chili'],
#  ['temperature', 'barbecue'],
#  ['sugar', 'pastry', 'brown-sugar'],
#  ['mushrooms'],
#  ['tea'],
#  ['chemistry', 'dry-aging'],
#  ['soup', 'spices'],
#  ['chicken', 'oven'],
#  ['dough', 'pizza', 'peel', 'neapolitan-pizza'],
#  ...]

# %%
mlb = MultiLabelBinarizer(classes=sorted(tags_counts.keys()))
y_train = mlb.fit_transform(y_train)
y_val = mlb.fit_transform(y_val)

# %%
y_train.shape
# Out:
# (11500, 713)

# %% [markdown]
# Train the classifiers for different data transformations: *bag-of-words* and *tf-idf*.

# %%
# %%time
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression, RidgeClassifier
clf = OneVsRestClassifier(RidgeClassifier(normalize=True))
clf.fit(X_train_tfidf, y_train)
# classifier_tfidf = train_classifier(X_train_tfidf, y_train)
# Out:
# Wall time: 27.8 s

# %% [markdown]
# Now you can create predictions for the data. You will need two types of predictions: labels and scores.

# %%
# %%time
y_val_predicted_labels_tfidf = clf.predict(X_val_tfidf)
# y_val_predicted_scores_tfidf = classifier_tfidf.decision_function(X_val_tfidf)
# Out:
# Wall time: 46.9 ms

# %% [markdown]
# Now take a look at how classifier, which uses TF-IDF, works for a few examples:

# %%
que = ['How do I stop pasta from clumping/sticking together?','What is a stick of butter?','how to do tadka in daal?', 'how to make chocolate brownie?']
que = [text_prepare(i) for i in que]
# que = [que]
que = tfidf_vectorizer.transform(que)
yp = clf.predict(que)
print(mlb.inverse_transform(yp))
# Out:
# [('pasta',), ('butter',), (), ('baking', 'brownies', 'chocolate')]

# %%
import pickle
import os 
pickle.dump(clf, open('model-cooking.pkl', 'wb'))
pickle.dump(mlb, open('tags-cooking.pkl', 'wb'))
pickle.dump(tfidf_vectorizer, open('tf-coking.pkl', 'wb'))
