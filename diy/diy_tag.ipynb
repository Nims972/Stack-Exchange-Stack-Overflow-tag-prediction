# %%
import nltk
#nltk.download('stopwords')
from ast import literal_eval
import pandas as pd
import numpy as np
from nltk.corpus import stopwords

# %%
def read_data(filename):
    data = pd.read_csv(filename, sep='\t')
    data['tags'] = data['tags'].apply(literal_eval)
    return data

# %%
tmp = pd.read_csv('diy.csv')
#train = read_data('cooking.csv')
#validation = read_data('validation.tsv')
#test = pd.read_csv('test.tsv', sep='\t')
tmp
# Out:
#           id                                              title  \
# 0          1  How do I install a new, non load bearing wall ...
# 1          2  What kind of caulk should I use around my bath...
# 2          3  Is fiberglass mesh tape a good choice for dryw...
# 3          4  Are there ways to determine if a wall is load ...
# 4          5  How do I safely replace a worn out electrical ...
# 5          6         How do I repair hairline cracks in stucco?
# 6          7  Where can I find a bathroom fan that will fit ...
# 7         10  How do I repair a small leak in a steam radiat...
# 8         11            How do I remove wallpaper from drywall?
# 9         16  What do I need to do to add stools to my vinyl...
# 10        17  How can I hanging something on an exterior wal...
# 11        18       How can I fill a void in a concrete seawall?
# 12        19  How to drain a baseboard radiator system for a...
# 13        20       Should old knob and tube wiring be replaced?
# 14        21  How do I find studs when stud finders won't work?
# 15        23  What do I have to do to prepare my garage floo...
# 16        25  What is the difference between a framing hamme...
# 17        26  How do I remove dried paint from ceramic tiles...
# 18        28  How do I remove the white residue on fresh til...
# 19        30        Why does my toilet's seal wear out so fast?
# 20        31  What are my options for asphalt driveway repai...
# 21        35  Is there a trick to applying caulk using a cau...
# 22        36  How can I paint over a ceiling after there's b...
# 23        39  What are my lighting options for a pole-barn g...
# 24        42  What is a good method to seal a baseboard to s...
# 25        48                    How can I repair a Palruf roof?
# 26        53  What are the tools that every Do-it-Yourselfer...
# 27        56                     Does liquid aerification work?
# 28        61         Which water heater types do you recommend?
# 29        65  How can I pour a concrete pad with a circular ...
# ...      ...                                                ...
# 25888  98594  Washer / Dryer suddenly popping house electric...
# 25889  98596  How can I troubleshoot faulty carbon monoxide ...
# 25890  98598                        remove a recessed light can
# 25891  98601  3Way Occupancy Sensor Switch NO neutral or gro...
# 25892  98606              How to repair my concrete slab porch.
# 25893  98610       Wiring extension cord for 240 volt generator
# 25894  98611  could air in the line cause drop in water pres...
# 25895  98617  To identify model of Liftmaster garage door op...
# 25896  98620  What could cause my washing machine to stop be...
# 25897  98622             How to tell if my led strip is busted?
# 25898  98623  Simpson Delta 422 washing machine - only agita...
# 25899  98624                    Vapor barrier on exterior walls
# 25900  98627                      How to reduce echo in a room?
# 25901  98628                Customising DeWalt TSTAK IV drawers
# 25902  98634                             Strange water pressure
# 25903  98635      Silicon or rubber protection for kitchen base
# 25904  98642                      Removing carpenter ant colony
# 25905  98645                              Led lights on sensors
# 25906  98646  Replacing kitchen sink, hot water valve under ...
# 25907  98647    Pairing door knobs from different manufacturers
# 25908  98648                  Concrete subfloor with 2x4 on top
# 25909  98650  For a single 12-2 NM cable, what hole size sho...
# 25910  98656  C WIRE MISSING, Trane Air-Handler Variable 4TEE3F
# 25911  98658    Plug socket won't turn off even after replacing
# 25912  98659  Is it safe to wire a light junction box to a p...
# 25913  98662  How to prevent standing water collecting at th...
# 25914  98663                            selectable thermostats?
# 25915  98665             measuring power drawn from an inverter
# 25916  98670  Old oil forced air heat only system (R/W wire ...
# 25917  98674                Light stays on even with switch off
#
#                                                  content  \
# 0      <p>I'm looking to finish my basement and simpl...
# 1      <p>I would like to recaulk between the bathtub...
# 2      <p>I'm going to be doing some drywalling short...
# 3      <p>Other than looking up blue prints, which ma...
# 4      <p>I have a number of outlets that are old and...
# 5      <p>The exterior walls on my house which is mad...
# 6      <p>The fan in the master-bathroom of my house ...
# 7      <p>One of my steam radiators has a small leak ...
# 8      <p>I know there are a lot of different ways to...
# 9      <p>I own a "cookie cutter" house built in 2006...
# 10     <p>My house has vinyl siding.  If I want to ha...
# 11     <p>My concrete seawall (on a freshwater lake) ...
# 12     <p>I have a leak in the second zone in my base...
# 13     <p>I have been doing some electrical work in m...
# 14     <p>I was trying to hang my TV at my new place,...
# 15     <p>I'd like to paint my garage floor, possibly...
# 16     <p>What is the difference between a framing ha...
# 17     <p>The previous owner didn't bother to lay dow...
# 18     <p>The day after grouting my tile, a white res...
# 19     <p>The toilet in our only bathroom seems to go...
# 20     <p>I live in New England and my asphalt drivew...
# 21     <p>Perhaps it is just me, but no matter how ca...
# 22     <p>We had a leak in our upstairs bathroom, abo...
# 23     <p>I just added on to my pole-barn garage, it ...
# 24     <p>Probably, due to faulty insulation/damp bar...
# 25     <p>I've installed a couple of transparent <a h...
# 26     <p>What are the tools that every DIY'er should...
# 27     <p>I have terrible soil in my yard, because th...
# 28     <p>I would like to upgrade my current water he...
# 29     <p>Essentially, I'd like to put down a concret...
# ...                                                  ...
# 25888  <p>I have a Whirlpool duet front loader washer...
# 25889  <p>This is kind of an odd one. Recently, my al...
# 25890  <p>i have old (late 1980's) recessed lighting....
# 25891  <p>I'm looking to add an occupancy sensor swit...
# 25892  <p>I bought this house a few years ago, built ...
# 25893  <p>I have a 240 volt gas generator that has a ...
# 25894  <p>My water pressure measures 80psi. When I sh...
# 25895  <p>At my new house there's already a <code>Lif...
# 25896  <p>This is the 2nd washing machine that has th...
# 25897  <p>I recently ordered an led strip off of amaz...
# 25898  <p>I have a Simpson Delta 422 washing machine,...
# 25899  <p>My house flooded with about 2 feet of water...
# 25900  <p>What would be the cheapest way to reduce ec...
# 25901  <p>As I seem to be collecting more and more De...
# 25902  <p>We have well water and Im unsure if that is...
# 25903  <p>I have been trying to find a solution for a...
# 25904  <p>We seem to have carpenter ants in our log h...
# 25905  <p>Have changed can lights to led, have some o...
# 25906  <p>Just got a strange issue where the kitchen ...
# 25907  <p>I live in a condo and want to change the do...
# 25908  <p>I need a new concrete subfloor due to water...
# 25909  <p>I know that code specifies the maximum hole...
# 25910  <p>Can you please tell me which wire/contact c...
# 25911  <p>I had a problem with a plug socket where th...
# 25912  <p>EDIT: I'm rephrasing the question, as it se...
# 25913  <p>I've got a major problem with rainfall wate...
# 25914  <p>I would like to add a second, remote thermo...
# 25915  <p>what could be the cause of this? The output...
# 25916  <p>This system is from the 60's era - the furn...
# 25917  <p>I have a problem, came home one morning to ...
#
#                                                     tags
# 0                          remodeling basement carpentry
# 1                                      caulking bathroom
# 2                                                drywall
# 3                          walls load-bearing structural
# 4                                      repair electrical
# 5                                           crack stucco
# 6                                                    fan
# 7                                               radiator
# 8                                      drywall wallpaper
# 9                                                windows
# 10                                          vinyl-siding
# 11                                              concrete
# 12                                  repair radiator pipe
# 13                  electrical fire-hazard knob-and-tube
# 14                           drywall walls framing studs
# 15                                    paint floor garage
# 16                                                 tools
# 17                                        paint bathroom
# 18                                            tile grout
# 19                               plumbing sealing toilet
# 20                                      asphalt driveway
# 21                                    caulking technique
# 22                                    paint ceiling leak
# 23                                         lighting pole
# 24                               draft baseboard sealing
# 25                             repair roof pvc treehouse
# 26                                                 tools
# 27                                                  lawn
# 28                        water-heater energy-efficiency
# 29                                    concrete technique
# ...                                                  ...
# 25888  circuit-breaker dryer washing-machine troubles...
# 25889                              alarm carbon-monoxide
# 25890                                  recessed-lighting
# 25891                           electrical wiring switch
# 25892                       concrete damage cement porch
# 25893                                          generator
# 25894                                           plumbing
# 25895                                 garage-door-opener
# 25896                                    washing-machine
# 25897                                     electrical led
# 25898                                    washing-machine
# 25899                     exterior vapor-barrier plastic
# 25900                              noise noise-reduction
# 25901                            plastic storage drawers
# 25902                          water water-pressure well
# 25903                         kitchens sealing carpentry
# 25904                                       pest-control
# 25905                            electrical-distribution
# 25906                                               sink
# 25907                                        doors knobs
# 25908                         concrete subfloor hardwood
# 25909                                  electrical wiring
# 25910                                         electrical
# 25911                           electrical wiring socket
# 25912    electrical wiring lighting light-fixture safety
# 25913                           water foundation grading
# 25914                                         thermostat
# 25915                                         electrical
# 25916                                  thermostat-c-wire
# 25917                                electrical lighting
#
# [25918 rows x 4 columns]

# %%
test = tmp.tail(1917)
train = tmp.head(24000)
validation = tmp.head(11500).tail(1500)

# %%
validation.head()
# Out:
#           id                                              title  \
# 10000  39812  When installing a stone fireplace, do I instal...
# 10001  39815            Why isn't my refrigerator getting cold?
# 10002  39826       Why is my washing machine making this sound?
# 10003  39831   Molten wire nuts on recessed MR16 halogen lights
# 10004  39835  What's the best way to shave off 1/8 of an inc...
#
#                                                  content  \
# 10000  <p>I have an existing, irregular river-stone f...
# 10001  <p>My compact fridge doesn't get cold, \nthe m...
# 10002  <p>I have uploaded a <a href="http://youtu.be/...
# 10003  <p>In one room of the apartment we rent, there...
# 10004  <p>When laying hardie backer I was told to mak...
#
#                                       tags
# 10000     wood woodworking fireplace stone
# 10001              appliances refrigerator
# 10002           appliances washing-machine
# 10003  electrical lighting ceiling halogen
# 10004               technique backer-board

# %%
train.head()
# Out:
#    id                                              title  \
# 0   1  How do I install a new, non load bearing wall ...
# 1   2  What kind of caulk should I use around my bath...
# 2   3  Is fiberglass mesh tape a good choice for dryw...
# 3   4  Are there ways to determine if a wall is load ...
# 4   5  How do I safely replace a worn out electrical ...
#
#                                              content  \
# 0  <p>I'm looking to finish my basement and simpl...
# 1  <p>I would like to recaulk between the bathtub...
# 2  <p>I'm going to be doing some drywalling short...
# 3  <p>Other than looking up blue prints, which ma...
# 4  <p>I have a number of outlets that are old and...
#
#                             tags
# 0  remodeling basement carpentry
# 1              caulking bathroom
# 2                        drywall
# 3  walls load-bearing structural
# 4              repair electrical

# %%
test.head()
# Out:
#           id                                              title  \
# 24001  92559                        Electric static new problem
# 24002  92562  Sprinkler valve solenoids won't activate at ma...
# 24003  92572  TV mount is 16.5" wide but stud centers are 17...
# 24004  92573  Forced air heater filter. Pros and Cons of reu...
# 24005  92574  Replace Track Lighting To Recessed Lights Util...
#
#                                                  content  \
# 24001  <p>Bought this house last year. Winter, no sta...
# 24002  <p>For years, the automatic sprinklers in my h...
# 24003  <p>I am not able to install the mount by posit...
# 24004  <p>When the gas service person came by to turn...
# 24005  <p>I had a Switch on one end of the kitchen an...
#
#                                                    tags
# 24001                                        electrical
# 24002           electrical sprinkler-system low-voltage
# 24003  drywall mounting studs drywall-anchor television
# 24004                                   hvac air-filter
# 24005        electrical wiring switch recessed-lighting

# %%
X_train, y_train = train['title'].values, train['tags'].values
X_val, y_val = validation['title'].values, validation['tags'].values
X_test = test['title'].values

# %%
y_train[1]
# Out:
# 'caulking bathroom'

# %%
import re

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))

def text_prepare(text):
    text = text.lower()
    text = REPLACE_BY_SPACE_RE.sub(' ', text)
    text = BAD_SYMBOLS_RE.sub('', text)
    text = ' '.join(word for word in text.split() if word not in STOPWORDS)
    #print(text)
    return text

# %%
# prepared_questions = []
# for line in open('text_prepare_tests.tsv', encoding='utf-8'):
#     line = text_prepare(line.strip())
#     prepared_questions.append(line)
# text_prepare_results = '\n'.join(prepared_questions)

# %%
X_train = [text_prepare(x) for x in X_train]
X_val = [text_prepare(x) for x in X_val]
X_test = [text_prepare(x) for x in X_test]

# %%
y_train[:3]
# Out:
# array(['remodeling basement carpentry', 'caulking bathroom', 'drywall'],
#       dtype=object)

# %%
from collections import defaultdict
tags_counts = defaultdict(int)
words_counts = defaultdict(int)
tmp=[]

for tags in y_train:
    tt = tags.split()
    tmp.append(tt)
    for tag in tt:
        #print(tag)
        tags_counts[tag] += 1
y_train=tmp
tmp=[]

for text in X_train:
    for word in text.split():
        #print(word)
        words_counts[word] += 1
        
for tags in y_val:
    tt = tags.split()
    tmp.append(tt)
    for tag in tt:
        #print(tag)
        tags_counts[tag] += 1
y_val=tmp
tmp=[]
for text in X_val:
    for word in text.split():
        #print(word)
        words_counts[word] += 1

# %%
most_common_tags = sorted(tags_counts.items(), key=lambda x: x[1], reverse=True)[:10]
most_common_words = sorted(words_counts.items(), key=lambda x: x[1], reverse=True)[:3]

# %%
most_common_words
# Out:
# [('water', 2009), ('wall', 1361), ('use', 1244)]

# %%
most_common_tags
# Out:
# [('electrical', 4358),
#  ('plumbing', 2207),
#  ('wiring', 1604),
#  ('lighting', 987),
#  ('hvac', 879),
#  ('bathroom', 878),
#  ('repair', 834),
#  ('water', 752),
#  ('wood', 725),
#  ('drywall', 717)]

# %%
from scipy import sparse as sp_sparse
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
??TfidVectorizer
# Out:
# Object `TfidVectorizer` not found.

# %%
#X_val

# %%
tfidf_vectorizer = TfidfVectorizer(min_df=5, max_df=0.9, ngram_range=(1, 2),token_pattern='(\S+)')
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_val_tfidf = tfidf_vectorizer.transform(X_val)
X_test_tfidf = tfidf_vectorizer.transform(X_test)
tfidf_vocab = tfidf_vectorizer.vocabulary_
#X_train_tfidf, X_val_tfidf, X_test_tfidf, tfidf_vocab = tfidf_features(X_train, X_val, X_test)

# %%
tfidf_reversed_vocab = {i:word for word,i in tfidf_vocab.items()}

# %%
tfidf_vocab['wall']
# Out:
# 4796

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# %%
tags_counts.keys()
# Out:
# dict_keys(['remodeling', 'basement', 'carpentry', 'caulking', 'bathroom', 'drywall', 'walls', 'load-bearing', 'structural', 'repair', 'electrical', 'crack', 'stucco', 'fan', 'radiator', 'wallpaper', 'windows', 'vinyl-siding', 'concrete', 'pipe', 'fire-hazard', 'knob-and-tube', 'framing', 'studs', 'paint', 'floor', 'garage', 'tools', 'tile', 'grout', 'plumbing', 'sealing', 'toilet', 'asphalt', 'driveway', 'technique', 'ceiling', 'leak', 'lighting', 'pole', 'draft', 'baseboard', 'roof', 'pvc', 'treehouse', 'lawn', 'water-heater', 'energy-efficiency', 'sound-proofing', 'basement-refinishing', 'carpet', 'sink', 'rust-removal', 'pocket-door', 'bathtub', 'insulation', 'attic', 'safety', 'afci', 'appliances', 'maintenance', 'layout', 'corner-bead', 'patch', 'spackle', 'patching-drywall', 'stairs', 'squeak', 'wood', 'hardwood-refinishing', 'hardwood', 'fence', 'painting', 'staining', 'pressure-treated', 'ventilation', 'wiring', 'brick', 'air-conditioning', 'installation', 'phone-wiring', 'exhaust-fan', 'asbestos', 'dangerous', 'health-and-safety', 'putty', 'replacement', 'exterior', 'conduit', 'coax', 'gutters', 'water', 'screens', 'pushfit', 'gas', 'doors', 'building-regulations', 'planning-permission', 'mold', 'foundation', 'deck', 'engineering', 'cinderblock', 'concrete-block', 'siding', 'shed', 'lumber', 'demolition', 'gravel', 'rock', 'sewer', 'copper-tubing', 'pex', 'fireplace', 'ceramic-tile', 'shower', 'temperature', 'fuse-breaker', 'aluminum-wiring', 'led', 'vapor-barrier', 'shingles', 'mortar', 'home-automation', 'hvac', 'forced-air', 'furnace', 'air-conditioner', 'vent', 'refrigerator', 'steam', 'lubrication', 'weep-hole', 'data-wiring', 'bundled-cables', 'patio', 'water-pressure', 'spraying', 'compressor', 'home-theater', 'audio', 'speakers', 'central-air', 'popcorn', 'precautions', 'nails', 'ductwork', 'cleaning', 'measuring', 'electric-motor', 'faucet', 'roofing', 'materials', 'porch-swing', 'laminate-floor', 'humidity', 'excavator', 'gardening', 'pavers', 'design', 'heating', 'boiler', 'smell', 'anchor', 'drywall-anchor', 'hardware', 'loft', 'sander', 'central-heating', 'mirror', 'hanging', 'trim', 'code-compliance', 'vanity', 'slab', 'air-quality', 'drainage', 'testing', 'air-filter', 'mosquitoes', 'pest', 'ants', 'pest-control', 'miter', 'blower', 'hiring', 'contractors', 'garage-door-opener', 'pool', 'drain-waste-vent', 'lennox', 'ceiling-fan', 'french-drain', 'level', 'flooding', 'sump-pump', 'software', 'drafting', 'downspout', 'rain', 'door-frame', 'fitting', 'flooring', 'heat-pump', 'screws', 'solar-panels', 'glue', 'radon', 'sprinkler-system', 'product-recommendation', 'grass', 'landscaping', 'severe-weather', 'weeds', 'water-tank', 'drains', 'construction', 'soldering', 'valve', 'shutoff', 'finishing', 'planning', 'workshop', 'kitchen-counters', 'child-safety', 'removal', 'microhood', 'hood', 'repainting', 'primer', 'preparation', 'water-softener', 'railing', 'energy-audit', 'dryer', 'timber-framing', 'weatherstripping', 'winterizing', 'washing-machine', 'linoleum', 'garbage-disposal', 'trash-can', 'stone', 'storm-door', 'fastener', 'gfci', 'breaker-box', 'septic', 'circuit-breaker', 'moss', 'well-pump', 'security', 'lock', 'water-hammer', 'crawlspace', 'inspection', 'acoustic', 'cfl', 'sanding', 'hardwood-floor', 'damage', 'finish', 'seal', 'vinyl-flooring', 'stove-top', 'glass-top-range', 'oven', 'woodworking', 'powertools', 'table-saw', 'ducts', 'septic-tanks', 'furniture', 'desk', 'steel', 'aluminum', 'drain', 'fans', 'meter', 'junction', 'lath-and-plaster', 'moisture', 'chimney', 'mice', 'extermination', 'turf', 'front-door', 'locks', 'odors', 'cable-management', 'shelving', 'noise-reduction', 'recessed-lighting', 'halogen', 'bulb', 'bolts', 'circuit', 'planting', 'thermostat', 'interior', 'switch', 'texture', 'chainsaw', 'drawers', 'self-assembly-furniture', 'wooden-furniture', 'outlets', 'kitchens', 'drill', 'receptacle', 'winter', 'cabinets', 'spackling-paste', 'pump', 'saw', 'joints', 'bath', 'diy-vs-p ...

# %%
y_val
# Out:
# [['wood', 'woodworking', 'fireplace', 'stone'],
#  ['appliances', 'refrigerator'],
#  ['appliances', 'washing-machine'],
#  ['electrical', 'lighting', 'ceiling', 'halogen'],
#  ['technique', 'backer-board'],
#  ['roof', 'attic', 'ventilation', 'dormer'],
#  ['bathroom', 'vent', 'exhaust-fan', 'hose'],
#  ['bulb'],
#  ['plumbing', 'repair', 'tools'],
#  ['hvac', 'furnace'],
#  ['electrical', 'grounding'],
#  ['steel', 'fastener'],
#  ['electrical', 'switch'],
#  ['mounting', 'glass', 'frame', 'railing'],
#  ['polyurethane'],
#  ['electrical', 'gfci'],
#  ['plumbing', 'drain-waste-vent'],
#  ['drain-waste-vent'],
#  ['electrical', 'wiring'],
#  ['deck', 'foundation'],
#  ['electrical', 'wiring', 'lighting', 'cfl'],
#  ['electrical', 'safety'],
#  ['bathroom', 'paint', 'mold'],
#  ['electrical'],
#  ['drainage', 'rain'],
#  ['lighting', 'ceiling'],
#  ['kitchens', 'removal', 'backsplash'],
#  ['foundation', 'drainage'],
#  ['hardwood-floor', 'polyurethane'],
#  ['repair'],
#  ['electrical', 'plumbing', 'water-heater', 'cord-and-plug'],
#  ['electrical', 'wiring', 'generator'],
#  ['bathroom', 'vent', 'renovation'],
#  ['kitchen-counters', 'wood-finishing'],
#  ['plumbing', 'sump-pump'],
#  ['shower', 'water-pressure'],
#  ['fence'],
#  ['sound-proofing', 'noise-reduction'],
#  ['ceiling', 'light-fixture'],
#  ['repair'],
#  ['concrete', 'tile', 'linoleum'],
#  ['dryer'],
#  ['water-heater', 'drain'],
#  ['concrete', 'metal', 'structural'],
#  ['hardwood-floor'],
#  ['bathroom', 'vanity'],
#  ['plumbing', 'radon', 'well'],
#  ['drywall', 'framing'],
#  ['washing-machine'],
#  ['wood', 'walls', 'sound-proofing'],
#  ['cleaning', 'refrigerator', 'smell'],
#  ['flooring', 'noise-reduction'],
#  ['bathroom', 'door-frame'],
#  ['windows', 'cleaning', 'glass'],
#  ['hardwood-floor', 'wood-finish'],
#  ['plumbing', 'bathroom', 'drain-waste-vent', 'rough-in'],
#  ['wood', 'countertops'],
#  ['compressor'],
#  ['hardwood-floor'],
#  ['kitchens', 'floor'],
#  ['painting', 'primer', 'sanding'],
#  ['concrete', 'shower', 'tile', 'code-compliance', 'thinset'],
#  ['plumbing', 'drain-waste-vent'],
#  ['garage', 'lock', 'garage-door'],
#  ['plumbing', 'bathroom', 'basement'],
#  ['electrical', 'repair'],
#  ['thermostat', 'thermostat-c-wire'],
#  ['paint', 'voc'],
#  ['insulation'],
#  ['plumbing'],
#  ['toilet'],
#  ['garbage-disposal'],
#  ['security', 'lock'],
#  ['wind'],
#  ['electrical', 'lighting', 'light-fixture', 'new-home'],
#  ['tile', 'subfloor'],
#  ['electrical', 'wiring', 'new-home'],
#  ['ceiling', 'construction', 'measuring'],
#  ['screws'],
#  ['tile', 'mounting', 'brackets'],
#  ['toilet'],
#  ['insulation', 'fireplace'],
#  ['insulation', 'basement'],
#  ['heating', 'water-heater', 'air-conditioning'],
#  ['concrete', 'kitchens', 'drain'],
#  ['fire-extinguisher'],
#  ['hvac', 'kitchens'],
#  ['tile', 'floor'],
#  ['patio', 'pavers'],
#  ['roof', 'shingles'],
#  ['hardwood-floor'],
#  ['drywall', 'walls', 'basement'],
#  ['hvac', 'furnace', 'central-heating'],
#  ['heating', 'heat-pump'],
#  ['carpentry', 'baseboard', 'lumber'],
#  ['electrical', 'safety'],
#  ['leak', 'faucet', 'outdoor', 'hose'],
#  ['staining', 'baseboard', 'lumber'],
#  ['repair', 'foundation'],
#  ['electrical', 'lighting', 'electrical-distribution', 'nec'],
#  ['electrical', 'lighting', 'electrical-distribution', 'nec'],
#  ['materials'],
#  ['insulation', 'air-conditioning', 'cooling'],
#  ['mold', 'washing-machine', 'smell'],
#  ['flooring', 'tile', 'level', 'self-leveling-concrete'],
#  ['brick'],
#  ['electrical', 'heating', 'thermostat'],
#  ['hardwood-floor'],
#  ['installation'],
#  ['sink', 'drainage'],
#  ['data-wiring', 'speakers'],
#  ['drain', 'mold'],
#  ['pest-control'],
#  ['air-conditioning', 'cooling'],
#  ['deck', 'drainage'],
#  ['electrical', 'thermostat-c-wire'],
#  ['electrical'],
#  ['plumbing'],
#  ['repair', 'plaster'],
#  ['repair', 'lath-and-plaster'],
#  ['insulation'],
#  ['switch'],
#  ['windows', 'framing', 'renovation', 'temporary'],
#  ['repair', 'lock'],
#  ['sump-pump'],
#  ['shower', 'tile', 'waterproofing', 'backer-board', 'thinset'],
#  ['hvac', 'air-conditioning', 'central-air'],
#  ['subfloor'],
#  ['plumbing'],
#  ['repainting', 'health-and-safety', 'stove-top', 'rust-proofing'],
#  ['electrical', 'circuit-breaker'],
#  ['repair', 'microwave-oven'],
#  ['electrical', 'wiring', 'walls'],
#  ['cleaning', 'woodworking', 'varnishing'],
#  ['electric-motor'],
#  ['repair', 'framing', 'joists'],
#  ['electrical'],
#  ['electrical'],
#  ['garbage-disposal'],
#  ['hvac', 'kitchens', 'furnace'],
#  ['plumbing'],
#  ['deck', 'pool', 'plastic', 'remove'],
#  ['plumbing', 'code-compliance', 'framing', 'joists'],
#  ['insulation'],
#  ['boiler', 'water-circulating-heating', 'radiant-heating'],
#  ['light-fixture', 'removal'],
#  ['tools', 'woodworking', 'cabinets', 'custom-cabinetry'],
#  ['hinges', 'particle-board'],
#  ['water', 'water-filtration'],
#  ['basement'],
#  ['appliances', 'washing-machine'],
#  ['plumbing', 'shower', 'valve'],
#  ['electrical'],
#  ['plumbing'],
#  ['electrical', 'removal', 'recessed-lighting', 'patching-drywall'],
#  ['repair', 'leak'],
#  ['vent', 'dryer', 'exhaust-vent'],
#  ['gfci', 'garbage-disposal'],
#  ['fireplace'],
#  ['wood', 'woodworking', 'drill', 'sanding', 'hole'],
#  ['tiling', 'thinset'],
#  ['walls', 'framing'],
#  ['plumbing', 'faucet'],
#  ['windows', 'trim'],
#  ['code-compliance', 'framing', 'sound-proofing'],
#  ['wood', 'wooden-furniture', 'epoxy'],
#  ['septic', 'new-home', 'septic-tanks'],
#  ['electrical', 'lighting', 'switch', 'remodeling'],
#  ['shower', 'tiling'],
#  ['sanding', 'polyurethane'],
#  ['tile', 'subfloor', 'ceramic-tile', 'cement-board', 'remove'],
#  ['painting'],
#  ['electrical'],
#  ['electrical'],
#  ['doors', 'exterior', 'structural'],
#  ['electrical', 'circuit-breaker', 'old-work'],
#  ['lock'],
#  ['insulation', 'basement-refinishing'],
#  ['dryer', 'circuit-breaker'],
#  ['painting', 'alkyd'],
#  ['central-heating'],
#  ['plumbing', 'water-heater', 'tankless'],
#  ['rust-removal', 'remove'],
#  ['doors', 'severe-weather'],
#  ['electrical'],
#  ['water', 'water-pressure'],
#  ['landscaping', 'wire'],
#  ['bolts'],
#  ['plumbing', 'toilet'],
#  ['wood'],
#  ['sink', 'bathtub'],
#  ['electrical', 'extension-cord'],
#  ['electrical', 'insulation', 'knob-and-tube'],
#  ['electrical', 'screws', 'circuit-breaker'],
#  ['pvc', 'cutting'],
#  ['electrical', 'lighting', 'windows', 'security', 'motion-sensor'],
#  ['wiring', 'furnace', 'thermostat', 'thermostat-c-wire'],
#  ['electrical'],
#  ['bathroom'],
#  ['bathroom', 'exhaust-fan'],
#  ['plumbing', 'leak', 'drain'],
#  ['repair'],
#  ['drywall', 'concrete', 'moisture'],
#  ['repair', 'walls', 'exterior'],
#  ['cleaning', 'laminate'],
#  ['security'],
#  ['electrical', 'circuit-breaker'],
#  ['electrical', 'breaker-box'],
#  ['lighting', 'energy-efficiency', 'motion-sensor'],
#  ['drawers'],
#  ['drywall', 'ceiling', 'light-fixture', 'recessed-lighting'],
#  ['electrical', 'circuit-breaker'],
#  ['bathroom', 'fans'],
#  ['electrical', 'mounting', 'studs', 'mirror'],
#  ['concrete'],
#  ['woodworking', 'furniture', 'table'],
#  ['electrical'],
#  ['hvac', 'air-conditioning', 'replacement'],
#  ['driveway'],
#  ['insulation', 'attic', 'air-quality'],
#  ['air-quality'],
#  ['painting', 'paint', 'exterior', 'repainting', 'contractors'],
#  ['painting'],
#  ['insulation', 'concrete', 'foundation', 'footings'],
#  ['bathroom', 'insulation', 'shower', 'vapor-barrier'],
#  ['drill', 'shelving', 'drywall-anchor'],
#  ['appliances'],
#  ['powertools', 'routers', 'cutting', 'ladder', 'hand-tools'],
#  ['tools', 'screws', 'bolts', 'hand-tools'],
#  ['water', 'vapor-barrier'],
#  ['electrical', 'wiring'],
#  ['baseboard'],
#  ['plumbing', 'water', 'refrigerator'],
#  ['repair', 'bathroom', 'shower', 'bathroom-fixtures'],
#  ['materials'],
#  ['electrical'],
#  ['self-assembly-furniture'],
#  ['brick', 'fireplace', 'chimney'],
#  ['electrical'],
#  ['basement'],
#  ['ceiling', 'garage', 'structural', 'load-bearing'],
#  ['bathroom', 'ceiling', 'waterproofing'],
#  ['electrical'],
#  ['plumbing'],
#  ['air-conditioning'],
#  ['bathroom', 'tub'],
#  ['gutters'],
#  ['drywall', 'adhesive'],
#  ['electrical'],
#  ['repair', 'adhesive', 'plastic'],
#  ['adhesive', 'plastic'],
#  ['cleaning', 'filter'],
#  ['garage', 'garage-door'],
#  ['remodeling'],
#  ['kitchens', 'cleaning'],
#  ['electrical', 'code-compliance', 'breaker-box'],
#  ['electrical', 'vent', 'foundation', 'crawlspace', 'solar-panels'],
#  ['electrical'],
#  ['fireplace'],
#  ['tile', 'paint', 'repainting'],
#  ['fence', 'pet-proofing'],
#  ['basement'],
#  ['windows', 'curtain-rail'],
#  ['flooring', 'transition'],
#  ['circuit-breaker', 'circuit'],
#  ['foundation', 'pest-control', 'landscaping', 'pest'],
#  ['electrical', 'wiring', 'garage'],
#  ['washing-machine'],
#  ['insulation', 'walls', 'basement'],
#  ['electrical'],
#  ['lighting'],
#  ['water-heater', 'furnace', 'storage'],
#  ['garage-door-opener', 'motion-sensor'],
#  ['flooring', 'hardwood-floor', 'carpet', 'subfloor', 'transition'],
#  ['plumbing', 'bathroom', 'subfloor'],
#  ['bathroom', 'exhaust-fan', 'exhaust-vent', 'timer'],
#  ['electrical'],
#  ['safety', 'outdoor', 'chainsaw'],
#  ['installation', 'fence', 'patio'],
#  ['kitchens', 'screws'],
#  ['shower', 'removal', 'caulk', 'silicone'],
#  ['asbestos'],
#  ['hardwood-floor', 'hardwood', 'hardwood-refinishing'],
#  ['walls', 'noise-reduction'],
#  ['hardwood-floor', 'appliances', 'water-damage'],
#  ['propane'],
#  ['health-and-safety'],
#  ['powertools'],
#  ['drywall', 'walls'],
#  ['wood', 'trim', 'finishing'],
#  ['bathroom', 'leak', 'sealing', 'tub'],
#  ['cleaning', 'paint', 'deck'],
#  ['plumbing', 'bathtub'],
#  ['refrigerator', 'mold', 'smell'],
#  ['lighting'],
#  ['garage-door'],
#  ['switch'],
#  ['windows'],
#  ['doorknob'],
#  ['walls', 'air-conditioning', 'installation', 'framing'],
#  ['flooring', 'kitchens', 'caulking'],
#  ['siding'],
#  ['joists', 'structural', 'blocking'],
#  ['toilet'],
#  ['doors', 'tile'],
#  ['concrete', 'garage', 'crack', 'render'],
#  ['repair', 'bathroom', 'waterproofing', 'plaster', 'water-damage'],
#  ['electrical', 'wiring', 'switch', 'circuit'],
#  ['plumbing', 'faucet', 'hose'],
#  ['wiring', 'basement'],
#  ['repair', 'drywall'],
#  ['installation', 'table'],
#  ['hvac', 'radiator', 'humidity', 'humidifier'],
#  ['heating', 'materials'],
#  ['staining', 'pine'],
#  ['heating', 'gas', 'heat-pump'],
#  ['plumbing', 'water', 'health-and-safety', 'chemicals', 'water-filtration'],
#  ['doors', 'lock'],
#  ['woodworking', 'polyurethane', 'wood-finishing'],
#  ['electrical'],
#  ['electrical', 'grounding'],
#  ['repair', 'plaster', 'lath-and-plaster'],
#  ['water', 'water-heater', 'water-pressure'],
#  ['air-filter', 'measuring', 'air-quality'],
#  ['bathroom', 'shower'],
#  ['walls', 'remodeling', 'support'],
#  ['drain-waste-vent'],
#  ['electrical'],
#  ['heating',
#   'air-conditioning',
#   'central-heating',
#   'central-air',
#   'heat-pump'],
#  ['safety'],
#  ['water-pressure'],
#  ['electrical'],
#  ['flooring', 'moisture', 'hardwood'],
#  ['bathroom', 'toilet', 'valve'],
#  ['termite'],
#  ['walls', 'safety'],
#  ['hvac', 'basement', 'temperature'],
#  ['water-heater', 'valve', 'replacement', 'natural-gas'],
#  ['concrete', 'damage', 'caulk'],
#  ['wood', 'pest-control'],
#  ['repair', 'dryer'],
#  ['roofing', 'shed', 'timber-framing'],
#  ['shower', 'hot-water'],
#  ['circuit'],
#  ['flooring', 'laminate'],
#  ['sump-pump', '240v'],
#  ['fence', 'staining'],
#  ['electrical', 'lighting', 'light-fixture'],
#  ['thermostat'],
#  ['toilet', 'replacement'],
#  ['foundation', 'shed', 'wind'],
#  ['electrical'],
#  ['insulation', 'basement'],
#  ['thermostat-c-wire'],
#  ['doors'],
#  ['doors', 'paint', 'noise', 'door-frame', 'noise-reduction'],
#  ['electrical', 'troubleshooting'],
#  ['electrical', 'wiring', 'meter'],
#  ['refrigerator'],
#  ['wood', 'wooden-furniture'],
#  ['repair', 'drill'],
#  ['drywall', 'framing', 'studs', 'structural'],
#  ['termite'],
#  ['water-damage'],
#  ['electrical', 'ceiling', 'junction-box'],
#  ['furnace'],
#  ['plumbing', 'drain'],
#  ['shower', 'water-heater', 'energy-efficiency', 'hot-water'],
#  ['maintenance'],
#  ['wood', 'patch'],
#  ['plumbing', 'drain-waste-vent', 'plumbing-fixture'],
#  ['refrigerator', 'compressor'],
#  ['water', 'roof', 'gutters'],
#  ['wooden-furniture', 'polyurethane'],
#  ['concrete', 'walls'],
#  ['electrical', 'wiring', 'grounding'],
#  ['walls', 'mounting'],
#  ['hvac', 'vent', 'framing', 'studs', 'exhaust-vent'],
#  ['plumbing', 'kitchens', 'drain', 'drain-waste-vent'],
#  ['thermostat', 'cooling', 'thermostat-c-wire'],
#  ['central-air'],
#  ['dryer'],
#  ['crawlspace'],
#  ['basement', 'ceiling', 'framing', 'egress'],
#  ['materials', 'lumber', 'planning'],
#  ['insulation', 'windows', 'stucco'],
#  ['wood', 'furniture', 'finishing', 'polyurethane'],
#  ['mortar'],
#  ['wooden-furniture', 'table', 'recycling'],
#  ['kitchens', 'cabinets'],
#  ['heating', 'installation', 'solar-panels'],
#  ['concrete', 'floor'],
#  ['pool', 'pump'],
#  ['repainting'],
#  ['garage', 'attic', 'support'],
#  ['garage-door-opener'],
#  ['toilet', 'drain-waste-vent', 'sewer'],
#  ['roof', 'shingles', 'metal-roof'],
#  ['flooring'],
#  ['drywall', 'adhesive'],
#  ['electrical', 'code-compliance', 'wire', 'doorbell'],
#  ['plumbing'],
#  ['flooring'],
#  ['repair', 'foundation'],
#  ['doors', 'glass', 'frame', 'aluminum', 'closer'],
#  ['drywall', 'shower'],
#  ['wiring'],
#  ['exterior', 'masonry'],
#  ['electrical', 'stove-top', 'cost-effective'],
#  ['wiring', 'repair'],
#  ['plumbing', 'valve'],
#  ['plumbing', 'drain', 'washing-machine'],
#  ['fireplace'],
#  ['electrical', 'circuit'],
#  ['concrete-block', 'retaining-wall'],
#  ['basement'],
#  ['lighting', 'led'],
#  ['electrical'],
#  ['design', 'engineering', 'gates'],
#  ['wiring', 'lighting', 'mirror'],
#  ['crawlspace'],
#  ['conduit'],
#  ['water', 'irrigation'],
#  ['siding'],
#  ['hvac', 'heating', 'air-conditioning', 'central-heating', 'central-air'],
#  ['plumbing'],
#  ['insulation', 'stucco'],
#  ['drywall', 'hvac', 'walls'],
#  ['appliances', 'refrigerator', 'water-filtration'],
#  ['electrical', 'garage', 'code-compliance', 'subpanel'],
#  ['electrical', 'garage', 'code-compliance', 'subpanel'],
#  ['electrical', 'garage', 'code-compliance', 'subpanel'],
#  ['electrical', 'code-compliance'],
#  ['kitchens', 'refrigerator'],
#  ['doors', 'interior'],
#  ['hvac', 'ducts', 'noise-reduction'],
#  ['leak', 'water-heater', 'natural-gas'],
#  ['bathroom', 'installation', 'framing', 'sink'],
#  ['insulation', 'drainage', 'footings', 'termite'],
#  ['electrical', 'oven'],
#  ['deck', 'decking'],
#  ['adhesive'],
#  ['drywall', 'basement', 'joists', 'carpentry'],
#  ['electrical', 'gfci'],
#  ['light-fixture'],
#  ['electrical', 'light-fixture', 'junction-box'],
#  ['plumbing', 'shower', 'sink', 'drain', 'clog'],
#  ['powertools', 'acrylic', 'hand-tools'],
#  ['cooling'],
#  ['electrical', 'lighting'],
#  ['electrical'],
#  ['windows', 'tile'],
#  ['repair', 'leak', 'sealing'],
#  ['hvac', 'retrofit'],
#  ['doors'],
#  ['electrical', 'wiring', 'grounding'],
#  ['woodworking', 'staining'],
#  ['asbestos'],
#  ['electrical', 'energy-efficiency'],
#  ['bathroom', 'vent'],
#  ['drainage'],
#  ['heating', 'fireplace'],
#  ['water', 'pool'],
#  ['trim', 'mdf', 'trim-carpentry'],
#  ['concrete', 'stairs', 'construction', 'mosaic'],
#  ['walls', 'paint', 'repainting'],
#  ['clothes-washer'],
#  ['gas'],
#  ['deck'],
#  ['roof', 'roofing', 'shingles'],
#  ['insulation'],
#  ['furnace', 'ducts', 'air-leaks'],
#  ['electrical'],
#  ['kitchens', 'drain'],
#  ['outdoor', 'stairs', 'lumber', 'nails'],
#  ['plaster', 'studs'],
#  ['screws', 'outdoor', 'lumber'],
#  ['cables', 'extension', 'protection', 'extension-cord'],
#  ['electrical', 'circuit-breaker', 'receptacle'],
#  ['basement', 'framing', 'sealing', 'subfloor'],
#  ['cleaning'],
#  ['tools'],
#  ['plumbing', 'installation', 'washing-machine', 'plumbing-fixture'],
#  ['hvac', 'vent', 'boiler'],
#  ['wood', 'baseboard', 'masonry', 'nails'],
#  ['repair', 'appliances', 'washing-machine'],
#  ['plumbing', 'drains'],
#  ['wiring', 'switch', 'receptacle'],
#  ['heating', 'thermostat', 'central-heating'],
#  ['wood'],
#  ['electrical', 'materials', 'terminology'],
#  ['fireplace'],
#  ['heating', 'leak'],
#  ['electrical', 'code-compliance', 'junction-box'],
#  ['plumbing'],
#  ['electrical', 'hot-tub'],
#  ['concrete'],
#  ['repair', 'sewer'],
#  ['lighting', 'concrete', 'tile'],
#  ['furnace'],
#  ['electrical'],
#  ['lock'],
#  ['sealing', 'driveway'],
#  ['repair', 'flooring', 'hardwood-floor', 'damage'],
#  ['plumbing', 'gutters', 'bolts', 'downspout'],
#  ['doors', 'closer'],
#  ['safety', 'utilities'],
#  ['repair', 'laminate-floor'],
#  ['electrical'],
#  ['sound-proofing'],
#  ['flooring', 'floor'],
#  ['electrical'],
#  ['basement', 'mortar', 'masonry'],
#  ['drywall', 'patching-drywall'],
#  ['repair', 'wood', 'furniture', 'epoxy', 'dry-rot'],
#  ['electrical'],
#  ['safety', 'circuit-breaker', 'receptacle', 'extension-cord'],
#  ['wood', 'attic', 'mounting', 'screens'],
#  ['repair'],
#  ['electrical', 'lighting'],
#  ['drywall', 'walls', 'shelving', 'hanging'],
#  ['removal', 'speakers', 'cover'],
#  ['repair', 'shower', 'marble'],
#  ['electrical', 'wiring', 'utilities'],
#  ['electrical', 'wiring', 'lighting', 'switch'],
#  ['tools', 'hand-tools'],
#  ['sprinkler-system'],
#  ['stairs'],
#  ['wood', 'exterior', 'staining'],
#  ['wood', 'woodworking'],
#  ['wiring', 'circuit-breaker'],
#  ['hvac'],
#  ['plumbing', 'flooring'],
#  ['painting', 'measuring'],
#  ['walls', 'load-bearing'],
#  ['basement', 'woodworking', 'fire-hazard', 'workshop'],
#  ['drainage'],
#  ['masonry'],
#  ['electrical'],
#  ['concrete'],
#  ['cabinets'],
#  ['wiring', 'disposal'],
#  ['flooring', 'floor', 'carpentry', 'measuring', 'custom-cabinetry'],
#  ['windows', 'condensation', 'render'],
#  ['walls', 'plaster', 'primer'],
#  ['repair', 'doors', 'refrigerator'],
#  ['plumbing'],
#  ['lighting'],
#  ['tile', 'demolition', 'thinset'],
#  ['installation', 'carpet'],
#  ['concrete', 'driveway'],
#  ['electrical', 'wiring'],
#  ['plumbing', 'bathroom'],
#  ['air-conditioning'],
#  ['thermostat', 'thermostat-c-wire'],
#  ['faucet'],
#  ['bathroom', 'gfci'],
#  ['design', 'hardware'],
#  ['basement', 'foundation', 'crawlspace', 'sump-pump'],
#  ['insulation'],
#  ['tile', 'outdoor', 'grout', 'thinset', 'mosaic'],
#  ['drill', 'metal'],
#  ['electrical', 'testing'],
#  ['doors', 'noise-reduction', 'closer'],
#  ['doors', 'screens'],
#  ['cleaning'],
#  ['water', 'heater', 'propane'],
#  ['wood', 'lubrication', 'silicone'],
#  ['electrical', 'drain', 'grounding'],
#  ['furnace', 'energy-efficiency', 'electric-motor', 'blower'],
#  ['shed', 'footings'],
#  ['tile', 'grout'],
#  ['tools', 'battery'],
#  ['insulation'],
#  ['vinyl-siding'],
#  ['wiring', 'attic'],
#  ['flooring'],
#  ['flooring', 'attic'],
#  ['plumbing', 'well-pump'],
#  ['doors', 'shower'],
#  ['outdoor', 'lumber', 'retaining-wall'],
#  ['aluminum', 'miter', 'bandsaw', 'table-saw'],
#  ['wood', 'woodworking'],
#  ['electrical'],
#  ['painting'],
#  ['bulb'],
#  ['drywall', 'walls', 'hole'],
#  ['electrical', 'kitchens', 'code-compliance'],
#  ['plumbing', 'pool', 'hose'],
#  ['wiring', 'hvac', 'thermostat'],
#  ['fence', 'pvc'],
#  ['structural', 'engineering'],
#  ['installation', 'fence'],
#  ['plumbing', 'drain', 'sewer', 'septic', 'clog'],
#  ['water-softener', 'hot-water', 'well'],
#  ['bulb'],
#  ['electrical', 'ceiling-fan'],
#  ['furnace'],
#  ['electrical', 'receptacle'],
#  ['blinds'],
#  ['painting', 'primer', 'mdf'],
#  ['data-wiring', 'telephone'],
#  ['wire'],
#  ['oven'],
#  ['wood', 'insulation', 'masonry', 'green'],
#  ['windows', 'energy-efficiency', 'blinds', 'green'],
#  ['plumbing', 'pipe', 'drain-waste-vent'],
#  ['attic', 'stairs'],
#  ['tile', 'technique', 'thinset', 'mosaic'],
#  ['insulation', 'attic', 'energy-efficiency', 'exhaust-fan', 'fans'],
#  ['installation', 'lamp'],
#  ['electrical', 'wire'],
#  ['sprinkler-system', 'irrigation'],
#  ['air-conditioning', 'evaporative-cooling'],
#  ['drain', 'bathtub', 'removal'],
#  ['concrete', 'fence'],
#  ['doors', 'lock'],
#  ['electrical', 'appliances'],
#  ['floor', 'level'],
#  ['lighting', 'bulb'],
#  ['joists', 'structural'],
#  ['basement', 'fastener', 'sill'],
#  ['plumbing', 'outdoor', 'sprinkler-system', 'lawn', 'irrigation'],
#  ['wood', 'woodworking'],
#  ['electrical', 'wiring', 'pool', 'pump'],
#  ['pool', 'filter'],
#  ['insulation', 'concrete', 'foundation', 'moisture'],
#  ['furnace', 'boiler', 'hot-water'],
#  ['foundation', 'drainage', 'structural', 'french-drain'],
#  ['electrical', 'switch', 'ceiling-fan'],
#  ['repair', 'water', 'pool', 'crack', 'fiberglass'],
#  ['concrete'],
#  ['hardwood-floor', 'hardwood-refinishing'],
#  ['hvac', 'air-conditioning', 'garage'],
#  ['walls', 'mounting', 'shelving'],
#  ['troubleshooting', 'lawn-mower', 'engine'],
#  ['roofing'],
#  ['dryer', 'venting'],
#  ['tile', 'remodeling', 'tiling'],
#  ['electrical', 'gfci', 'receptacle'],
#  ['bathroom', 'vent', 'exhaust-fan'],
#  ['repair', 'dryer', 'appliances', 'stove'],
#  ['washing-machine', 'clothes-washer'],
#  ['drywall', 'kitchens'],
#  ['walls', 'landscaping', 'retaining-wall'],
#  ['electrical', 'wiring'],
#  ['cabling', 'bundled-cables'],
#  ['insulation', 'basement'],
#  ['lighting', 'switch', 'led'],
#  ['roof', 'carpentry', 'patio', 'ledger'],
#  ['electrical'],
#  ['gfci', 'troubleshooting', 'circuit'],
#  ['electrical', 'wiring', 'lighting'],
#  ['doors', 'lock', 'home-automation'],
#  ['joists', 'decking'],
#  ['plumbing', 'pipe', 'pvc', 'adhesive', 'sprinkler-system'],
#  ['roof', 'attic'],
#  ['pest-control', 'pest'],
#  ['patio', 'pavers'],
#  ['bathroom', 'ducts'],
#  ['electrical', 'kitchens', 'safety'],
#  ['electrical', 'wiring', 'ceiling-fan'],
#  ['bathroom', 'tile', 'crack'],
#  ['wiring'],
#  ['electrical'],
#  ['exterior', 'brick', 'crack', 'mortar'],
#  ['hardwood-floor', 'subfloor', 'engineered-flooring'],
#  ['electrical', 'ceiling-fan', 'fans'],
#  ['electrical', 'wiring', 'data-wiring'],
#  ['deck', 'joists', 'ledger'],
#  ['plumbing', 'kitchens', 'drain', 'putty'],
#  ['painting'],
#  ['windows', 'screws', 'drill', 'hanging', 'drywall-anchor'],
#  ['electric-motor'],
#  ['240v'],
#  ['mold', 'insect'],
#  ['brick', 'gas', 'fireplace', 'removal'],
#  ['concrete', 'brick', 'mortar', 'patio', 'architecture'],
#  ['plumbing', 'kitchens', 'leak', 'roof'],
#  ['water-softener'],
#  ['painting', 'trim', 'interior', 'spraypainting'],
#  ['custom-cabinetry'],
#  ['termite', 'underground'],
#  ['electrical', 'lighting', 'light-fixture', 'closet'],
#  ['drill', 'powertools', 'damage'],
#  ['electrical', 'lighting', 'light-fixture', 'recessed-lighting'],
#  ['plumbing'],
#  ['electrical'],
#  ['bathroom', 'tile', 'caulking'],
#  ['wood', 'flooring', 'hardwood-floor', 'hardwood', 'engineered-flooring'],
#  ['ceiling', 'garage'],
#  ['cabinets', 'carpentry'],
#  ['shower'],
#  ['plumbing', 'water', 'filter', 'corrosion'],
#  ['electrical', 'wiring', 'hvac', 'home-automation'],
#  ['asbestos'],
#  ['plumbing', 'water-heater'],
#  ['electrical', 'switch', 'receptacle'],
#  ['powertools'],
#  ['roof', 'carpentry', 'patio', 'ledger', 'cover'],
#  ['walls', 'tile', 'plaster', 'ceramic-tile'],
#  ['electrical'],
#  ['concrete'],
#  ['kitchens', 'framing', 'natural-gas'],
#  ['crawlspace'],
#  ['sump-pump'],
#  ['kitchens', 'finishing'],
#  ['electrical', 'receptacle'],
#  ['plumbing', 'water', 'sprinkler-system', 'winterizing'],
#  ['electrical', 'doorbell'],
#  ['drywall', 'kitchens', 'cabinets'],
#  ['electrical', 'wiring', 'grounding'],
#  ['plumbing', 'drain-waste-vent', 'sewer'],
#  ['wood', 'floor'],
#  ['plumbing', 'exterior'],
#  ['construction'],
#  ['repair', 'concrete', 'walls', 'brick', 'structural'],
#  ['hvac', 'lennox'],
#  ['metal', 'brackets'],
#  ['lighting', 'exterior', 'wire', 'conduit'],
#  ['wire', 'underground'],
#  ['joints', 'aluminum'],
#  ['screws'],
#  ['wiring', 'cabling', 'speakers'],
#  ['tile', 'ceramic-tile'],
#  ['electrical', 'hvac', 'air-conditioning', 'circuit-breaker'],
#  ['electrical', 'stove', 'stove-top'],
#  ['electrical', 'outdoor'],
#  ['electrical'],
#  ['pipe', 'sewer', 'septic'],
#  ['lighting'],
#  ['insulation', 'furnace', 'framing', 'ducts'],
#  ['furnace', 'ducts', 'radiant-barrier'],
#  ['wiring', 'exterior', 'coax'],
#  ['floor'],
#  ['foundation', 'crawlspace', 'pier-blocks'],
#  ['adhesive', 'acrylic'],
#  ['woodworking', 'saw'],
#  ['electrical', 'switch'],
#  ['sink', 'rust-removal'],
#  ['tools', 'bolts'],
#  ['plumbing', 'insulation', 'freezing'],
#  ['screws'],
#  ['baseboard', 'nails'],
#  ['flooring', 'level', 'support'],
#  ['cleaning', 'removal', 'asphalt'],
#  ['plumbing', 'pipe'],
#  ['plumbing', 'insulation', 'pipe', 'freezing'],
#  ['electrical'],
#  ['heating', 'furnace', 'energy-efficiency', 'heat-pump'],
#  ['electrical', 'code-compliance', 'electrical-distribution'],
#  ['plaster'],
#  ['stairs'],
#  ['electrical', 'code-compliance', 'pvc', 'driveway', 'conduit'],
#  ['insulation', 'thermostat', 'chimney'],
#  ['electrical'],
#  ['fireplace'],
#  ['concrete', 'brick', 'drainage', 'landscaping'],
#  ['plumbing', 'toilet', 'renovation'],
#  ['basement', 'floor', 'drain', 'level', 'self-leveling-concrete'],
#  ['electrical'],
#  ['plumbing'],
#  ['wood', 'woodworking', 'wood-finishing'],
#  ['trim', 'moisture', 'door-frame'],
#  ['projector'],
#  ['windows', 'framing', 'foundation'],
#  ['radiator'],
#  ['wiring', 'drywall', 'garage', 'caulking', 'vinyl-siding'],
#  ['carpet', 'built-ins'],
#  ['toilet'],
#  ['wiring'],
#  ['screws', 'cord-and-plug'],
#  ['electrical'],
#  ['plumbing', 'outdoor', 'taps'],
#  ['plumbing', 'water', 'refrigerator', 'interior'],
#  ['electrical', 'circuit-breaker'],
#  ['thermostat'],
#  ['roofing', 'metal'],
#  ['hvac'],
#  ['plumbing', 'water', 'refrigerator', 'copper-tubing'],
#  ['plumbing', 'water', 'valve'],
#  ['kitchens'],
#  ['ceiling', 'structural', 'renovation'],
#  ['structural'],
#  ['hvac'],
#  ['tile', 'fireplace', 'subfloor', 'granite'],
#  ['flooring', 'asbestos', 'health-and-safety', 'renovation', 'linoleum'],
#  ['plumbing', 'bathroom', 'shower'],
#  ['circular-saw'],
#  ['hvac'],
#  ['roof', 'roofing', 'shingles'],
#  ['gas', 'oven'],
#  ['hvac', 'cleaning', 'air-conditioning'],
#  ['drywall', 'basement', 'moisture'],
#  ['coaxial-cable'],
#  ['plywood', 'water-damage'],
#  ['bathtub'],
#  ['mold', 'inspection', 'rental'],
#  ['dishwasher'],
#  ['electrical'],
#  ['home-automation'],
#  ['evaporative-cooling'],
#  ['fence'],
#  ['electrical', 'wiring', 'lighting', 'light-fixture'],
#  ['repair', 'fence'],
#  ['shower'],
#  ['electrical'],
#  ['plumbing', 'drain-waste-vent', 'lead'],
#  ['plumbing', 'pex'],
#  ['plumbing', 'pex'],
#  ['refrigerator'],
#  ['kitchens', 'cabinets'],
#  ['electrical', 'wiring', 'safety', 'dryer', 'fire-hazard'],
#  ['outdoor', 'post'],
#  ['data-wiring'],
#  ['drill', 'hole'],
#  ['coax'],
#  ['pool'],
#  ['pvc', 'joints'],
#  ['plumbing', 'boiler', 'water-pressure', 'water-tank'],
#  ['safety', 'gates'],
#  ['lighting', 'garage-door-opener'],
#  ['plumbing', 'water', 'water-pressure', 'sprinkler-system', 'irrigation'],
#  ['electrical', 'garbage-disposal'],
#  ['paint', 'repainting'],
#  ['electric-motor'],
#  ['paint', 'spraying'],
#  ['kitchens', 'kitchen-counters', 'countertops'],
#  ['electrical', 'wiring'],
#  ['electrical', 'doorbell'],
#  ['water'],
#  ['concrete', 'tile', 'ceramic-tile'],
#  ['electrical', 'lighting'],
#  ['electrical', 'lighting', 'light-fixture', 'gfci', 'circuit'],
#  ['cleaning', 'oven'],
#  ['leak', 'toilet'],
#  ['insulation', 'roof'],
#  ['fans'],
#  ['copper'],
#  ['repainting', 'preparation'],
#  ['plumbing', 'drain-waste-vent'],
#  ['basement'],
#  ['kitchens', 'drain', 'clog'],
#  ['electrical', 'bathroom'],
#  ['installation', 'trim'],
#  ['pest-control'],
#  ['hvac', 'exterior', 'pest-control'],
#  ['electrical', 'wood', 'woodworking', 'steam'],
#  ['wood', 'brick', 'structural', 'patio', 'post'],
#  ['wood', 'windows', 'frame', 'demolition'],
#  ['electrical'],
#  ['flooring', 'subfloor'],
#  ['repair', 'floor', 'ceramic-tile'],
#  ['framing', 'load-bearing'],
#  ['plumbing'],
#  ['roof', 'structural', 'patio', 'span-tables'],
#  ['plumbing', 'hvac', 'sump-pump'],
#  ['electrical'],
#  ['ceiling'],
#  ['electrical', 'code-compliance'],
#  ['electrical', 'wire', 'lubrication'],
#  ['insulation', 'water-circulating-heating'],
#  ['electrical', 'data-wiring', 'low-voltage'],
#  ['bedroom'],
#  ['electrical', 'led'],
#  ['attic', 'mold', 'contractors'],
#  ['air-conditioning'],
#  ['plumbing', 'water', 'pvc', 'sprinkler-system', 'irrigation'],
#  ['plumbing'],
#  ['garage', 'screws', 'storage'],
#  ['wood', 'staining', 'pressure-treated'],
#  ['electrical', 'switch', 'appliances'],
#  ['remodeling'],
#  ['electrical', 'lighting'],
#  ['wooden-furniture', 'carpentry', 'desk', 'table'],
#  ['wood', 'woodworking', 'load-bearing'],
#  ['drywall', 'ceiling', 'adhesive'],
#  ['replacement', 'roofing', 'diy-vs-pro'],
#  ['concrete', 'plaster', 'pool'],
#  ['electrical', 'drywall', 'circuit'],
#  ['plumbing', 'water-pressure', 'sprinkler-system', 'well-pump', 'irrigation'],
#  ['chimney'],
#  ['construction', 'building-regulations', 'new-home'],
#  ['ceiling-fan'],
#  ['repair', 'wood', 'flooring', 'floor', 'plywood'],
#  ['subpanel', '240v'],
#  ['tile'],
#  ['repair', 'drywall', 'patching-drywall', 'joints', 'spackling-paste'],
#  ['doors', 'noise', 'noise-reduction'],
#  ['smell'],
#  ['electrical', 'wiring', 'installation', 'grounding', 'data-wiring'],
#  ['water-heater', 'gfci', 'circuit-breaker'],
#  ['electrical', 'code-compliance'],
#  ['lighting'],
#  ['plumbing', 'water', 'well-pump', 'well'],
#  ['concrete', 'paint', 'plaster', 'pool'],
#  ['wood', 'pipe'],
#  ['drywall', 'ceiling', 'foundation', 'structural'],
#  ['furnace'],
#  ['wood', 'support', 'porch-swing'],
#  ['concrete', 'driveway', 'hole-repair'],
#  ['wiring', 'lighting', 'led'],
#  ['code-compliance'],
#  ['exterior'],
#  ['concrete', 'pool'],
#  ['plaster', 'pool'],
#  ['walls', 'framing', 'load-bearing'],
#  ['walls'],
#  ['shower', 'sealing', 'caulking'],
#  ['framing', 'blocking'],
#  ['garage-door-opener'],
#  ['hvac', 'taping'],
#  ['electrical', 'wiring', 'air-conditioning'],
#  ['electrical', 'hvac', 'central-heating', 'central-air'],
#  ['water', 'foundation', 'drainage', 'rain'],
#  ['windows'],
#  ['wood', 'pest', 'lumber'],
#  ['washing-machine'],
#  ['screws'],
#  ['lighting', 'windows', 'wind'],
#  ['concrete', 'pool'],
#  ['pool', 'electric-motor'],
#  ['tools', 'woodworking', 'wooden-furniture', 'measuring'],
#  ['hvac', 'ducts'],
#  ['electrical', 'wiring', 'lamp'],
#  ['thermostat'],
#  ['plumbing', 'water'],
#  ['electrical', 'bathroom', 'switch', 'fans'],
#  ['plumbing', 'bathroom', 'sink', 'drain', 'drain-waste-vent'],
#  ['electrical', 'wiring', 'lighting', 'switch'],
#  ['wood', 'waterproofing'],
#  ['insulation', 'attic'],
#  ['plumbing', 'water', 'sprinkler-system'],
#  ['water-heater'],
#  ['wood', 'concrete'],
#  ['walls', 'flooring', 'ceiling', 'rental'],
#  ['hvac', 'ducts'],
#  ['lawn', 'engine'],
#  ['basement'],
#  ['bathroom', 'walls', 'flooring', 'floor'],
#  ['pest-control'],
#  ['water-softener', 'radon', 'well', 'water-filtration'],
#  ['concrete', 'timber-framing', 'protection'],
#  ['trim-carpentry'],
#  ['washing-machine'],
#  ['tools', 'storage'],
#  ['flooring', 'paint', 'outdoor'],
#  ['electric-motor', 'fans', '240v'],
#  ['plumbing', 'water', 'well-pump', 'well'],
#  ['soffit'],
#  ['drywall', 'trim'],
#  ['sheathing'],
#  ['hvac', 'air-conditioning', 'ice'],
#  ['concrete', 'driveway'],
#  ['plumbing', 'bathroom', 'sink', 'drain-waste-vent'],
#  ['plumbing', 'basement', 'drain', 'drain-waste-vent', 'clog'],
#  ['electrical', 'garage', 'circuit-breaker', 'circuit', 'subpanel'],
#  ['tools', 'maintenance'],
#  ['mold', 'air-quality'],
#  ['windows', 'replacement', 'construction', 'renovation'],
#  ['wiring'],
#  ['noise'],
#  ['roof', 'soffit'],
#  ['lighting', 'outdoor'],
#  ['plumbing', 'bathroom', 'shower', 'tub'],
#  ['hvac'],
#  ['water-pressure', 'maintenance'],
#  ['metal', 'rust-removal', 'rust-proofing'],
#  ['brick'],
#  ['pipe', 'closet'],
#  ['plumbing', 'sink', 'drain'],
#  ['water-pressure', 'maintenance'],
#  ['flooring', 'subfloor'],
#  ['ceiling', 'plaster', 'lath-and-plaster'],
#  ['electrical'],
#  ['water-pressure', 'maintenance', 'water-softener'],
#  ['tools', 'storage'],
#  ['central-air'],
#  ['insulation', 'exterior', 'polyurethane'],
#  ['gas', 'propane'],
#  ['ants'],
#  ['kitchen-counters', 'granite', 'countertops'],
#  ['electrical'],
#  ['flooring', 'plywood', 'underlayment'],
#  ['windows', 'sound-proofing', 'pvc', 'aluminum'],
#  ['walls'],
#  ['concrete', 'floor', 'sealing'],
#  ['painting'],
#  ['drainage', 'shed'],
#  ['windows'],
#  ['water', 'switch'],
#  ['concrete', 'rebar'],
#  ['electrical', 'wiring', 'receptacle', 'powertools'],
#  ['bathtub'],
#  ['lighting'],
#  ['deck', 'construction', 'decking'],
#  ['insulation', 'fireplace'],
#  ['screws', 'drill', 'powertools'],
#  ['electrical', 'lighting'],
#  ['gutters'],
#  ...]

# %%
mlb = MultiLabelBinarizer(classes=sorted(tags_counts.keys()))
y_train = mlb.fit_transform(y_train)
y_val = mlb.fit_transform(y_val)

# %%
y_train.shape
# Out:
# (24000, 712)

# %% [markdown]
# Train the classifiers for different data transformations: *bag-of-words* and *tf-idf*.

# %%
# %%time
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression, RidgeClassifier
clf = OneVsRestClassifier(RidgeClassifier(normalize=True))
clf.fit(X_train_tfidf, y_train)
# classifier_tfidf = train_classifier(X_train_tfidf, y_train)
# Out:
# Wall time: 2min 31s

# %% [markdown]
# Now you can create predictions for the data. You will need two types of predictions: labels and scores.

# %%
# %%time
y_val_predicted_labels_tfidf = clf.predict(X_val_tfidf)
# y_val_predicted_scores_tfidf = classifier_tfidf.decision_function(X_val_tfidf)
# Out:
# Wall time: 78.1 ms

# %% [markdown]
# Now take a look at how classifier, which uses TF-IDF, works for a few examples:

# %%
que = ['What power tools are there and what do they do?','Why are my radiators cold?','What’s the best way to clean paintbrushes?']
que = [text_prepare(i) for i in que]
# que = [que]
que = tfidf_vectorizer.transform(que)
yp = clf.predict(que)
print(mlb.inverse_transform(yp))
# Out:
# [('electrical', 'powertools', 'tools'), ('central-heating', 'heating', 'radiator'), ('cleaning',)]

# %%
import pickle
import os 
pickle.dump(clf, open('model-diy.pkl', 'wb'))
pickle.dump(mlb, open('tags-diy.pkl', 'wb'))
pickle.dump(tfidf_vectorizer, open('tf-diy.pkl', 'wb'))
