# %%
import nltk
#nltk.download('stopwords')
from ast import literal_eval
import pandas as pd
import numpy as np
from nltk.corpus import stopwords

# %%
def read_data(filename):
    data = pd.read_csv(filename, sep='\t')
    data['tags'] = data['tags'].apply(literal_eval)
    return data

# %%
tmp = pd.read_csv('travel.csv')
#train = read_data('cooking.csv')
#validation = read_data('validation.tsv')
#test = pd.read_csv('test.tsv', sep='\t')
tmp
# Out:
#           id                                              title  \
# 0          1       What are some Caribbean cruises for October?
# 1          2  How can I find a guide that will take me safel...
# 2          4  Does Singapore Airlines offer any reward seats...
# 3          5  What is the easiest transportation to use thro...
# 4          6                        How can I visit Antarctica?
# 5          8    Best way to get from SeaTac airport to Redmond?
# 6          9  What are must-visit destinations for the first...
# 7         10  When traveling to a country with a different c...
# 8         11  What is the best way to obtain visas for the T...
# 9         13  Where can I find up-to-date information about ...
# 10        14  Is it advisable for US citizen to attempt a vi...
# 11        15  What are some of the sights to see in Budapest...
# 12        16  Is there a good website to plan a trip via tra...
# 13        25  What are the best ways to avoid data roaming f...
# 14        26  What should I know about "Around The World" fl...
# 15        27  What are some good ways to find things to expl...
# 16        28                 Cheapest mobile operator in Europe
# 17        31                         Sightseeing the USA by air
# 18        33  Online resources/communities especially for tr...
# 19        34  What kind of questions should I be asking abou...
# 20        41                  Where to find good cave-swimming?
# 21        45  Are there advantages to using private car serv...
# 22        47  Are there caves and tunnels under Tallinn, Est...
# 23        66  Is it possible to get a permit to travel to Ti...
# 24        67           What is there to do in Orlando, Florida?
# 25        69  How bad is baggage theft at Johannesburg airport?
# 26        73  Is it safe to travel in Japan considering the ...
# 27        77                           Flight deals from the UK
# 28        78    Tel Aviv a good base to see Israel & Palestine?
# 29        79      Something to do in or around Colmar in France
# ...      ...                                                ...
# 19249  77950  How to deal with contact numbers while traveling?
# 19250  77953  From Australia to America driver's license tra...
# 19251  77954                          Cluj-Napoca to Sighisoara
# 19252  77956        Vueling bags rules when buying extra weight
# 19253  77958  Is there a way to go from Phuket to Banda Aceh...
# 19254  77964               Mobile Data for Short Trip to Canada
# 19255  77965     Schengen Visa . No response from the Consulate
# 19256  77966               Greek Customs with Electronic Device
# 19257  77974                   Called for French Visa interview
# 19258  77977                            Pasta in San Francisco!
# 19259  77980  Firstname and lastname reverse on flight ticke...
# 19260  77981  Ukrainian citizen traveling to U.S.A with a co...
# 19261  77982  How can I determine if there's a way I can leg...
# 19262  77984  Can I still purchase 4G/unlimited SIM card onc...
# 19263  77985  Possibility of getting u k tier 5 visa with pr...
# 19264  77986  Laptop in hand luggage with qatar airways from...
# 19265  77988  Croatian entry stamp with no exit stamp: will ...
# 19266  77991  Will we be required to use a PIN associated wi...
# 19267  77993  Can I use preclearance for a flight Dublin to ...
# 19268  77996                             Vueling hand bag rules
# 19269  78002                               Patagonia in a month
# 19270  78003  Taxi cost from New Delhi airport to the nearby...
# 19271  78005  Moving household stuff from Bangalore(India) t...
# 19272  78007             Using APC kiosk with new ESTA/passport
# 19273  78008  Which is the NYC airport with the quickest cus...
# 19274  78013                       Tipping in USA.California.SF
# 19275  78016  As a Canadian, what are appropriate gifts to b...
# 19276  78018  Does Macedonian police issue visitors a regist...
# 19277  78019                 Can my Austrian Visa D be renewed?
# 19278  78022            Shortest wide-body route from Frankfurt
#
#                                                  content  \
# 0      <p>My fiancée and I are looking for a good Car...
# 1      <p>This was one of our definition questions, b...
# 2      <p>Singapore Airlines has an all-business clas...
# 3      <p>Another definition question that interested...
# 4      <p>A year ago I was reading some magazine, and...
# 5      <p>Can anyone suggest the best way to get from...
# 6      <p>We are considering visiting Argentina for u...
# 7      <p>Recently my wife and I traveled to Italy an...
# 8      <p>I'm planning on taking the trans-Siberian /...
# 9      <p>I need to travel from Cusco, Peru to La Paz...
# 10     <p>I am aware of travel agencies catering to U...
# 11     <p>I'm planning my first international trip ou...
# 12     <p>My wife and I have decided to move across E...
# 13     <p>I'm looking for data plans I can use while ...
# 14     <p>I have heard rumours of such things, and ha...
# 15     <p>When traveling, one of my favorite things t...
# 16     <blockquote>\n  <p><strong>Possible Duplicate:...
# 17     <p>The next time family from overseas comes to...
# 18     <p>I'm dreaming of visiting remote islands suc...
# 19     <p>Tropical destinations have to be one of the...
# 20     <p>I'd love to travel to a place that has a go...
# 21     <p>When planning a trip I've seen people say p...
# 22     <p>This spring I was in Tallinn, and I heard a...
# 23     <p>I am confused about how I go about getting ...
# 24     <p>Aside from the Disney World, what else is t...
# 25     <p>South Africa's Johannesburg's airport has a...
# 26     <p>Are there any areas that should be avoided ...
# 27     <p>Can someone recommend a good website with f...
# 28     <p>I'm planning to spend 3 weeks in Israel &am...
# 29     <p>My wife and I will be travelling to Colmar ...
# ...                                                  ...
# 19249  <p>The Android Contact List (People App) on my...
# 19250  <p>I'm aware of "reciprocity agreements" some ...
# 19251  <p>I want to travel from Cluj-Napoca to Sighis...
# 19252  <p>I am booking on Vueling and have chosen the...
# 19253  <p>I would like to go to Banda Aceh from Phuke...
# 19254  <p>I am an American planning a short trip to C...
# 19255  <p>I just got information from the VFS site th...
# 19256  <p>I bought headphones in USA, for ~300$. Shou...
# 19257  <p>I am very worried and looking for some hope...
# 19258  <p>Is there any good place for pasta in San Fr...
# 19259  <p>I'm getting really worried as I realized my...
# 19260  <p>My friend was turned away at the airport in...
# 19261  <p>Considering <a href="http://travel.stackexc...
# 19262  <p>I want to purchase a mobile prepaid SIM car...
# 19263  <p>My Canada visa got rejected in 2014 since I...
# 19264  <p>I want to take my laptop as I need to its r...
# 19265  <p>I am an Indian passport holder with a Germa...
# 19266  <p>We are headed to Austria, Germany and the C...
# 19267  <p>I am booking a holiday to LAX from Dublin. ...
# 19268  <p>I go with Vueling, I am asking about the ha...
# 19269  <p>We are a couple of friends (all around 24 y...
# 19270  <p>I have no idea what prices in India are lik...
# 19271  <p>What would be the  best way to move househo...
# 19272  <p>I'm a Dutch citizen flying to Dulles from A...
# 19273  <p>I'll be flying into NYC from London and I w...
# 19274  <p>Being a <a href="https://gsamaras.wordpress...
# 19275  <p>I live in Vancouver, Canada and will be tra...
# 19276  <p>In Serbia and Macedonia, you have to Regist...
# 19277  <p>I am in Austria on a Visa D multiple entry,...
# 19278  <p>What is the shortest passenger route served...
#
#                                                     tags
# 0                           caribbean cruising vacations
# 1      guides extreme-tourism amazon-river amazon-jungle
# 2      loyalty-programs routes ewr singapore-airlines...
# 3                                 romania transportation
# 4                             extreme-tourism antarctica
# 5                     usa airport-transfer taxis seattle
# 6      sightseeing public-transport transportation ar...
# 7             safety international-travel money exchange
# 8             russia visas china mongolia trans-siberian
# 9      online-resources transportation peru south-ame...
# 10                        us-citizens travel-agents cuba
# 11                          sightseeing hungary budapest
# 12        europe online-resources planning guides trains
# 13     budget cellphones data-plans communication mob...
# 14                           air-travel around-the-world
# 15                    sightseeing planning tourist-traps
# 16             budget europe cellphones mobile-operators
# 17                      air-travel usa sightseeing tours
# 18     online-resources international-travel adventur...
# 19                        planning tropical-destinations
# 20      destinations adventure activities swimming caves
# 21     transportation taxis automobiles airport-transfer
# 22                     sightseeing estonia tallinn caves
# 23                            china trains permits tibet
# 24                                   usa florida orlando
# 25            luggage airports security south-africa jnb
# 26                         health japan safety radiation
# 27        air-travel budget online-resources uk airlines
# 28               israel accommodation palestine tel-aviv
# 29                                       france children
# ...                                                  ...
# 19249                         canada cellphones software
# 19250                                   driving-licenses
# 19251                                     routes romania
# 19252                                    luggage vueling
# 19253                 thailand ferries sumatra-indonesia
# 19254                                  canada cellphones
# 19255              schengen india application-status vfs
# 19256  usa customs-and-immigration europe local-custo...
# 19257               visas schengen france-schengen-visas
# 19258  usa food-and-drink california recommendations ...
# 19259                     air-travel usa airline-booking
# 19260          visas schengen transit ukrainian-citizens
# 19261                             legal safety souvenirs
# 19262           airports cellphones south-korea internet
# 19263                                           visas uk
# 19264  air-travel electronic-items hand-luggage secur...
# 19265    indian-citizens germany passport-stamps croatia
# 19266       germany payment-cards austria czech-republic
# 19267            air-travel usa lhr dublin pre-clearance
# 19268  air-travel luggage electronic-items hand-lugga...
# 19269                       argentina trekking patagonia
# 19270       india airport-transfer taxis price new-delhi
# 19271                         india transportation nepal
# 19272            usa esta us-visa-waiver-program vwp iad
# 19273     air-travel customs-and-immigration jfk ewr lga
# 19274  usa food-and-drink california tipping san-fran...
# 19275                     uk canada france culture gifts
# 19276  customs-and-immigration officials registration...
# 19277                                      visas austria
# 19278                                           untagged
#
# [19279 rows x 4 columns]

# %%
test = tmp.tail(1278)
train = tmp.head(18000)
validation = tmp.head(11500).tail(1500)

# %%
validation.head()
# Out:
#           id                                              title  \
# 10000  43808  Is the UK planning to introduce exit checks in...
# 10001  43811  How to pass time / manage a very long drive (2...
# 10002  43816     Can I bring beef jerky to the US from Nigeria?
# 10003  43817           Airport employees in preclearance areas?
# 10004  43820                 NJ Transit Train first time riding
#
#                                                  content  \
# 10000  <p>Someone from America is a tourist/visitor h...
# 10001  <p>We have a group of 8 that are taking two ve...
# 10002  <p>I am going to be traveling to Nigeria and I...
# 10003  <p>How does this work, people working in the s...
# 10004  <p>I've never taken a train anywhere before an...
#
#                                              tags
# 10000                   visas uk visas-on-arrival
# 10001                      usa driving road-trips
# 10002  usa customs-and-immigration food-and-drink
# 10003                      airports pre-clearance
# 10004                     trains public-transport

# %%
train.head()
# Out:
#    id                                              title  \
# 0   1       What are some Caribbean cruises for October?
# 1   2  How can I find a guide that will take me safel...
# 2   4  Does Singapore Airlines offer any reward seats...
# 3   5  What is the easiest transportation to use thro...
# 4   6                        How can I visit Antarctica?
#
#                                              content  \
# 0  <p>My fiancée and I are looking for a good Car...
# 1  <p>This was one of our definition questions, b...
# 2  <p>Singapore Airlines has an all-business clas...
# 3  <p>Another definition question that interested...
# 4  <p>A year ago I was reading some magazine, and...
#
#                                                 tags
# 0                       caribbean cruising vacations
# 1  guides extreme-tourism amazon-river amazon-jungle
# 2  loyalty-programs routes ewr singapore-airlines...
# 3                             romania transportation
# 4                         extreme-tourism antarctica

# %%
test.head()
# Out:
#           id                                              title  \
# 18001  73152  Do you need to schedule a new biometrics appoi...
# 18002  73155                schengen visa from uk related query
# 18003  73157                            Acceptance of USD bills
# 18004  73158                  Is tap water in US safe to drink?
# 18005  73159  How to best get through a motorway toll booth ...
#
#                                                  content                 tags
# 18001  <p>My son was refused a UK Visa for not supply...  biometric-passports
# 18002  <p>I am having work permit for one year in UK ...    visas schengen uk
# 18003  <p>I have some USD bills of 2003-2006. The mon...                  usa
# 18004  <p>This might sound silly but I come from a pl...        usa tap-water
# 18005  <p>Perhaps this is not the most clear question...        driving tolls

# %%
X_train, y_train = train['title'].values, train['tags'].values
X_val, y_val = validation['title'].values, validation['tags'].values
X_test = test['title'].values

# %%
y_train[1]
# Out:
# 'guides extreme-tourism amazon-river amazon-jungle'

# %%
import re

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))

def text_prepare(text):
    text = text.lower()
    text = REPLACE_BY_SPACE_RE.sub(' ', text)
    text = BAD_SYMBOLS_RE.sub('', text)
    text = ' '.join(word for word in text.split() if word not in STOPWORDS)
    #print(text)
    return text

# %%
# prepared_questions = []
# for line in open('text_prepare_tests.tsv', encoding='utf-8'):
#     line = text_prepare(line.strip())
#     prepared_questions.append(line)
# text_prepare_results = '\n'.join(prepared_questions)

# %%
X_train = [text_prepare(x) for x in X_train]
X_val = [text_prepare(x) for x in X_val]
X_test = [text_prepare(x) for x in X_test]

# %%
y_train[:3]
# Out:
# array(['caribbean cruising vacations',
#        'guides extreme-tourism amazon-river amazon-jungle',
#        'loyalty-programs routes ewr singapore-airlines sin'], dtype=object)

# %%
from collections import defaultdict
tags_counts = defaultdict(int)
words_counts = defaultdict(int)
tmp=[]

for tags in y_train:
    tt = tags.split()
    tmp.append(tt)
    for tag in tt:
        #print(tag)
        tags_counts[tag] += 1
y_train=tmp
tmp=[]

for text in X_train:
    for word in text.split():
        #print(word)
        words_counts[word] += 1
        
for tags in y_val:
    tt = tags.split()
    tmp.append(tt)
    for tag in tt:
        #print(tag)
        tags_counts[tag] += 1
y_val=tmp
tmp=[]
for text in X_val:
    for word in text.split():
        #print(word)
        words_counts[word] += 1

# %%
most_common_tags = sorted(tags_counts.items(), key=lambda x: x[1], reverse=True)[:10]
most_common_words = sorted(words_counts.items(), key=lambda x: x[1], reverse=True)[:3]

# %%
most_common_words
# Out:
# [('visa', 4333), ('us', 1550), ('travel', 1384)]

# %%
most_common_tags
# Out:
# [('visas', 3952),
#  ('air-travel', 2272),
#  ('usa', 2202),
#  ('schengen', 1637),
#  ('uk', 1499),
#  ('customs-and-immigration', 1066),
#  ('transit', 1062),
#  ('trains', 878),
#  ('passports', 739),
#  ('public-transport', 728)]

# %%
from scipy import sparse as sp_sparse
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
??TfidVectorizer
# Out:
# Object `TfidVectorizer` not found.

# %%
#X_val

# %%
tfidf_vectorizer = TfidfVectorizer(min_df=5, max_df=0.9, ngram_range=(1, 2),token_pattern='(\S+)')
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_val_tfidf = tfidf_vectorizer.transform(X_val)
X_test_tfidf = tfidf_vectorizer.transform(X_test)
tfidf_vocab = tfidf_vectorizer.vocabulary_
#X_train_tfidf, X_val_tfidf, X_test_tfidf, tfidf_vocab = tfidf_features(X_train, X_val, X_test)

# %%
tfidf_reversed_vocab = {i:word for word,i in tfidf_vocab.items()}

# %%
tfidf_vocab['visa']
# Out:
# 4075

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# %%
tags_counts.keys()
# Out:
# dict_keys(['caribbean', 'cruising', 'vacations', 'guides', 'extreme-tourism', 'amazon-river', 'amazon-jungle', 'loyalty-programs', 'routes', 'ewr', 'singapore-airlines', 'sin', 'romania', 'transportation', 'antarctica', 'usa', 'airport-transfer', 'taxis', 'seattle', 'sightseeing', 'public-transport', 'argentina', 'safety', 'international-travel', 'money', 'exchange', 'russia', 'visas', 'china', 'mongolia', 'trans-siberian', 'online-resources', 'peru', 'south-america', 'bolivia', 'us-citizens', 'travel-agents', 'cuba', 'hungary', 'budapest', 'europe', 'planning', 'trains', 'budget', 'cellphones', 'data-plans', 'communication', 'mobile-operators', 'air-travel', 'around-the-world', 'tourist-traps', 'tours', 'adventure', 'islands', 'tropical-destinations', 'destinations', 'activities', 'swimming', 'caves', 'automobiles', 'estonia', 'tallinn', 'permits', 'tibet', 'florida', 'orlando', 'luggage', 'airports', 'security', 'south-africa', 'jnb', 'health', 'japan', 'radiation', 'uk', 'airlines', 'israel', 'accommodation', 'palestine', 'tel-aviv', 'france', 'children', 'shanghai', 'hong-kong', 'new-zealand', 'vietnam', 'hanoi', 'insurance', 'central-america', 'panama', 'colombia', 'upgrades', 'tips-and-tricks', 'india', 'beggars', 'hiking', 'africa', 'kilimanjaro', 'gear', 'eu', 'eurozone', 'sea-travel', 'freighter-travel', 'language-barrier', 'russian-language', 'ecuador', 'paris', 'festivals', 'luxury', 'high-speed-rail', 'fares', 'middle-east', 'yemen', 'road-trips', 'denmark', 'nature-and-wildlife', 'auroras', 'overland', 'iran', 'pakistan', 'gilgit-baltistan', 'tehran', 'spain', 'diving', 'ecotourism', 'malaysia', 'mountain-climbing', 'tanzania', 'astrakhan', 'ferries', 'uzbekistan', 'kazakhstan', 'embassies', 'consulates', 'turkmenistan', 'italy', 'mountains', 'castles', 'fortresses', 'backpacking', 'carnet-de-passage', 'maldives', 'australia', 'weather-and-climate', 'event-travel', 'eclipses', 'landmarks', 'architecture', 'beijing', 'great-wall-of-china', 'star-alliance', 'work', 'seasonal', 'alaska', 'local-customs', 'culture', 'tipping', 'photography', 'driving', 'car-rentals', 'los-angeles', 'buses', 'western-usa', 'long-haul', 'rental', 'bicycles', 'passenger-rights', 'delays', 'aktau', 'regulations', 'extreme-sports', 'georgia-country', 'caucasus', 'borders', 'southeast-asia', 'myanmar', 'black-sea', 'eastern-europe', 'rome', 'motorcycles', 'north-america', 'passports', 'passport-stamps', 'azerbaijan', 'armenia', 'study', 'languages', 'guatemala', 'istanbul', 'ist', 'spanish-language', 'french-language', 'turkey', 'visas-on-arrival', 'trekking', 'machu-picchu', 'iceland', 'roaming', 'paperwork', 'greece', 'athens', 'event-based-effects', 'clothing', 'islam', 'religion', 'english-language', 'customs-and-immigration', 'canada', 'pre-clearance', 'shore-excursions', 'food-and-drink', 'tap-water', 'driving-licenses', 'officials', 'corruption', 'registration', 'gps-navigation', 'itineraries', 'maps', 'beaches', 'boston', 'new-york-city', 'camping', 'bulgaria', 'southern-california', 'lax', 'cities', 'statistics', 'germany', 'poland', 'power', 'cambridge', 'bukhara', 'philippines', 'saint-petersburg', 'south-india', 'london', 'lgw', 'kuala-lumpur', 'kul', 'mexico', 'mail', 'grand-canyon', 'helicopters', 'disney', 'solo-travel', 'female-travellers', 'cambodia', 'laos', 'switzerland', 'taiwan', 'hotels', 'airport-security', 'geography', 'legal', 'uk-citizens', 'public-holidays', 'thailand', 'latvia', 'baltics', 'coffee', 'yyz', 'ride-sharing', 'oregon', 'hostels', 'hostelworld', 'australian-citizens', 'working-holiday', 'schengen', 'russian-citizens', 'swaziland', 'electronic-items', 'adapters', 'payment-cards', 'football', 'washington-dc', 'british-columbia', 'norway', 'fjords', 'campers', 'netherlands', 'long-term', 'eurostar', 'pets', 'countries', 'disputed-territories', 'cyprus', 'northern-cyprus', 'animal-riding', 'asia', 'easyjet', 'geneva', 'esta', 'short-notice', 'toronto', 'honduras', 'loire-valley', 'mobile-apps', 'tajikista ...

# %%
y_val
# Out:
# [['visas', 'uk', 'visas-on-arrival'],
#  ['usa', 'driving', 'road-trips'],
#  ['usa', 'customs-and-immigration', 'food-and-drink'],
#  ['airports', 'pre-clearance'],
#  ['trains', 'public-transport'],
#  ['international-travel', 'car-rentals'],
#  ['trains', 'indian-railways', 'dietary-restrictions', 'nostalgia'],
#  ['camping', 'hiking', 'hokkaido'],
#  ['visas', 'uk', 'visa-refusal', 'scams'],
#  ['iceland', 'finland', 'freighter-travel'],
#  ['taiwan', 'entertainment'],
#  ['transit', 'customs-and-immigration', 'security'],
#  ['air-travel', 'tickets'],
#  ['schengen', 'italy', 'tourist-visas', 'sri-lankan-citizens'],
#  ['visas', 'india', 'passports', 'us-citizens'],
#  ['france', 'automobiles', 'insurance'],
#  ['money', 'sri-lanka'],
#  ['visas', 'usa'],
#  ['air-travel', 'luggage', 'hand-luggage', 'damaged-luggage'],
#  ['legal', 'airlines', 'eu', 'compensation', 'missed-flights'],
#  ['airport-security', 'yyz'],
#  ['visas', 'uk', 'passports', 'uk-citizens', 'south-african-citizens'],
#  ['schengen', 'uk', 'transit', 'cruising', 'filipino-citizens'],
#  ['air-travel', 'planning', 'airlines', 'jfk', 'lga'],
#  ['visas', 'air-travel', 'uk', 'chilean-citizens'],
#  ['usa'],
#  ['customs-and-immigration', 'canada', 'us-citizens', 'pre-clearance'],
#  ['safety', 'croatia', 'trekking', 'bosnia', 'montenegro'],
#  ['air-travel', 'passports', 'us-citizens', 'hong-kong', 'hong-kong-citizens'],
#  ['international-travel', 'indian-citizens', 'dublin'],
#  ['religion', 'landmarks', 'pakistan', 'locate-this', 'gilgit-baltistan'],
#  ['visas', 'uk', 'transit', 'overstaying', 'vietnamese-citizens'],
#  ['canada', 'regulations', 'food-and-drink'],
#  ['air-travel', 'regulations', 'aircraft', 'seating'],
#  ['transit', 'luggage', 'dxb', 'kenyan-citizens'],
#  ['weather-and-climate', 'where-on-earth', 'mountains'],
#  ['schengen'],
#  ['trains', 'europe', 'netherlands', 'belgium', 'train-stations'],
#  ['amtrak', 'los-angeles', 'chicago'],
#  ['air-travel', 'aeroflot', 'miles-and-more'],
#  ['visas', 'paperwork', 'mexico', 'fmm'],
#  ['usa', 'money', 'russia', 'exchange'],
#  ['france', 'hiking', 'nature-and-wildlife', 'lyon'],
#  ['eu', 'alcohol', 'duty-free'],
#  ['food-and-drink', 'cambodia', 'coffee'],
#  ['budget', 'canada', 'cellphones'],
#  ['visas', 'transit', 'germany'],
#  ['visas', 'uk', 'visa-refusal', 'business-travel'],
#  ['air-travel', 'transit', 'airports', 'dub'],
#  ['visas', 'transit', 'turkey', 'uk-citizens', 'missed-flights'],
#  ['aircraft'],
#  ['international-travel', 'airport-transfer', 'dubai'],
#  ['georgia-country', 'event-based-effects', 'ukraine', 'black-sea'],
#  ['online-resources', 'airlines', 'delays'],
#  ['uk', 'scotland', 'event-travel', 'festivals', 'edinburgh'],
#  ['schengen', 'italy', 'hungary', 'ryanair'],
#  ['public-transport', 'buses', 'backpacking', 'costa-rica', 'nicaragua'],
#  ['visas', 'legal', 'us-citizens', 'south-africa'],
#  ['airport-transfer', 'layovers', 'cdg', 'tgvair'],
#  ['budget', 'transportation', 'new-york-city', 'boston'],
#  ['air-travel',
#   'planning',
#   'airport-security',
#   'electronic-items',
#   'fragile-luggage'],
#  ['tickets', 'japan', 'luxury', 'japan-rail', 'jr-pass'],
#  ['schengen', '90-180-visa-rules'],
#  ['luggage', 'international-travel', 'emirates', 'taipei', 'korean-air'],
#  ['schengen', 'study', '90-180-visa-rules'],
#  ['airports', 'automobiles', 'long-term', 'chicago', 'ord'],
#  ['airport-security', 'hand-luggage'],
#  ['money', 'payment-cards'],
#  ['visas', 'schengen'],
#  ['air-travel', 'children', 'tips-and-tricks', 'new-zealand', 'qantas'],
#  ['visas', 'schengen', 'transit', 'italy', 'spain'],
#  ['india', 'food-and-drink', 'local-cuisine'],
#  ['schengen', 'europe', 'germany', 'paris', 'amsterdam'],
#  ['air-travel', 'usa', 'tsa'],
#  ['hotels', 'bookings', 'terminology'],
#  ['united-airlines'],
#  ['usa', 'passports', 'paperwork'],
#  ['air-travel', 'tickets', 'regulations', 'paperwork', 'driving-licenses'],
#  ['australia', 'us-citizens', 'insurance', 'backpacking'],
#  ['transportation', 'driving', 'terminology', 'pakistan'],
#  ['visas', 'china', 'vietnam', 'embassies', 'consulates'],
#  ['public-transport', 'safety', 'sports-events', 'chicago'],
#  ['safety', 'mexico', 'mexico-city'],
#  ['visas', 'schengen', 'europe', 'germany', 'australia'],
#  ['airport-transfer', 'lgw'],
#  ['budget', 'san-francisco', 'dublin', 'taxes'],
#  ['borders', 'israel', 'taxis', 'jordan'],
#  ['health'],
#  ['air-travel', 'food-and-drink', 'dietary-restrictions'],
#  ['bicycles', 'south-america', 'gifts'],
#  ['japan', 'luggage-storage', 'osaka'],
#  ['air-travel', 'tickets'],
#  ['air-travel', 'usa', 'tsa'],
#  ['luggage', 'brussels', 'luggage-storage'],
#  ['weather-and-climate', 'indonesia', 'bali'],
#  ['cellphones', 'israel'],
#  ['air-travel', 'tickets', 'airlines', 'bookings'],
#  ['transit', 'ukrainian-citizens', 'vie'],
#  ['hotels', 'denver'],
#  ['canada', 'greyhound', 'maps'],
#  ['usa', 'customs-and-immigration', 'import-tax'],
#  ['transit'],
#  ['india', 'entertainment', 'local-knowledge'],
#  ['usa', 'driving', 'road-trips'],
#  ['driving', 'car-rentals', 'colorado'],
#  ['accommodation', 'destinations', 'cambodia', 'mountains'],
#  ['customs-and-immigration', 'india', 'duty-free'],
#  ['germany', 'airports', 'berlin', 'easyjet'],
#  ['electronic-items', 'shopping', 'cambodia', 'phnom-penh'],
#  ['visas', 'schengen', 'visa-extensions'],
#  ['visas', 'uk'],
#  ['airport-transfer', 'italy', 'mxp', 'milano-centrale'],
#  ['visas', 'transit', 'filipino-citizens', 'seoul', 'korean-air'],
#  ['money', 'exchange', 'nicaragua'],
#  ['visas', 'customs-and-immigration', 'canadian-citizens'],
#  ['uk', 'france', 'ferries'],
#  ['transportation', 'vancouver', 'yellowstone'],
#  ['usa', 'canada', 'us-visa-waiver-program'],
#  ['air-travel', 'luggage'],
#  ['security', 'wifi'],
#  ['luggage', 'security'],
#  ['air-travel', 'luggage', 'australia'],
#  ['usa', 'canada', 'automobiles', 'rental'],
#  ['visas', 'schengen', 'spain', 'multiple-entry'],
#  ['air-travel', 'budget', 'adventure'],
#  ['visas', 'schengen', 'germany', 'multiple-entry', 'czech-republic'],
#  ['minors'],
#  ['visas', 'dubai', 'uae'],
#  ['health', 'georgia-country', 'rabies'],
#  ['san-francisco', 'sfo'],
#  ['visas', 'europe'],
#  ['air-travel', 'usa', 'eu', 'statistics'],
#  ['visas', 'germany', 'pakistani-citizens'],
#  ['buses', 'san-francisco'],
#  ['mountains', 'tenerife', 'star-gazing'],
#  ['visas', 'schengen', 'passports', 'us-citizens', '90-180-visa-rules'],
#  ['health', 'colombia'],
#  ['usa', 'driving-licenses'],
#  ['visas', 'transit', 'lhr', 'bangladeshi-citizens'],
#  ['visas'],
#  ['spain', 'hiking', 'nature-and-wildlife'],
#  ['tickets', 'bookings', 'greece'],
#  ['borders', 'vietnam', 'cambodia', 'land-borders'],
#  ['road-trips', 'tanzania'],
#  ['southeast-asia', 'sri-lanka'],
#  ['customs-and-immigration', 'passports', 'borders', 'uk-citizens'],
#  ['japan', 'culture', 'japanese-visitors'],
#  ['usa', 'b1-b2-visas', 'visa-refusal'],
#  ['visas', 'customs-and-immigration', 'eurostar', 'chinese-citizens'],
#  ['air-travel', 'legal', 'airlines'],
#  ['air-travel', 'airlines'],
#  ['customs-and-immigration', 'canada', 'working-holiday'],
#  ['air-travel', 'children', 'long-haul'],
#  ['air-travel', 'budget', 'airlines', 'low-cost-carriers'],
#  ['legal', 'france', 'sncf', 'air-france', 'tgvair'],
#  ['visas', 'transit', 'uk'],
#  ['budget', 'public-transport', 'netherlands', 'ams'],
#  ['airports', 'safety', 'transportation', 'china'],
#  ['usa', 'budget', 'arizona', 'colorado'],
#  ['transit-visas', 'dxb', 'el-salvador-citizens'],
#  ['usa', 'transit', 'uk', 'customs-and-immigration', 'b1-b2-visas'],
#  ['schengen', 'netherlands', 'multiple-entry', 'greece-schengen-visas'],
#  ['visas', 'morocco'],
#  ['bookings', 'ferries'],
#  ['india', 'local-customs', 'hygiene'],
#  ['visas', 'indian-citizens', 'russia'],
#  ['trains', 'transportation', 'buses', 'belgium'],
#  ['paperwork', 'i-94'],
#  ['paperwork', 'driving-licenses', 'indonesia', 'motorcycles', 'bali'],
#  ['public-transport', 'buses', 'croatia', 'national-parks', 'split'],
#  ['visas', 'schengen', 'transit', 'zurich', 'chinese-citizens'],
#  ['air-travel'],
#  ['visas', 'schengen', 'netherlands', 'netherlands-schengen-visa'],
#  ['gear'],
#  ['safety', 'international-travel', 'ukraine', 'kiev'],
#  ['germany', 'italy', 'ride-sharing'],
#  ['visas', 'uk', 'study', 'australian-citizens', 'overstaying'],
#  ['loyalty-programs', 'american-airlines', 'upgrades'],
#  ['schengen'],
#  ['driving', 'spain', 'driving-licenses', 'motorcycles'],
#  ['loyalty-programs', 'amtrak', 'lounges'],
#  ['air-travel', 'food-and-drink', 'tips-and-tricks'],
#  ['transit', 'uk', 'indian-citizens', 'h1b-visas'],
#  ['visas', 'usa', 'international-travel', 'uk-citizens'],
#  ['visas', 'canada', 'france', 'north-america'],
#  ['airlines', 'compensation', 'qantas'],
#  ['trains', 'luggage', 'canada', 'bicycles'],
#  ['visas', 'transit', 'india', 'british-citizens'],
#  ['schengen', '90-180-visa-rules', 'turkish-citizens'],
#  ['customs-and-immigration', 'us-citizens', 'dual-nationality', 'eu-citizens'],
#  ['japan', 'language-barrier'],
#  ['local-customs', 'middle-east', 'female-travellers', 'north-africa'],
#  ['customs-and-immigration', 'mexico', 'shipping'],
#  ['planning', 'health', 'sunbathing'],
#  ['visas', 'usa', 'transit', 'indian-citizens', 'transit-visas'],
#  ['shipping', 'sports-equipment', 'canoeing-and-kayaking'],
#  ['legal', 'drugs'],
#  ['air-travel', 'flight-search-engines'],
#  ['online-resources', 'cruising', 'gps-navigation'],
#  ['visas', 'kenya', 'malta', 'kenyan-citizens'],
#  ['hotels', 'bookings'],
#  ['air-travel', 'usa', 'price'],
#  ['money', 'turkey', 'istanbul'],
#  ['gps-navigation'],
#  ['aircraft', 'hand-luggage'],
#  ['luggage-storage', 'las-vegas'],
#  ['visas', 'air-travel', 'uk', 'ireland', 'south-african-citizens'],
#  ['visas', 'uk'],
#  ['nature-and-wildlife', 'ethiopia'],
#  ['buses', 'chile'],
#  ['uk',
#   'visa-refusal',
#   'business-travel',
#   'proof-provenance-of-funds',
#   'proof-of-employment'],
#  ['schengen', 'visa-free-entry', '90-180-visa-rules'],
#  ['visas', 'air-travel', 'airports', 'italy'],
#  ['usa', 'passports'],
#  ['visas', 'uk', 'australian-citizens', 'visas-on-arrival', 'working-holiday'],
#  ['luggage-storage', 'mad'],
#  ['usa', 'car-rentals', 'insurance'],
#  ['budget', 'safety', 'automobiles', 'mexico-city'],
#  ['visas', 'schengen', 'uk-citizens', 'iceland'],
#  ['customs-and-immigration', 'luggage', 'india'],
#  ['camping', 'chile'],
#  ['visas', 'uk'],
#  ['visas', 'transit', 'india', 'uk-citizens'],
#  ['airports', 'montreal'],
#  ['uk-citizens', 'driving-licenses', 'eu'],
#  ['schengen', 'germany', 'visa-refusal'],
#  ['online-resources', 'driving', 'routes', 'maps'],
#  ['europe', 'car-rentals', 'road-trips'],
#  ['customs-and-immigration', 'france', 'london', 'eurostar'],
#  ['visas', 'usa', 'f1-visas'],
#  ['food-and-drink', 'tokyo', 'dietary-restrictions'],
#  ['visas', 'legal', 'france', 'spain', 'overstaying'],
#  ['legal', 'hotels'],
#  ['uk', 'london', 'taxis'],
#  ['visas', 'usa', 'canada', 'iranian-citizens'],
#  ['japan', 'nightlife'],
#  ['visas', 'germany'],
#  ['visas', 'schengen'],
#  ['schengen', 'transit', 'layovers', 'zurich', 'zrh'],
#  ['transit', 'airports', 'hotels'],
#  ['visas', 'schengen', 'passports'],
#  ['visas', 'air-travel', 'schengen', 'airports', 'transit-visas'],
#  ['air-travel', 'budget', 'online-resources', 'flight-search-engines'],
#  ['budget', 'accommodation', 'driving', 'spain', 'motorcycles'],
#  ['safety', 'spain', 'motorcycles'],
#  ['europe', 'eurostar'],
#  ['usa', 'canada', 'us-visa-waiver-program', 'visa-refusal', 'land-borders'],
#  ['luggage', 'tips-and-tricks', 'gear'],
#  ['schengen', 'customs-and-immigration', '90-180-visa-rules', 'visa-runs'],
#  ['borders'],
#  ['layovers', 'hong-kong', 'hkg'],
#  ['visas', 'transit', 'london'],
#  ['visas', 'international-travel'],
#  ['visas', 'singapore', 'visas-on-arrival'],
#  ['customs-and-immigration', 'airports', 'greece', 'athens'],
#  ['schengen'],
#  ['visas', 'usa', 'work', 'b1-b2-visas'],
#  ['budget', 'planning', 'money', 'tips-and-tricks'],
#  ['visas', 'passports', 'china', 'us-citizens'],
#  ['usa', 'b1-b2-visas', 'business-travel'],
#  ['netherlands', 'rental', 'bicycles'],
#  ['visas', 'schengen', 'passports', 'iceland'],
#  ['visas', 'uae'],
#  ['air-france'],
#  ['air-travel', 'thailand', 'bangkok'],
#  ['visas'],
#  ['hotels', 'russia'],
#  ['schengen', 'international-travel', 'study'],
#  ['identify-this', 'architecture', 'cities', 'landmarks', 'mount-fuji'],
#  ['transportation', 'car-rentals', 'automobiles', 'road-trips'],
#  ['visas', 'uk', 'egyptian-citizens'],
#  ['visas', 'usa', 'transit', 'paris'],
#  ['public-transport', 'national-parks', 'ontario'],
#  ['hotels', 'fees-and-charges', 'resorts'],
#  ['customs-and-immigration', 'thailand'],
#  ['uk', 'eu-citizens', 'south-african-citizens'],
#  ['legal', 'driving', 'italy', 'automobiles', 'driving-licenses'],
#  ['car-rentals', 'hotels', 'cancellations'],
#  ['visas', 'schengen', 'netherlands', 'prague'],
#  ['france', 'germany', 'switzerland', 'taxis', 'basel'],
#  ['beaches', 'sri-lanka', 'swimming'],
#  ['tips-and-tricks', 'hiking', 'trekking', 'backpacks', 'fragile-luggage'],
#  ['india', 'tours', 'history', 'dutch-language'],
#  ['usa', 'los-angeles', 'boston'],
#  ['automobiles', 'tips-and-tricks', 'vignettes'],
#  ['visas',
#   'uk',
#   'visa-refusal',
#   'russian-citizens',
#   'proof-provenance-of-funds'],
#  ['visas', 'uk', 'business-travel', 'change-purpose-of-travel'],
#  ['luggage', 'emirates'],
#  ['visas', 'air-travel', 'international-travel', 'kenyan-citizens'],
#  ['usa', 'b1-b2-visas'],
#  ['visas', 'uk', 'london', 'multiple-entry', 'filipino-citizens'],
#  ['visas', 'schengen', 'uk', 'international-travel', 'indian-citizens'],
#  ['vancouver', 'services'],
#  ['usa', 'money', 'switzerland', 'exchange'],
#  ['schengen', 'transit', 'russia', 'dual-nationality', 'visa-free-entry'],
#  ['airport-transfer', 'seoul', 'icn', 'gmp'],
#  ['visas', 'transit', 'canada', 'pakistan'],
#  ['public-holidays', 'religion', 'lisbon'],
#  ['transit', 'layovers', 'istanbul', 'ist', 'turkish-airlines'],
#  ['driving', 'gear', 'belgium'],
#  ['india', 'health'],
#  ['esta', 'california', 'texas'],
#  ['visas', 'passports', 'canada', 'turkey', 'greece'],
#  ['public-transport', 'tickets', 'legal', 'germany', 'berlin'],
#  ['germany', 'driving', 'local-customs', 'berlin'],
#  ['germany', 'berlin', 'nightlife'],
#  ['camping', 'chile', 'torres-del-paine'],
#  ['uk', 'luggage'],
#  ['mexico', 'cancun', 'cun'],
#  ['thailand', 'weather-and-climate'],
#  ['visas', 'china'],
#  ['car-rentals', 'automobiles', 'perth'],
#  ['indian-citizens', 'uae', 'qatar'],
#  ['legal', 'islands'],
#  ['visas', 'schengen', 'paperwork', 'study', 'czech-republic'],
#  ['airports', 'china', 'stop-overs', 'guangzhou'],
#  ['air-travel', 'transit', 'emirates', 'air-india', 'air-canada'],
#  ['uk', 'customs-and-immigration', 'food-and-drink', 'new-zealand', 'gifts'],
#  ['accommodation', 'hotels', 'ireland', 'architecture'],
#  ['uk',
#   'customs-and-immigration',
#   'visas-on-arrival',
#   'visa-free-entry',
#   'passport-stamps'],
#  ['legal', 'islands'],
#  ['budget', 'public-transport', 'amsterdam', 'ams'],
#  ['visas', 'schengen', 'uk', 'europe', 'norway'],
#  ['usa', 'uk', 'london', 'us-citizens', 'embassies'],
#  ['uk', 'trains', 'tickets'],
#  ['food-and-drink', 'ireland'],
#  ['local-customs', 'dubai', 'islam', 'ramadan'],
#  ['transit'],
#  ['tickets', 'terminology'],
#  ['transit'],
#  ['visas', 'schengen', 'visa-extensions', 'zimbabwean-citizen'],
#  ['visas', 'schengen', 'visa-extensions', 'ships'],
#  ['public-transport', 'airport-transfer', 'philippines', 'mnl'],
#  ['europe', 'geek-travel'],
#  ['visas', 'schengen', 'germany', 'children', 'visa-refusal'],
#  ['france', 'accommodation', 'rental'],
#  ['uk', 'taxis', 'price', 'fares'],
#  ['health', 'thailand', 'chiang-mai'],
#  ['culture', 'countries'],
#  ['money', 'payment-cards'],
#  ['france', 'paris'],
#  ['budget', 'public-transport', 'transportation', 'scotland', 'national-rail'],
#  ['australia', 'visa-free-entry', 'eta'],
#  ['car-rentals', 'us-citizens', 'chile'],
#  ['japan', 'local-customs'],
#  ['schengen', 'transit', 'stop-overs', 'pakistani-citizens', 'zrh'],
#  ['planning'],
#  ['air-travel', 'tickets', 'gds'],
#  ['legal', 'mexico'],
#  ['visas', 'schengen', 'visa-refusal', 'cooling-off-periods'],
#  ['air-travel', 'luggage'],
#  ['visas', 'france', 'paris', 'greece', 'athens'],
#  ['public-transport', 'turkey', 'istanbul', 'mobile-apps'],
#  ['public-transport', 'istanbul', 'saw'],
#  ['usa', 'national-parks'],
#  ['customs-and-immigration', 'legal', 'cuba'],
#  ['trains', 'money', 'london', 'paris', 'loyalty-programs'],
#  ['luggage', 'buses', 'colombia'],
#  ['schengen'],
#  ['air-travel'],
#  ['public-transport',
#   'car-rentals',
#   'recommendations',
#   'vancouver',
#   'seattle'],
#  ['passports', 'turkey', 'malaysian-citizens'],
#  ['photography', 'egypt'],
#  ['layovers', 'walking', 'nrt'],
#  ['air-travel', 'safety', 'regulations', 'rationale'],
#  ['visas'],
#  ['china', 'business-travel', 'guides'],
#  ['indian-citizens', 'egypt'],
#  ['uk', 'passports'],
#  ['usa', 'uk', 'esta', 'work'],
#  ['usa', 'airports', 'international-travel'],
#  ['luggage', 'code-share'],
#  ['customs-and-immigration', 'work'],
#  ['airports', 'stockholm'],
#  ['tickets', 'london', 'buses', 'tfl'],
#  ['public-transport', 'netherlands', 'eindhoven'],
#  ['schengen', 'customs-and-immigration'],
#  ['schengen'],
#  ['europe', 'driving', 'automobiles', 'price'],
#  ['visas', 'air-travel', 'usa', 'transit'],
#  ['transit', 'public-transport', 'paris', 'ratp'],
#  ['camping', 'nature-and-wildlife', 'islands', 'panama'],
#  ['cellphones', 'data-plans'],
#  ['budget', 'india', 'motorcycles', 'england', 'silk-road'],
#  ['visas'],
#  ['europe', 'passports', 'italy', 'italian-citizens'],
#  ['visas', 'australian-citizens', 'south-africa', 'repeat-visits'],
#  ['visas', 'uk'],
#  ['turkey', 'fees-and-charges', 'atms'],
#  ['trains', 'indian-railways', 'tatkal'],
#  ['visas', 'passports', 'visas-on-arrival'],
#  ['paris', 'fares', 'cdg', 'ratp'],
#  ['luggage', 'tsa'],
#  ['visas', 'germany', 'accommodation', 'visa-refusal'],
#  ['visas', 'uk', 'indian-citizens'],
#  ['visas', 'singapore', 'multiple-entry'],
#  ['visas', 'usa', 'us-visa-waiver-program'],
#  ['air-travel', 'london', 'ryanair', 'dublin'],
#  ['public-transport', 'tickets', 'paris', 'ratp'],
#  ['public-transport', 'tickets', 'japan'],
#  ['children', 'spain', 'hiking', 'malaga'],
#  ['customs-and-immigration', 'india', 'uae'],
#  ['france'],
#  ['driving', 'driving-licenses', 'new-zealand'],
#  ['cellphones', 'china', 'gps-navigation'],
#  ['visas', 'schengen'],
#  ['visas', 'transit', 'us-citizens', 'moscow', 'svo'],
#  ['transit', 'luggage', 'istanbul', 'dublin', 'turkish-airlines'],
#  ['transit', 'lhr', 'visas-on-arrival', 'filipino-citizens'],
#  ['budget', 'tips-and-tricks', 'internet', 'cuba'],
#  ['air-travel', 'japan', 'south-korea'],
#  ['india', 'temples', 'kerala'],
#  ['customs-and-immigration', 'australia'],
#  ['customs-and-immigration', 'layovers', 'rome', 'short-connection', 'fco'],
#  ['money', 'exchange', 'brazil', 'sweden'],
#  ['hiking', 'recommendations', 'seattle'],
#  ['passports', 'dual-nationality', 'colombia'],
#  ['visas', 'transit', 'lhr'],
#  ['visas', 'schengen', 'italy', 'portugal', 'russian-citizens'],
#  ['visas', 'air-travel', 'uk', 'business-travel', 'repeat-visits'],
#  ['budget', 'accommodation', 'vietnam', 'guest-houses'],
#  ['online-resources', 'accommodation', 'rental', 'airbnb'],
#  ['visas', 'uk', 'paperwork'],
#  ['visas', 'schengen', 'france', 'romania', 'residency'],
#  ['air-travel', 'delays', 'flight-status'],
#  ['visas', 'schengen', 'italy', 'paperwork'],
#  ['visas', 'schengen', '90-180-visa-rules'],
#  ['luggage', 'winter-sports', 'skiing'],
#  ['japan', 'minors'],
#  ['budget', 'online-resources', 'australia'],
#  ['uk', 'pakistani-citizens', 'minors'],
#  ['visas', 'usa', 'belgium', 'iranian-citizens'],
#  ['spain', 'public-holidays', 'closures'],
#  ['budget', 'public-transport', 'airport-transfer', 'panama', 'pty'],
#  ['thailand', 'animal-riding', 'chiang-mai'],
#  ['borders', 'kyrgyzstan', 'uzbekistan', 'land-borders'],
#  ['visas', 'schengen', 'italy', 'paperwork'],
#  ['customs-and-immigration', 'lhr', 'duty-free'],
#  ['driving', 'car-rentals', 'havana'],
#  ['public-transport', 'panama', 'indigenous-peoples'],
#  ['canada', 'ireland', 'working-holiday'],
#  ['tickets'],
#  ['visas', 'air-travel', 'uk', 'customs-and-immigration', 'visa-free-entry'],
#  ['air-travel', 'luggage', 'hand-luggage', 'photography'],
#  ['air-travel', 'schengen', 'uk', 'customs-and-immigration', 'greece'],
#  ['visas', 'schengen', 'transit'],
#  ['usa', 'children', 'cruising'],
#  ['israel', 'emergencies'],
#  ['sightseeing', 'paris', 'nightlife'],
#  ['car-rentals', 'payment-cards'],
#  ['italy', 'price', 'restaurants'],
#  ['transit', 'kul'],
#  ['visas', 'schengen'],
#  ['visas', 'schengen', 'france', 'working-holiday'],
#  ['identity-cards', 'denmark', 'kosovo'],
#  ['tips-and-tricks', 'damaged-luggage'],
#  ['car-rentals', 'us-citizens', 'panama'],
#  ['usa', 'passports', 'canadian-citizens', 'nexus'],
#  ['usa', 'esta'],
#  ['schengen', 'transit', 'uk', 'france', 'south-africa'],
#  ['tickets', 'london', 'payment-cards', 'london-underground', 'tfl'],
#  ['visas', 'uk', 'business-travel'],
#  ['trains', 'india', 'indian-railways'],
#  ['iran', 'hitchhiking', 'cultural-awareness'],
#  ['tickets', 'canada', 'new-zealand-citizens'],
#  ['accommodation', 'festivals'],
#  ['sightseeing', 'tips-and-tricks', 'road-trips'],
#  ['payment-cards'],
#  ['visas', 'uk', 'visa-refusal', 'business-travel'],
#  ['tickets'],
#  ['romania', 'croatia', 'passport-stamps', 'serbia', 'balkans'],
#  ['airports', 'yellowstone', 'grand-teton'],
#  ['uk', 'paperwork', 'visa-refusal', 'nigerian-citizens'],
#  ['tickets', 'passports'],
#  ['air-travel', 'open-jaw', 'search'],
#  ['visas', 'visa-refusal', 'religion'],
#  ['visas', 'schengen', 'indian-citizens', 'italy', 'proof-of-funds'],
#  ['online-resources', 'bookings', 'refunds'],
#  ['air-travel', 'europe', 'passports', 'business-travel', 'emergencies'],
#  ['air-travel', 'cancellations', 'compensation'],
#  ['visas', 'uk', 'indian-citizens', 'paris'],
#  ['amsterdam', 'family'],
#  ['germany', 'study', 'sweden'],
#  ['tours', 'dublin'],
#  ['road-trips', 'iceland'],
#  ['camping', 'hiking', 'iceland', 'winter'],
#  ['usa', 'legal', 'driving'],
#  ['layovers', 'lax', 'short-connection'],
#  ['legal', 'borders', 'security', 'vietnam', 'cambodia'],
#  ['esta'],
#  ['visas', 'china', 'australian-citizens', 'multiple-entry', 'vietnam'],
#  ['public-transport', 'germany', 'berlin'],
#  ['customs-and-immigration',
#   'passports',
#   'filipino-citizens',
#   'overstaying',
#   'kuwait'],
#  ['public-transport', 'transportation', 'airport-transfer', 'chicago', 'ord'],
#  ['visas', 'uk', 'canada'],
#  ['visas', 'us-citizens', 'russia'],
#  ['northern-ireland'],
#  ['usa', 'canada', 'us-visa-waiver-program', 'ferries'],
#  ['hiking', 'national-parks', 'tunisia'],
#  ['air-travel', 'tickets', 'cdg', 'yyz'],
#  ['usa', 'customs-and-immigration', 'legal', 'borders', 'drugs'],
#  ['schengen', 'aircraft', 'eu-citizens', 'russian-citizens'],
#  ['france', 'insurance', 'working-holiday'],
#  ['visas', 'schengen', 'indian-citizens'],
#  ['visas', 'schengen', 'germany', 'italy', '90-180-visa-rules'],
#  ['china', 'shopping'],
#  ['china', 'borders', 'russia', 'north-korea'],
#  ['visas', 'passports'],
#  ['europe', 'money', 'netherlands', 'exchange'],
#  ['visas', 'schengen', 'tickets', 'poland', 'residency'],
#  ['europe', 'car-rentals', 'insurance', 'portugal'],
#  ['air-travel', 'italy', 'genoa', 'verona'],
#  ['schengen', 'netherlands'],
#  ['trains', 'airport-transfer', 'tokyo', 'hnd'],
#  ['transit'],
#  ['transit'],
#  ['payment-cards', 'united-airlines', 'lounges'],
#  ['europe', 'legal', 'us-citizens', 'security'],
#  ['air-travel', 'passports', 'india', 'identity-cards'],
#  ['schengen', 'australian-citizens', 'british-citizens'],
#  ['airports', 'airport-security', 'dublin', 'dub', 'pre-clearance'],
#  ['usa', 'b1-b2-visas', 'overstaying'],
#  ['usa', 'mail'],
#  ['visas', 'spain', 'eu-citizens', 'spouses'],
#  ['airports', 'mumbai'],
#  ['online-resources', 'legal', 'accommodation', 'iran'],
#  ['visas', 'uk', 'transit'],
#  ['visas', 'schengen', 'proof-provenance-of-funds'],
#  ['loyalty-programs', 'delta-airlines', 'fare-class'],
#  ['online-resources', 'flight-search-engines', 'mobile-apps'],
#  ['luggage', 'lhr'],
#  ['usa', 'transit', 'esta'],
#  ['usa', 'canada', 'esta', 'us-visa-waiver-program', 'visa-extensions'],
#  ['visas', 'usa', 'german-citizens'],
#  ['usa', 'transit', 'luggage', 'airlines'],
#  ['air-travel', 'terminology', 'fare-class', 'fare-basis'],
#  ['visas', 'uk', 'application-status'],
#  ['visas', 'schengen', 'itineraries'],
#  ['visas', 'schengen', 'destinations'],
#  ['schengen', 'germany', 'amsterdam'],
#  ['air-travel', 'tickets', 'airlines'],
#  ['paris', 'internet', 'communication'],
#  ['budget', 'international-travel', 'paris', 'liege'],
#  ['car-rentals', 'automobiles', 'paris'],
#  ['trains', 'international-travel', 'prague', 'cologne'],
#  ['europe', 'camping', 'poland', 'eastern-europe'],
#  ['customs-and-immigration', 'health', 'australia'],
#  ['passports', 'italy', 'paperwork', 'emergencies', 'malaysian-citizens'],
#  ['air-travel', 'compensation', 'iberia', 'overbooking'],
#  ['tickets', 'indian-railways', 'tatkal'],
#  ['schengen'],
#  ['visas', 'air-travel', 'transit', 'canada', 'jordanian-citizens'],
#  ['identify-this', 'national-parks', 'locate-this', 'utah'],
#  ['visas', 'canada', 'cruising', 'residency', 'filipino-citizens'],
#  ['usa', 'customs-and-immigration', 'mexico', 'b1-b2-visas'],
#  ['schengen', 'itineraries'],
#  ['visas', 'schengen', 'paperwork'],
#  ['visas', 'schengen'],
#  ['visas', 'us-visa-waiver-program'],
#  ['visas', 'schengen', 'belgium'],
#  ['air-travel', 'china', 'cancellations', 'fees-and-charges', 'vietnam'],
#  ['uk', 'visa-refusal', 'uae', 'pakistani-citizens', 'applications'],
#  ['visas', 'schengen', 'cruising'],
#  ['airports', 'london', 'tap-water', 'lcy'],
#  ['hotels', 'hong-kong', 'hygiene'],
#  ['uk', 'hygiene', 'england', 'accessibility'],
#  ['international-travel', 'one-way'],
#  ['budget', 'online-resources', 'sweden', 'denmark'],
#  ['france', 'children', 'paris', 'restaurants', 'family'],
#  ['usa', 'us-visa-waiver-program'],
#  ['visas', 'air-travel', 'usa'],
#  ['schengen', 'france', 'multiple-entry'],
#  ['visas', 'uk', 'south-african-citizens'],
#  ['usa', 'customs-and-immigration', 'passports'],
#  ['public-transport', 'airport-transfer', 'dublin', 'dub'],
#  ['airports', 'airport-security', 'dublin', 'dub', 'pre-clearance'],
#  ['luggage', 'airlines', 'qantas'],
#  ['india', 'indian-citizens', 'duty-free'],
#  ['visas', 'uk', 'canadian-citizens'],
#  ['sightseeing', 'locate-this', 'north-korea'],
#  ['visas', 'schengen', 'indian-citizens'],
#  ['visas', 'b1-b2-visas', 'applications'],
#  ['uk', 'electronic-items', 'power'],
#  ['luggage', 'turkish-airlines'],
#  ['usa', 'esta'],
#  ['food-and-drink',
#   'paris',
#   'architecture',
#   'parks-and-gardens',
#   'versailles'],
#  ['visas', 'international-travel', 'china', 'backpacking'],
#  ['japan', 'cellphones'],
#  ['budget', 'europe', 'food-and-drink'],
#  ['visas', 'uk', 'visa-refusal', 'spouses'],
#  ['usa', 'automobiles', 'rental', 'florida', 'michigan'],
#  ['passports', 'paperwork'],
#  ['visas', 'uk', 'indian-citizens'],
#  ['weather-and-climate', 'clothing', 'brazil', 'pantanal'],
#  ['public-transport', 'borders'],
#  ['visas', 'uk', 'applications'],
#  ['iran', 'tehran'],
#  ['safety', 'bicycles', 'poland', 'romania'],
#  ['visas', 'uk', 'france', 'indian-citizens'],
#  ['visas', 'dual-nationality', 'brazilian-citizens'],
#  ['visas', 'dubai', 'south-african-citizens'],
#  ['usa', 'electronic-items', 'duty-free'],
#  ['visas', 'usa', 'thailand'],
#  ['luggage-storage', 'boston'],
#  ['visas', 'usa'],
#  ['hiking', 'vancouver'],
#  ['united-airlines'],
#  ['uk', 'rental', 'driving-licenses'],
#  ['visas', 'uk', 'canadian-citizens'],
#  ['eu', 'roaming'],
#  ['austria', 'religion', 'vienna'],
#  ['visas',
#   'international-travel',
#   'terminology',
#   'singapore',
#   'denial-of-entry'],
#  ['visas', 'schengen', 'business-travel'],
#  ['usa', 'buses', 'esta', 'us-visa-waiver-program', 'land-borders'],
#  ['schengen',
#   'uk-citizens',
#   'dual-nationality',
#   'pakistan',
#   'turkish-citizens'],
#  ['online-resources', 'bookings', 'indian-railways', 'tatkal'],
#  ['esta', 'application-status', 'irish-citizens'],
#  ['france',
#   'rental',
#   'water-sports',
#   'sports-equipment',
#   'canoeing-and-kayaking'],
#  ['visas', 'schengen'],
#  ['visas', 'international-travel', 'spain', 'eu'],
#  ['trains', 'public-transport', 'tickets', 'amsterdam', 'rotterdam'],
#  ['customs-and-immigration', 'legal', 'japan', 'shopping'],
#  ['passports', 'legal', 'minors'],
#  ['customs-and-immigration', 'europe', 'russia', 'svo'],
#  ['visas', 'transit', 'india', 'canadian-citizens', 'kathmandu'],
#  ['usa', 'food-and-drink', 'tipping'],
#  ['visas', 'usa', 'schengen', 'stateless-persons'],
#  ['air-travel'],
#  ['airlines', 'united-airlines', 'code-share'],
#  ['rental', 'clothing', 'iran', 'tehran'],
#  ['visas', 'uk', 'south-africa'],
#  ['budget', 'atlantic-ocean'],
#  ['visas', 'amsterdam'],
#  ['visas', 'air-travel', 'overstaying', 'visa-free-entry', 'denial-of-entry'],
#  ['passports', 'indian-citizens'],
#  ['schengen', 'germany', 'paperwork'],
#  ['safety', 'camping', 'belgium', 'hostels', 'festivals'],
#  ['visas', 'schengen', 'france', 'indian-citizens'],
#  ['visas', 'uk', 'transit', 'lgw', 'azerbaijani-citizens'],
#  ['camping', 'new-zealand', 'auckland', 'star-gazing'],
#  ['visas', 'uk'],
#  ['visas', 'transit', 'australia', 'transit-visas'],
#  ['trains', 'online-resources', 'iran'],
#  ['france', 'cellphones'],
#  ['visas', 'uk', 'london', 'syrian-citizens'],
#  ['air-travel', 'children', 'seating'],
#  ['visas', 'usa', 'iran'],
#  ['schengen',
#   'indian-citizens',
#   'accommodation',
#   'czech-republic',
#   'invitation-letter'],
#  ['visas', 'us-citizens', 'vietnam'],
#  ['public-transport', 'buses', 'malta', 'nostalgia'],
#  ['communication', 'roaming'],
#  ['b1-b2-visas', 'j1-visas'],
#  ['visas', 'air-travel', 'esta', 'vancouver'],
#  ['visas', 'schengen', 'accommodation', 'new-york-city'],
#  ['transit'],
#  ['air-travel', 'passports', 'bookings'],
#  ['airport-transfer', 'lhr'],
#  ['vietnam', 'visa-extensions'],
#  ['safety', 'paris', 'solo-travel', 'female-travellers'],
#  ['airlines', 'low-cost-carriers', 'jet-airways'],
#  ['indonesia'],
#  ['visas', 'visa-refusal', 'overstaying', 'denmark'],
#  ['air-travel',
#   'online-resources',
#   'bookings',
#   'aircraft',
#   'flight-search-engines'],
#  ['israel', 'jordan'],
#  ['schengen', 'transit', 'airport-security', 'munich'],
#  ['japan', 'etiquette', 'ryokans'],
#  ['air-travel',
#   'customs-and-immigration',
#   'electronic-items',
#   'central-europe'],
#  ['japan', 'cellphones'],
#  ['trains', 'netherlands', 'belgium'],
#  ['visas', 'australia', 'south-africa'],
#  ['health', 'philippines'],
#  ['visas', 'schengen', 'transportation'],
#  ['visas', 'uk', 'visa-refusal', 'denial-of-entry'],
#  ['visas', 'uk', 'paperwork', 'visa-refusal', 'denial-of-entry'],
#  ['visas', 'uk', 'visa-refusal', 'visa-free-entry', 'denial-of-entry'],
#  ['visas', 'uk', 'visa-refusal', 'denial-of-entry', 'officials'],
#  ['visas', 'schengen', 'conferences'],
#  ['visas', 'schengen', 'uk', 'france', 'germany'],
#  ['religion', 'islam', 'ramadan', 'bahrain'],
#  ['air-travel', 'safety', 'dubai'],
#  ['uk', 'trains', 'tickets', 'bookings', 'national-rail'],
#  ['visas', 'south-africa', 'dutch-citizens'],
#  ['customs-and-immigration'],
#  ['tickets', 'indonesia', 'sydney', 'syd', 'jetstar'],
#  ['visas', 'schengen', 'indian-citizens', 'multiple-entry', 'slovenia'],
#  ['visas', 'uk', 'customs-and-immigration', 'canadian-citizens'],
#  ['india', 'western-usa', 'pilgrimages'],
#  ['visas', 'schengen', 'indian-citizens', 'stop-overs', 'zrh'],
#  ['tickets', 'legal', 'bookings'],
#  ['transit', 'lhr'],
#  ['visas', 'schengen', 'transit', 'syrian-citizens', 'gva'],
#  ['london', 'sightseeing'],
#  ['visas', 'usa'],
#  ['usa', 'europe', 'fares', 'business-travel'],
#  ['bookings', 'fares', 'airbnb'],
#  ['visas', 'us-citizens', 'israel', 'study'],
#  ['weather-and-climate', 'iceland'],
#  ['usa', 'canada', 'esta'],
#  ['visas', 'air-travel', 'russia', 'bangladeshi-citizens'],
#  ['visas', 'transit', 'germany'],
#  ['visas', 'uk', 'visa-refusal', 'visa-rejection'],
#  ['luggage', 'peru', 'itineraries', 'machu-picchu', 'altitude'],
#  ['visas', 'schengen', 'germany', 'fra'],
#  ['london', 'accommodation', 'rental'],
#  ['air-travel'],
#  ['san-francisco', 'hitchhiking', 'montreal'],
#  ['transit', 'indian-citizens', 'russia', 'cuba'],
#  ['transit', 'london'],
#  ['taxes'],
#  ['visas', 'uk', 'money', 'proof-of-funds'],
#  ['customs-and-immigration', 'indian-citizens'],
#  ['trains', 'milan', 'florence', 'mxp'],
#  ['canada', 'exchange', 'mexico'],
#  ['visas', 'schengen', 'indian-citizens'],
#  ['usa', 'passports', 'b1-b2-visas'],
#  ['taxis', 'croatia'],
#  ['food-and-drink', 'austria', 'vienna', 'souvenirs'],
#  ['visas'],
#  ['airport-security', 'tsa', 'luxury', 'tsa-precheck'],
#  ['visas', 'transit', 'indian-citizens', 'turkey'],
#  ['passports', 'us-citizens', 'borders', 'minors'],
#  ['visas', 'air-travel', 'schengen', 'europe'],
#  ['visas', 'transit', 'indian-citizens', 'cuba'],
#  ['visas', 'paperwork'],
#  ['usa', 'customs-and-immigration', 'luggage', 'canada'],
#  ['paris', 'guidebooks', 'milan'],
#  ['thailand', 'new-zealand-citizens'],
#  ['tickets', 'international-travel', 'australia', 'us-citizens'],
#  ['customs-and-immigration', 'canada', 'alcohol'],
#  ['visas', 'usa', 'filipino-citizens'],
#  ['air-travel', 'delays', 'compensation'],
#  ['spain', 'national-parks', 'barcelona', 'train-stations'],
#  ['cruising', 'istanbul', 'tbilisi', 'black-sea', 'batumi'],
#  ['visas', 'indian-citizens', 'jamaica'],
#  ['visas', 'international-travel', 'kazakhstan'],
#  ['visas', 'usa', 'transit', 'indian-citizens', 'ireland'],
#  ['public-transport', 'buses', 'austria', 'salzburg'],
#  ['europe', 'safety', 'solo-travel', 'hitchhiking', 'western-europe'],
#  ['luggage', 'united-airlines'],
#  ['barcelona', 'madrid', 'summer'],
#  ['canada', 'insurance', 'payment-cards'],
#  ['factoids', 'where-on-earth', 'destinations', 'geek-travel'],
#  ['canada', 'insurance', 'payment-cards'],
#  ['visas', 'schengen', 'uk'],
#  ['schengen'],
#  ['air-travel', 'aircraft'],
#  ['visas', 'hong-kong', 'overstaying', 'italian-citizens'],
#  ['where-on-earth', 'internet'],
#  ['visas', 'schengen', 'indian-citizens', 'hungary'],
#  ['air-travel', 'transit', 'germany', 'car-rentals', 'austria'],
#  ['trains', 'budget', 'eurail'],
#  ['visas', 'schengen', 'uk', 'indian-citizens'],
#  ['visas', 'usa', 'transit'],
#  ['online-resources',
#   'bookings',
#   'seating',
#   'british-airways',
#   'american-airlines'],
#  ['europe', 'cellphones', 'norway'],
#  ['visas', 'uk-citizens', 'visas-on-arrival', 'multiple-entry', 'nepal'],
#  ['visas', 'schengen', 'transit', 'ghanaian-citizens'],
#  ['italy', 'local-customs', 'restaurants', 'local-cuisine'],
#  ['uk', 'customs-and-immigration', 'pets'],
#  ['visas', 'stateless-persons', 'refugees'],
#  ['tickets', 'online-resources', 'bookings'],
#  ['airports', 'sleeping', 'fra', 'frankfurt'],
#  ['sea-travel', 'croatia', 'dubrovnik', 'split'],
#  ['visas', 'visa-refusal', 'denmark'],
#  ['public-transport', 'airport-transfer', 'portugal', 'lisbon', 'lis'],
#  ['central-america', 'passport-stamps', 'panama', 'taxes'],
#  ['trains', 'germany', 'wifi'],
#  ['visas', 'air-travel', 'uk', 'transit', 'nigerian-citizens'],
#  ['usa', 'customs-and-immigration'],
#  ['legal', 'layovers', 'brussels', 'short-connection'],
#  ['trains', 'japan', 'shinkansen'],
#  ['where-on-earth', 'cuba', 'architecture', 'locate-this'],
#  ['public-transport', 'tickets', 'brussels'],
#  ['visas', 'uk', 'europe', 'automobiles', 'eurostar'],
#  ['visas', 'air-travel', 'us-citizens', 'layovers', 'turkey'],
#  ['china', 'maps'],
#  ['south-africa', 'cape-town'],
#  ['health', 'weather-and-climate', 'tropical-destinations', 'deserts'],
#  ['visas', 'schengen', 'indian-citizens', 'paperwork', 'denmark'],
#  ['visas', 'budget', 'health', 'cuba', 'new-orleans'],
#  ['sydney', 'syd'],
#  ['airport-transfer', 'luggage-storage', 'barcelona', 'bcn'],
#  ['usa', 'campers', 'western-usa'],
#  ['vietnam', 'activities', 'outdoor-activities', 'parks-and-gardens'],
#  ['public-transport', 'europe', 'milan'],
#  ['paris', 'cruising'],
#  ['schengen', 'france', 'visa-refusal'],
#  ['india'],
#  ['public-transport'],
#  ['legal', 'nature-and-wildlife', 'england', 'swimming'],
#  ['china', 'mail', 'import-tax', 'taxes'],
#  ['turkey', 'weather-and-climate', 'beaches'],
#  ['car-rentals', 'paris'],
#  ['hiking', 'mobile-apps', 'hillwalking', 'third-party-sites'],
#  ['visas', 'uk', 'paperwork', 'deportation'],
#  ['airport-transfer', 'china', 'beijing', 'great-wall-of-china'],
#  ['china', 'beijing', 'xian'],
#  ['transit', 'airports', 'vietnam', 'hanoi', 'han'],
#  ['public-transport', 'rotterdam'],
#  ['barcelona', 'locate-this'],
#  ['transit', 'dublin', 'short-connection', 'dub'],
#  ['visas', 'transit', 'indian-citizens', 'cai'],
#  ['tickets', 'online-resources'],
#  ['customs-and-immigration', 'airports', 'nas'],
#  ['visas', 'transit', 'amsterdam', 'filipino-citizens'],
#  ['uk', 'trains', 'safety', 'bicycles'],
#  ['trains', 'netherlands', 'belgium'],
#  ['air-travel', 'food-and-drink', 'hand-luggage'],
#  ['visas', 'schengen', 'uk', 'indian-citizens', 'denmark'],
#  ['visas', 'schengen'],
#  ['customs-and-immigration', 'esta', 'jfk', 'missed-flights', 'san-diego'],
#  ['tours', 'netherlands', 'walking'],
#  ['air-travel', 'airlines'],
#  ['china', 'language-barrier', 'languages'],
#  ['trains', 'south-america', 'ecuador'],
#  ['air-travel', 'airport-security'],
#  ['visas', 'schengen', 'romania', 'new-zealand-citizens'],
#  ['health', 'hygiene', 'asia'],
#  ['health', 'food-and-drink', 'western-europe'],
#  ['us-citizens', 'proof-of-onward-travel'],
#  ['tokyo', 'nightlife'],
#  ['trains', 'public-transport', 'brussels'],
#  ['uk', 'trains'],
#  ['vietnam', 'outdoor-activities'],
#  ['uk', 'hiking', 'walking', 'lake-district'],
#  ['indian-citizens', 'visa-free-entry', 'dominican-republic'],
#  ['usa', 'customs-and-immigration', 'passports'],
#  ['automobiles', 'new-york-city'],
#  ['bookings', 'paris', 'taxis'],
#  ['air-travel', 'usa', 'budget', 'cancellations'],
#  ['usa', 'international-travel', 'chinese-citizens'],
#  ['usa', 'weather-and-climate', 'hiking'],
#  ['air-travel', 'tickets', 'seating', 'ryanair'],
#  ['global-entry'],
#  ['passports', 'russia', 'russian-citizens', 'consulates'],
#  ['passports', 'russia', 'russian-citizens', 'embassies', 'consulates'],
#  ['paris', 'weather-and-climate'],
#  ['europe', 'food-and-drink', 'dietary-restrictions'],
#  ['schengen', 'italy', 'multiple-entry', 'austria'],
#  ['air-travel', 'delays', 'emergencies', 'turkish-airlines'],
#  ['visas', 'uk', 'indian-citizens', 'london'],
#  ['budget', 'france', 'car-rentals'],
#  ['visas', 'schengen', 'transit', 'zurich', 'thai-citizens'],
#  ['uk', 'lhr', 'london-underground', 'oxford', 'national-rail'],
#  ['trains', 'canada', 'bicycles'],
#  ['legal', 'consulates'],
#  ['visas', 'usa', 'schengen', 'india', 'germany'],
#  ['trains', 'germany', 'bookings', 'belgium', 'eurail'],
#  ['visas', 'schengen'],
#  ['transportation', 'thailand', 'remote-locations'],
#  ['legal', 'japan', 'regulations', 'tokyo', 'minors'],
#  ['trains', 'public-transport', 'tickets', 'stockholm'],
#  ['air-travel'],
#  ['visas', 'china'],
#  ['usa', 'passports', 'layovers'],
#  ['usa', 'canada', 'russian-citizens', 'mail'],
#  ['cellphones', 'internet', 'austria', 'vienna'],
#  ['india', 'transportation', 'weather-and-climate'],
#  ['buses', 'finland', 'helsinki', 'hel'],
#  ['visas', 'schengen'],
#  ['food-and-drink', 'regulations', 'netherlands'],
#  ['visas', 'transit', 'portugal', 'transit-visas'],
#  ['passports', 'airports', 'uk-citizens', 'dual-nationality'],
#  ['customs-and-immigration', 'luggage', 'international-travel'],
#  ['sightseeing', 'chicago'],
#  ['usa', 'cellphones'],
#  ['esta'],
#  ['accommodation', 'rental', 'summer', 'montenegro'],
#  ['visas', 'thailand', 'uk-citizens'],
#  ['visas', 'schengen', 'germany', 'visa-refusal'],
#  ['trains', 'public-transport', 'washington-dc'],
#  ['visas', 'passports', 'australia'],
#  ['visas', 'schengen', 'italy', 'visa-refusal'],
#  ['legal', 'japan', 'photography', 'officials'],
#  ['air-travel', 'regulations'],
#  ['air-travel', 'uk'],
#  ['us-citizens', 'cuba'],
#  ['usa', 'b1-b2-visas'],
#  ['passports', 'russia', 'russian-citizens'],
#  ['usa', 'trains', 'fares', 'amtrak'],
#  ['visas', 'air-travel', 'uk', 'visas-on-arrival', 'visa-free-entry'],
#  ['beaches',
#   'event-based-effects',
#   'canary-islands',
#   'environmental-disasters'],
#  ['visas', 'schengen', 'invitation-letter', 'proof-of-accomodation'],
#  ['visas', 'transit', 'lhr'],
#  ['air-travel', 'usa', 'routes'],
#  ['luggage', 'canada', 'international-travel'],
#  ['visas', 'uk', 'customs-and-immigration', 'passports', 'visas-on-arrival'],
#  ['visas', 'schengen', 'spain'],
#  ['schengen', 'eu'],
#  ['passports', 'ukraine'],
#  ['usa', 'esta'],
#  ['visas', 'schengen', 'uk', 'germany-schengen-visas'],
#  ['schengen'],
#  ['nepal', 'event-based-effects', 'natural-disasters'],
#  ['visas', 'dubai'],
#  ['air-travel', 'schengen', 'customs-and-immigration', 'eu'],
#  ['schengen', 'us-citizens', 'switzerland', 'eu'],
#  ['passports', 'russian-citizens', 'consulates'],
#  ['usa', 'passports'],
#  ['airports', 'layovers', 'sleeping', 'munich', 'muc'],
#  ['sweden', 'gifts'],
#  ['air-travel', 'international-travel', 'travel-agents', 'delta-airlines'],
#  ['customs-and-immigration', 'airports', 'layovers', 'oslo'],
#  ['visas', 'russia'],
#  ['trains', 'price', 'balkans', 'montenegro'],
#  ['visas', 'schengen', 'indian-citizens'],
#  ['uk',
#   'indian-citizens',
#   'visa-refusal',
#   'family',
#   'proof-provenance-of-funds'],
#  ['trains', 'sweden', 'day-trips', 'stockholm'],
#  ['visas', 'italy', 'german-citizens', 'filipino-citizens'],
#  ['visas', 'air-travel', 'schengen', 'germany', 'paris'],
#  ['visas', 'uk', 'nepali-citizens'],
#  ['air-travel', 'paperwork'],
#  ['visas', 'schengen', 'uk'],
#  ['visas', 'transit', 'dubai', 'iranian-citizens', 'dub'],
#  ['international-travel', 'payment-cards'],
#  ['air-travel', 'food-and-drink', 'emirates', 'in-flight-service'],
#  ['transit', 'airport-security', 'new-york-city', 'jfk'],
#  ['uk', 'visa-refusal', 'proof-of-funds'],
#  ['nepal', 'event-based-effects', 'natural-disasters'],
#  ['visas', 'belgium', 'around-the-world'],
#  ['visas', 'usa', 'customs-and-immigration', 'canada'],
#  ['usa', 'passports', 'mexican-citizens'],
#  ['transit', 'customs-and-immigration', 'indian-citizens', 'oman', 'muscat'],
#  ['europe', 'international-travel', 'car-rentals', 'montenegro', 'dubrovnik'],
#  ['passports', 'china', 'passport-stamps'],
#  ['japan', 'automobiles', 'festivals'],
#  ['money', 'cuba'],
#  ['customs-and-immigration', 'food-and-drink', 'australia'],
#  ['visas', 'removal'],
#  ['us-citizens',
#   'dual-nationality',
#   'overstaying',
#   'south-africa',
#   'spanish-citizens'],
#  ['customs-and-immigration', 'south-africa', 'overstaying'],
#  ['visas', 'schengen', 'south-african-citizens'],
#  ['usa', 'customs-and-immigration', 'proof-of-funds', 'malaysian-citizens'],
#  ['legal', 'road-trips'],
#  ['visas', 'schengen', 'indian-citizens'],
#  ['italy', 'sports-events'],
#  ['transit', 'mobile-apps'],
#  ['visas', 'indian-citizens', 'singapore', 'overstaying'],
#  ['visas', 'schengen', 'spain', 'greece', '90-180-visa-rules'],
#  ['visas', 'schengen', 'germany', 'long-stay-visas'],
#  ['local-customs', 'sea-travel', 'croatia', 'montenegro', 'dubrovnik'],
#  ['visas', 'transit', 'us-citizens', 'south-africa', 'overstaying'],
#  ['air-travel', 'flight-status'],
#  ['air-travel', 'uk', 'luggage', 'airports', 'hand-luggage'],
#  ['recommendations', 'dublin'],
#  ['transit', 'layovers', 'dubai', 'pakistani-citizens'],
#  ['visas', 'international-travel', 'australia', 'dutch-citizens', 'eta'],
#  ['visas', 'uk', 'london'],
#  ['air-travel', 'usa', 'schengen', 'trains', 'visas-on-arrival'],
#  ['airlines', 'cancellations', 'american-airlines', 'refunds', 'vouchers'],
#  ['new-york-city'],
#  ['budget', 'germany', 'transportation', 'berlin'],
#  ['customs-and-immigration', 'italy', 'czech-republic', 'lost-documents'],
#  ['visas', 'schengen', 'visa-duration'],
#  ['usa', 'planning'],
#  ['trains', 'tickets', 'france', 'bookings', 'sncf'],
#  ['air-travel', 'saudi-airlines'],
#  ['customs-and-immigration', 'international-travel', 'layovers'],
#  ['luggage', 'legal'],
#  ['japan', 'language-barrier'],
#  ['india', 'airport-security'],
#  ['air-travel', 'luggage'],
#  ['budget', 'accommodation', 'hostels', 'iran'],
#  ['uk', 'visa-refusal', 'j1-visas', 'nigerian-citizens'],
#  ['customs-and-immigration', 'india'],
#  ['japan', 'meditation'],
#  ['usa', 'indian-citizens', 'b1-b2-visas'],
#  ['visas', 'sweden-citizens'],
#  ['visas', 'ireland'],
#  ['passports', 'dual-nationality'],
#  ['visas', 'china', 'invitation-letter'],
#  ['visas', 'international-travel', 'south-korea'],
#  ['visas', 'uk'],
#  ['visas', 'canada', 'proof-of-funds', 'romanian-citizens'],
#  ['usa', 'customs-and-immigration', 'money', 'paperwork'],
#  ['bookings', 'family'],
#  ['visas', 'canadian-citizens', 'chinese-citizens'],
#  ['germany', 'safety', 'hotels', 'berlin', 'solo-travel'],
#  ['visas', 'schengen', 'uk', 'south-africa', 'overstaying'],
#  ['visas', 'uk', 'visa-refusal'],
#  ['south-korea', 'north-korea'],
#  ['budget', 'public-transport', 'france', 'accommodation', 'paris'],
#  ['trains', 'france', 'bookings', 'high-speed-rail', 'sncf'],
#  ['usa',
#   'customs-and-immigration',
#   'dual-nationality',
#   'british-citizens',
#   'jamaican-citizen'],
#  ['india', 'cultural-awareness'],
#  ['tickets', 'airports', 'paperwork', 'shopping', 'rationale'],
#  ['india', 'bookings', 'indian-railways', 'refunds'],
#  ['usa', 'canada', 'car-rentals', 'insurance'],
#  ['tickets', 'airlines', 'fares'],
#  ['uk', 'hiking', 'pilgrimages', 'literature', 'yorkshire'],
#  ['schengen', 'europe', 'food-and-drink'],
#  ['usa', 'ferries', 'cuba', 'florida'],
#  ['air-travel', 'airports', 'international-travel', 'layovers', 'osl'],
#  ['visas', 'uk', 'us-citizens', 'denial-of-entry', 'removal'],
#  ['money', 'uk-citizens', 'sweden'],
#  ['public-transport', 'safety', 'buses', 'cuba'],
#  ['hiking', 'macau'],
#  ['visas', 'vietnam', 'hanoi'],
#  ['visas', 'uk'],
#  ['visas'],
#  ...]

# %%
mlb = MultiLabelBinarizer(classes=sorted(tags_counts.keys()))
y_train = mlb.fit_transform(y_train)
y_val = mlb.fit_transform(y_val)

# %%
y_train.shape
# Out:
# (18000, 1607)

# %% [markdown]
# Train the classifiers for different data transformations: *bag-of-words* and *tf-idf*.

# %%
# %%time
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression, RidgeClassifier
clf = OneVsRestClassifier(RidgeClassifier(normalize=True))
clf.fit(X_train_tfidf, y_train)
# classifier_tfidf = train_classifier(X_train_tfidf, y_train)

# %% [markdown]
# Now you can create predictions for the data. You will need two types of predictions: labels and scores.

# %%
# %%time
y_val_predicted_labels_tfidf = clf.predict(X_val_tfidf)
# y_val_predicted_scores_tfidf = classifier_tfidf.decision_function(X_val_tfidf)
# Out:
# Wall time: 46.9 ms

# %% [markdown]
# Now take a look at how classifier, which uses TF-IDF, works for a few examples:

# %%
que = ['How do I stop pasta from clumping/sticking together?','What is a stick of butter?','how to do tadka in daal?', 'how to make chocolate brownie?']
que = [text_prepare(i) for i in que]
# que = [que]
que = tfidf_vectorizer.transform(que)
yp = clf.predict(que)
print(mlb.inverse_transform(yp))
# Out:
# [('pasta',), ('butter',), (), ('baking', 'brownies', 'chocolate')]

# %%
import pickle
import os 
pickle.dump(clf, open('model-cooking.pkl', 'wb'))
pickle.dump(mlb, open('tags-cooking.pkl', 'wb'))
pickle.dump(tfidf_vectorizer, open('tf-coking.pkl', 'wb'))
